# %% [markdown]
# ## Analysis of Funding Received by Start-ups in India from 2018 to 2021
#
# # 1. Business Understanding
#
#      1.1 Project Description
#
# This is analysis project focuses on the funding received by start-ups in India from 2018 to 2021. The objective is to gain insights into the Indian start-up ecosystem and recommend the best action for our team's venture. By analyzing the data on funding amounts, start-up details, and investor information, we aim to uncover prevailing patterns and gain insights into the opportunities within India's start-up ecosystem to inform decision-making.
#
#      1.2 Type of Problem
#
# This project involves exploratory data analysis (EDA) and visualization. Our goal is to deduce hidden insights and patterns from the available data.

# %% [markdown]
# ## 2. Data Understanding
#
# We have collected data from various startups in India spanning the years 2018 to 2021, including information on the amounts they received in funding. By analyzing this data, we aim to gain a deeper insight into the startup ecosystem and identify the key contributing factors.

# %% [markdown]
# ## 3. Data Assumptions
#
# The amounts in the 2019 dataset are all in USD. Please note that the exchange rate for 2018 is \***\*1 USD = 70 INR**.

# %% [markdown]
# ## 4. Data Analytics questions and Hypthesis

# %% [markdown]
#     5 SMART Analytics Questions:
#
# 1.  What is the overall trend in funding received by start-ups in India from 2018 to 2021?
# 2.  Which sectors have received the highest funding during this period?
# 3.  What is the distribution of startups across the cities in India?
# 4.  What is the average funding amount received by start-ups in India during this period?
# 5.  What is the distribution of the number of startups that received funding in each year from 2018 to 2021?
# 6.  At What Stages were Most Start-ups Funded?
# 7.  Hypotheses testing
#
# Hypothesis 1
#
# **Null Hypothesis (H₀):** There are no significant disparities in funding received by different sectors of Indian startups.
#
# **Alternate Hypothesis (Ha):** The technology sector receives significantly higher funding compared to other industries.
#
# Hypothesis 2
#
# **Null Hypothesis (H₀):** The location of a startup in a particular city does not influence the amount of funding it receives.
#
# **Alternate Hypothesis (Ha):** The location of a startup in a particular city significantly affects the amount of funding it receives.
#
#     Hypotheses justifications
#
# **Hypothesis 1:** The technology sector is often seen as a high-growth area with substantial investment potential, which may lead to higher funding.
#
# **Hypothesis 2:** Certain cities might have more developed startup ecosystems, better infrastructure, and more active investment communities, which could impact funding amounts.
#
#     Testing Methods
#
# **For Hypothesis 1:** We will use statistical tests like t-tests to compare the average funding amounts across different sectors.
#
# **For Hypothesis 2:** We will use statistical tests such regression analysis to analyze the funding amounts across different cities.

# %% [markdown]
# ## 5. Data preparation

# %% [markdown]
#     5.1 Importing libraries

# %%
import os, sys
from sqlalchemy import create_engine
import pyodbc # Database Connectivity with  Open Database Connectivity (pyodbc)
from dotenv import dotenv_values # dotenv library to load environment variables

# Lib for data manipulation  analysis  
import pandas as pd
import numpy as np
import sklearn

from sklearn.impute import SimpleImputer

# lib for Vizualization
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import f_oneway
from scipy import stats
from prettytable import PrettyTable
# from matplotlib.ticker import FuncFormatter
import re # regular expressions.
from matplotlib.colors import LinearSegmentedColormap
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
#     5.2 Loading datasets

# %%
# Load environment variables from .env file 

environment_variables=dotenv_values('.env')
# Access login credentials from  the '.env' file
server = environment_variables.get("SERVER")
database = environment_variables.get("DATABASE")
username = environment_variables.get("UID")
password = environment_variables.get("PWD")

# %%
#  Credection Connection tesr
connection = f"DRIVER={{SQL Server}};SERVER={server};DATABASE={database};UID={username};PWD={password}"

# %%
# connect to the server .

con = pyodbc.connect(connection)

# %%
# Load the dataset SQL query
query1 = "Select * from dbo.LP1_startup_funding2020"
query2 = "Select * from dbo.LP1_startup_funding2021"

# Read data from the  on dataset to the dataframe 
data_2018 = pd.read_csv('dataset\startup_funding2018.csv')
data_2019 = pd.read_csv('dataset\startup_funding2019.csv')
data_2020 = pd.read_sql(query1, con)
data_2021 = pd.read_sql(query2, con)

# %% [markdown]
#     5.2.1 Data Overview

# %%
# 2018 dataset 
data_2018.head(3)
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
#
#   Round/Series       Amount                     Location  \
# 0         Seed       250000  Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000   Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000      Gurgaon, Haryana, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# 2          Leading Online Loans Marketplace in India

# %%
# 2019 dataset 
data_2019.head(3)
# Out:
#     Company/Brand  Founded HeadQuarter     Sector  \
# 0  Bombay Shaving      NaN         NaN  Ecommerce
# 1       Ruangguru   2014.0      Mumbai     Edtech
# 2        Eduisfun      NaN      Mumbai     Edtech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
#
#                                          Investor     Amount($)          Stage
# 0                            Sixth Sense Ventures    $6,300,000            NaN
# 1                                General Atlantic  $150,000,000       Series C
# 2  Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000  Fresh funding

# %%
# 2020 dataset 
data_2020.head(3)
# Out:
#   Company_Brand  Founded HeadQuarter              Sector  \
# 0    Aqgromalin   2019.0     Chennai            AgriTech
# 1      Krayonnz   2019.0   Bangalore              EdTech
# 2  PadCare Labs   2018.0        Pune  Hygiene management
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
#
#                            Founders         Investor   Amount     Stage  \
# 0   Prasanna Manogaran, Bharani C L  Angel investors 200000.0      None
# 1  Saurabh Dixit, Gurudutt Upadhyay  GSF Accelerator 100000.0  Pre-seed
# 2                   Ajinkya Dhariya   Venture Center      NaN  Pre-seed
#
#   column10
# 0     None
# 1     None
# 2     None

# %%
# 2021 dataset 
data_2021.head(3)
# Out:
#     Company_Brand  Founded HeadQuarter      Sector  \
# 0  Unbox Robotics   2019.0   Bangalore  AI startup
# 1          upGrad   2015.0      Mumbai      EdTech
# 2     Lead School   2012.0      Mumbai      EdTech
#
#                                         What_it_does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
#
#                                    Investor        Amount         Stage
# 0               BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1  Unilazer Ventures, IIFL Asset Management  $120,000,000          None
# 2          GSV Ventures, Westbridge Capital   $30,000,000      Series D

# %% [markdown]
# Similarities of datasets

# %%
data_2018.columns
# Out:
# Index(['Company Name', 'Industry', 'Round/Series', 'Amount', 'Location',
#        'About Company'],
#       dtype='object')

# %%
data_2019.columns
# Out:
# Index(['Company/Brand', 'Founded', 'HeadQuarter', 'Sector', 'What it does',
#        'Founders', 'Investor', 'Amount($)', 'Stage'],
#       dtype='object')

# %%
data_2020.columns
# Out:
# Index(['Company_Brand', 'Founded', 'HeadQuarter', 'Sector', 'What_it_does',
#        'Founders', 'Investor', 'Amount', 'Stage', 'column10'],
#       dtype='object')

# %%
data_2021.columns
# Out:
# Index(['Company_Brand', 'Founded', 'HeadQuarter', 'Sector', 'What_it_does',
#        'Founders', 'Investor', 'Amount', 'Stage'],
#       dtype='object')

# %% [markdown]
#         5.3 Data Exploration

# %% [markdown]
#     5.3.1 2018 Data

# %% [markdown]
# 5.3.1.1 Data Inspection

# %% [markdown]
# ![Data 2018 Summary Image](Images\2018DataWrangler1.png)

# %%
data_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
# dtypes: object(6)
# memory usage: 24.8+ KB

# %% [markdown]
# Statistics summary of 2018 data

# %% [markdown]
# From the result summary
#
# - 2018 Data has no Missing values
# - columns are in string data type

# %% [markdown]
# 5.3.1.2 Handling Missing values

# %% [markdown]
# start by checking Unique values in each column

# %%
def uniqueValue(data, column): #Industry, Round/Series,Amount, Location and Amount
    return data[column].value_counts()

# %%
#Industry
uniqueValue(data_2018,'Industry')
# Out:
# Industry
# —                                              30
# Financial Services                             15
# Education                                       8
# Information Technology                          7
# Health Care, Hospital                           5
#                                                ..
# Education, Gaming, Training                     1
# Automotive, Search Engine, Service Industry     1
# Wealth Management                               1
# B2B, Farming, Marketplace                       1
# Biotechnology, Health Care, Pharmaceutical      1
# Name: count, Length: 405, dtype: int64

# %%
uniqueValue(data_2018,'Round/Series')
# Out:
# Round/Series
# Seed                                                                                                       280
# Series A                                                                                                    73
# Angel                                                                                                       37
# Venture - Series Unknown                                                                                    37
# Series B                                                                                                    20
# Series C                                                                                                    16
# Debt Financing                                                                                              13
# Private Equity                                                                                              10
# Corporate Round                                                                                              8
# Pre-Seed                                                                                                     6
# Series E                                                                                                     5
# Grant                                                                                                        4
# Series D                                                                                                     3
# Secondary Market                                                                                             3
# Post-IPO Equity                                                                                              3
# Undisclosed                                                                                                  2
# Post-IPO Debt                                                                                                2
# Non-equity Assistance                                                                                        1
# Series H                                                                                                     1
# https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593      1
# Funding Round                                                                                                1
# Name: count, dtype: int64

# %% [markdown]
# The Column has Incosistent data
# Its have a int64 to be converted to string
# and have Undisclosed, undisclosed

# %%
uniqueValue(data_2018,'Amount')
# Out:
# Amount
# —              148
# 1000000         24
# 500000          13
# 2000000         12
# ₹50,000,000      9
#               ...
# 2200000          1
# 1200000          1
# $15,000          1
# $1,041,000       1
# 35000000         1
# Name: count, Length: 198, dtype: int64

# %% [markdown]
# From this information we ave to assume that
#
# - the amount with not current as USD Amount
# - the Column Incosistent data, has comma, has 3 different current

# %%
uniqueValue(data_2018,'Location')
# Out:
# Location
# Bangalore, Karnataka, India         102
# Mumbai, Maharashtra, India           94
# Bengaluru, Karnataka, India          55
# Gurgaon, Haryana, India              52
# New Delhi, Delhi, India              51
# Pune, Maharashtra, India             20
# Chennai, Tamil Nadu, India           19
# Hyderabad, Andhra Pradesh, India     18
# Delhi, Delhi, India                  16
# Noida, Uttar Pradesh, India          15
# Haryana, Haryana, India              11
# Jaipur, Rajasthan, India              9
# Ahmedabad, Gujarat, India             6
# Kolkata, West Bengal, India           6
# Bangalore City, Karnataka, India      5
# Indore, Madhya Pradesh, India         4
# India, Asia                           4
# Kormangala, Karnataka, India          3
# Ghaziabad, Uttar Pradesh, India       2
# Kochi, Kerala, India                  2
# Bhopal, Madhya Pradesh, India         2
# Thane, Maharashtra, India             2
# Jodhpur, Rajasthan, India             1
# Powai, Assam, India                   1
# Andheri, Maharashtra, India           1
# Mylapore, Tamil Nadu, India           1
# Kalpakkam, Tamil Nadu, India          1
# Guntur, Andhra Pradesh, India         1
# Coimbatore, Tamil Nadu, India         1
# Worli, Maharashtra, India             1
# Alleppey, Kerala, India               1
# Chandigarh, Chandigarh, India         1
# Guindy, Tamil Nadu, India             1
# Uttar Pradesh, India, Asia            1
# Trivandrum, Kerala, India             1
# Ernakulam, Kerala, India              1
# Kanpur, Uttar Pradesh, India          1
# Kannur, Kerala, India                 1
# Alwar, Rajasthan, India               1
# Margão, Goa, India                    1
# Belgaum, Karnataka, India             1
# Kalkaji, Delhi, India                 1
# Anand, Gujarat, India                 1
# Kota, Rajasthan, India                1
# Faridabad, Haryana, India             1
# Cochin, Kerala, India                 1
# Hubli, Karnataka, India               1
# Azadpur, Delhi, India                 1
# Mohali, Punjab, India                 1
# Lucknow, Uttar Pradesh, India         1
# Name: count, dtype: int64

# %% [markdown]
# The location the is have inconsitent need to need to be cleaned

# %% [markdown]
# 5.3.1.3 Data cleaning

# %% [markdown]
#     Check Duplications

# %%
data_2018.duplicated().value_counts()
# Out:
# False    525
# True       1
# Name: count, dtype: int64

# %% [markdown]
# Duplications

# %%
data_2018[data_2018.duplicated(keep=False)]
# Out:
#         Company Name                                           Industry  \
# 0    TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 348  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
#
#     Round/Series  Amount                     Location  \
# 0           Seed  250000  Bangalore, Karnataka, India
# 348         Seed  250000  Bangalore, Karnataka, India
#
#                                          About Company
# 0    TheCollegeFever is a hub for fun, fiesta and f...
# 348  TheCollegeFever is a hub for fun, fiesta and f...

# %% [markdown]
# Dropping data duplicate

# %%
# Drop 2018 data duplicates
data_2018 = data_2018.drop_duplicates()

# %%
# double check the doublicates again 
data_2018.duplicated().value_counts()
# Out:
# False    525
# Name: count, dtype: int64

# %% [markdown]
# No duplicate anymore in data 2018

# %% [markdown]
# Columns Data types

# %% [markdown]
# The `Amount` column is currently classified as a string data type, but it should be represented as an integer. Several issues in this column need to be addressed:
#
# - **Character Removal:** The presence of `,`, `$`, and `₹` characters must be eliminated.
# - **Null Values:** The `_` characters, indicating null values, need to be handled appropriately.
# - **Currency Standardization:** Amounts in Indian Rupees will be converted to US Dollars to maintain a consistent currency standard.we need ti use our assumption 1 USD = 70rupee based on avarege exchange rate of 2018
# - **Data Type Conversion:** Finally, the `Amount` column will be converted to a numeric data type.

# %%
# Remove ',' in amount
data_2018['Amount'].replace(',','', regex=True, inplace=True)
data_2018['Amount'].sample(5)
# Out:
# 240     ₹30000000
# 469    ₹400000000
# 166        $15000
# 359     ₹45000000
# 46        1300000
# Name: Amount, dtype: object

# %%
# A function to convert amount to $ and clean the amount column
def convert_to_usd(amount):
    exchange_rate = 68.4  # Average exchange rate in 2018 to USD: 68.4113 INR.[https://www.exchangerates.org.uk/USD-INR-spot-exchange-rates-history-2018.html]

    if '₹' in str(amount):  #  if  amount is in INR
        amount = (str(amount).replace('₹', ''))  

        return pd.to_numeric(amount, errors='coerce' )/ exchange_rate

    elif '$' in str(amount):

        return  amount.replace('$','')

    elif "—" in str(amount):

        return None  
    else:
        return (amount)

pd.set_option('display.float_format', '{:.1f}'.format)
# Apply the conversion function to the 'Amount' column
data_2018["Amount"] = data_2018["Amount"].apply(convert_to_usd)

# %% [markdown]
# conventing the data to numeric

# %%
data_2018["Amount"]=data_2018["Amount"].astype(float)
data_2018["Amount"].dtype
# Out:
# dtype('float64')

# %%
data_2018['Amount'].isnull().sum()
# Out:
# 148

# %%
#Imputing missing values
array= data_2018["Amount"].values.reshape(-1,1) #
imputer=SimpleImputer(strategy="median")
data_2018["Amount"]=imputer.fit_transform(array)

# %%
data_2018["Amount"].sample(5)
# Out:
# 287   1300000.0
# 431   1300000.0
# 268    242690.1
# 483   1000000.0
# 496    127924.0
# Name: Amount, dtype: float64

# %%
data_2018['Amount'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Based on other data across other 3 datasets which will later make merging easier, `Location` and `Industry` columns will only remain with the first word.

# %%
data_2018["Location"].sample(10)
# Out:
# 383           Ahmedabad, Gujarat, India
# 314         Bangalore, Karnataka, India
# 2               Gurgaon, Haryana, India
# 512            Jaipur, Rajasthan, India
# 247          Mumbai, Maharashtra, India
# 367    Hyderabad, Andhra Pradesh, India
# 370         Bangalore, Karnataka, India
# 346          Chennai, Tamil Nadu, India
# 173            Pune, Maharashtra, India
# 339         Bangalore, Karnataka, India
# Name: Location, dtype: object

# %%
# removing space and Capilize
data_2018["Location"] = data_2018["Location"].str.strip()
data_2018["Location"] = data_2018["Location"].str.title()

# split the address the Have multiple
data_2018["Location"] = data_2018["Location"].map(lambda x: x.split(',')[0])
data_2018["Location"].sample(10)
# Out:
# 14     Bangalore
# 157      Chennai
# 276        Noida
# 367    Hyderabad
# 59         India
# 154       Kannur
# 216    Bangalore
# 266       Mumbai
# 65     New Delhi
# 305    Bengaluru
# Name: Location, dtype: object

# %%
data_2018["Industry"].head(10)
# Out:
# 0    Brand Marketing, Event Promotion, Marketing, S...
# 1                                 Agriculture, Farming
# 2     Credit, Financial Services, Lending, Marketplace
# 3                          Financial Services, FinTech
# 4                   E-Commerce Platforms, Retail, SaaS
# 5                     Cloud Infrastructure, PaaS, SaaS
# 6                       Internet, Leisure, Marketplace
# 7                                      Market Research
# 8         Information Services, Information Technology
# 9                                      Mobile Payments
# Name: Industry, dtype: object

# %%
data_2018["Industry"] = data_2018["Industry"].map(lambda x: str(x).split(',')[0].strip() if pd.notnull(x) else x)

data_2018["Industry"].unique().tolist()
# Out:
# ['Brand Marketing',
#  'Agriculture',
#  'Credit',
#  'Financial Services',
#  'E-Commerce Platforms',
#  'Cloud Infrastructure',
#  'Internet',
#  'Market Research',
#  'Information Services',
#  'Mobile Payments',
#  'B2B',
#  'Apps',
#  'Food Delivery',
#  'Industrial Automation',
#  'Automotive',
#  'Finance',
#  'Accounting',
#  'Artificial Intelligence',
#  'Internet of Things',
#  'Air Transportation',
#  'Food and Beverage',
#  'Autonomous Vehicles',
#  'Enterprise Software',
#  'Logistics',
#  'Insurance',
#  'Information Technology',
#  'Blockchain',
#  'Education',
#  'E-Commerce',
#  'Renewable Energy',
#  'E-Learning',
#  'Clean Energy',
#  'Transportation',
#  'Fitness',
#  'Hospitality',
#  'Media and Entertainment',
#  'Broadcasting',
#  'EdTech',
#  'Health Care',
#  '—',
#  'Sports',
#  'Big Data',
#  'Cloud Computing',
#  'Food Processing',
#  'Trading Platform',
#  'Consumer Goods',
#  'Wellness',
#  'Fashion',
#  'Consulting',
#  'Biotechnology',
#  'Communities',
#  'Consumer',
#  'Consumer Applications',
#  'Mobile',
#  'Advertising',
#  'Marketplace',
#  'Aerospace',
#  'Home Decor',
#  'Energy',
#  'Digital Marketing',
#  'Creative Agency',
#  'Consumer Lending',
#  'Health Diagnostics',
#  'Banking',
#  'Embedded Systems',
#  'Beauty',
#  'AgTech',
#  'Credit Cards',
#  'Software',
#  'Manufacturing',
#  'Hospital',
#  'Events',
#  '3D Printing',
#  'Digital Entertainment',
#  'Funding Platform',
#  'Classifieds',
#  'Enterprise Resource Planning (ERP)',
#  'Audio',
#  'Government',
#  'Digital Media',
#  'Business Intelligence',
#  'Children',
#  'Rental',
#  'Travel',
#  'Wealth Management',
#  'Veterinary',
#  'Tourism',
#  'Consumer Electronics',
#  'Analytics',
#  'Facilities Support Services',
#  'Medical',
#  'Music Streaming',
#  'Retail',
#  'Business Development',
#  'Human Resources',
#  'Customer Service',
#  'Training',
#  'Dietary Supplements',
#  'Collaboration',
#  'Nanotechnology',
#  'File Sharing',
#  'Crowdfunding',
#  'Catering',
#  'Computer',
#  'Android',
#  'Delivery',
#  'Environmental Consulting',
#  'Commercial Real Estate',
#  'Delivery Service',
#  'Basketball',
#  'Fraud Detection',
#  'Cryptocurrency',
#  'Wedding',
#  'Crowdsourcing',
#  'Farming',
#  'Business Travel',
#  'Career Planning',
#  'Medical Device',
#  'Alternative Medicine',
#  'Dental',
#  'CleanTech',
#  'Marketing',
#  'Commercial',
#  'Continuing Education',
#  'Smart Cities',
#  'Social Media',
#  'Biopharma',
#  'Child Care',
#  'Health Insurance',
#  'Gaming',
#  'Search Engine',
#  'Battery',
#  'Cosmetics',
#  'eSports',
#  'Reading Apps',
#  'Electric Vehicle',
#  'Packaging Services',
#  'Last Mile Transportation',
#  'Cooking',
#  'FinTech',
#  'Online Games',
#  'Online Portals',
#  'Music',
#  'News',
#  'Industrial',
#  'Dating',
#  'Fantasy Sports',
#  'Eyewear']

# %%
data_2018['Industry'] = data_2018['Industry'].replace('', np.nan)

# %%
def Industry_redistribution2018(Industry):
    if re.search(r'finance|credit|financial services|Funding Platform|accounting|insurance|blockchain|trading platform|crowdfunding|consumer lending|banking|wealth management|credit cards|fintech|fraud detection|cryptocurrency', Industry, re.IGNORECASE):
        return 'Finance'
    elif re.search(r'transport|automotive|air transport|logistics|autonomous vehicles|transportation|delivery|aerospace|electric vehicle|delivery service|last mile transportation', Industry, re.IGNORECASE):
        return 'Transport'
    elif re.search(r'technology|Enterprise Resource Planning (ERP)|it|File Sharing|Crowdsourcing|Battery|Computer|Android|Information Services|Enterprise Resource Planning (ERP)|artificial intelligence|cloud|internet|software|big data|iot|nanotechnology|embedded systems|smart cities|search engine|mobile|apps|cloud computing|saas|information technology|biotechnology|facilities support services|communities|hospitality|digital marketing|edtech|media and entertainment|internet of things|3d printing', Industry, re.IGNORECASE):
        return 'Technology'
    elif re.search(r'health|medical|hospital|biotechnology|biopharma|Child Care|health diagnostics|health insurance|alternative medicine|dental|medical device|veterinary|health care', Industry, re.IGNORECASE):
        return 'Healthcare'
    elif re.search(r'e-commerce|marketplace|retail|online portals|e-commerce platforms', Industry, re.IGNORECASE):
        return 'E-Commerce'
    elif re.search(r'education|e-learning|edtech|continuing education|children|career planning', Industry, re.IGNORECASE):
        return 'Education'
    elif re.search(r'entertainment|sports|fitness|Basketball|wellness|media|digital media|digital entertainment|gaming|online games|fantasy sports|music|music streaming|esports|audio|broadcasting|news|social media', Industry, re.IGNORECASE):
        return 'Entertainment'
    elif re.search(r'|digital media|marketing|brand marketing|Classifieds|digital marketing|advertising|market research', Industry, re.IGNORECASE):
        return 'Marketing'
    elif re.search(r'consumer|consumer goods|consumer applications|consumer electronics|fashion|cosmetics|shoes||wellness|fitness|dietary supplements|home decor|catering|cooking|hospitality|tourism|travel|rental|dating|events|wedding|cosmetics|eyewear|shopping|restaurants|food and beverage|food delivery|food processing|organic food|snack food|tea|food|beverage', Industry, re.IGNORECASE):
        return 'Consumer Services'
    elif re.search(r'industrial|manufacturing|industrial automation|facilities support services|cleantech|clean energy|renewable energy|packaging services|energy|3d printing|clean energy', Industry, re.IGNORECASE):
        return 'Industrial'
    elif re.search(r'agriculture|farming|agtech|farmers market|agriculture', Industry, re.IGNORECASE):
        return 'Agriculture'
    elif re.search(r'human resources|hr|training|customer service', Industry, re.IGNORECASE):
        return 'Human Resources'
    elif re.search(r'consulting|beauty|customer service|Cosmetics|Commercial|B2B|Collaboration|environmental consulting|business development|commercial real estate|business intelligence|outsourcing|analytics|business services|creative agency', Industry, re.IGNORECASE):
        return 'Business Services'
    elif re.search(r'legaltech|legal', Sector, re.IGNORECASE): # type: ignore
        return 'Justince'

    else:
        return Industry

# List of categories
categories = data_2018['Industry']
# Categorize each item in the list
categorized_items = {category: Industry_redistribution2018(category) for category in categories}

# Print categorized items
for item, category in categorized_items.items():
    print(f"{item}: {category}")
# Out:
# Brand Marketing: Marketing
# Agriculture: Marketing
# Credit: Finance
# Financial Services: Finance
# E-Commerce Platforms: E-Commerce
# Cloud Infrastructure: Technology
# Internet: Technology
# Market Research: Marketing
# Information Services: Technology
# Mobile Payments: Technology
# B2B: Marketing
# Apps: Technology
# Food Delivery: Transport
# Industrial Automation: Marketing
# Automotive: Transport
# Finance: Finance
# Accounting: Finance
# Artificial Intelligence: Technology
# Internet of Things: Technology
# Air Transportation: Transport
# Food and Beverage: Marketing
# Autonomous Vehicles: Transport
# Enterprise Software: Technology
# Logistics: Transport
# Insurance: Finance
# Information Technology: Technology
# Blockchain: Finance
# Education: Education
# E-Commerce: E-Commerce
# Renewable Energy: Marketing
# E-Learning: Education
# Clean Energy: Marketing
# Transportation: Transport
# Fitness: Technology
# Hospitality: Technology
# Media and Entertainment: Technology
# Broadcasting: Entertainment
# EdTech: Technology
# Health Care: Healthcare
# —: Marketing
# Sports: Entertainment
# Big Data: Technology
# Cloud Computing: Technology
# Food Processing: Marketing
# Trading Platform: Finance
# Consumer Goods: Marketing
# Wellness: Entertainment
# Fashion: Marketing
# Consulting: Marketing
# Biotechnology: Technology
# Communities: Technology
# Consumer: Marketing
# Consumer Applications: Marketing
# Mobile: Technology
# Advertising: Marketing
# Marketplace: E-Commerce
# Aerospace: Transport
# Home Decor: Marketing
# Energy: Marketing
# Digital Marketing: Technology
# Creative Agency: Marketing
# Consumer Lending: Finance
# Health Diagnostics: Healthcare
# Banking: Finance
# Embedded Systems: Technology
# Beauty: Marketing
# AgTech: Marketing
# Credit Cards: Finance
# Software: Technology
# Manufacturing: Marketing
# Hospital: Technology
# Events: Marketing
# 3D Printing: Technology
# Digital Entertainment: Technology
# Funding Platform: Finance
# Classifieds: Marketing
# Enterprise Resource Planning (ERP): Marketing
# Audio: Entertainment
# Government: Marketing
# Digital Media: Technology
# Business Intelligence: Marketing
# Children: Education
# Rental: Marketing
# Travel: Marketing
# Wealth Management: Finance
# Veterinary: Healthcare
# Tourism: Marketing
# Consumer Electronics: Marketing
# Analytics: Marketing
# Facilities Support Services: Technology
# Medical: Healthcare
# Music Streaming: Entertainment
# Retail: E-Commerce
# Business Development: Marketing
# Human Resources: Marketing
# Customer Service: Marketing
# Training: Marketing
# Dietary Supplements: Marketing
# Collaboration: Marketing
# Nanotechnology: Technology
# File Sharing: Technology
# Crowdfunding: Finance
# Catering: Marketing
# Computer: Technology
# Android: Technology
# Delivery: Transport
# Environmental Consulting: Marketing
# Commercial Real Estate: Marketing
# Delivery Service: Transport
# Basketball: Entertainment
# Fraud Detection: Finance
# Cryptocurrency: Finance
# Wedding: Marketing
# Crowdsourcing: Technology
# Farming: Marketing
# Business Travel: Marketing
# Career Planning: Education
# Medical Device: Healthcare
# Alternative Medicine: Healthcare
# Dental: Healthcare
# CleanTech: Marketing
# Marketing: Marketing
# Commercial: Marketing
# Continuing Education: Education
# Smart Cities: Technology
# Social Media: Entertainment
# Biopharma: Healthcare
# Child Care: Healthcare
# Health Insurance: Finance
# Gaming: Entertainment
# Search Engine: Technology
# Battery: Technology
# Cosmetics: Marketing
# eSports: Entertainment
# Reading Apps: Technology
# Electric Vehicle: Transport
# Packaging Services: Marketing
# Last Mile Transportation: Transport
# Cooking: Marketing
# FinTech: Finance
# Online Games: Entertainment
# Online Portals: E-Commerce
# Music: Entertainment
# News: Entertainment
# Industrial: Marketing
# Dating: Marketing
# Fantasy Sports: Entertainment
# Eyewear: Marketing

# %%
# Apply the Industry_redistribution function to the 'Industry' column and update it
data_2018['Industry'] = data_2018['Industry'].apply(Industry_redistribution2018)

# %%
#replace '—' with null in data_2018['Industry']

# Replace '—' with NaN
data_2018['Industry'] = data_2018['Industry'].replace('—', np.nan)

# Replace empty strings with NaN
data_2018['Industry'] = data_2018['Industry'].replace('', np.nan)

# %% [markdown]
# the SimpleImputer with strategy='most_frequent'

# %%
imputer = SimpleImputer(strategy='most_frequent')
data_2018['Industry'] = imputer.fit_transform(data_2018[['Industry']]).ravel() # .ravel() is used to flatten the 2D array returned by fit_transform to a 1D array
imputer = SimpleImputer(strategy='most_frequent')
data_2018['Industry'] = imputer.fit_transform(data_2018[['Industry']]).ravel()

# %%
data_2018['Industry'].unique().tolist()
# Out:
# ['Marketing',
#  'Finance',
#  'E-Commerce',
#  'Technology',
#  'Transport',
#  'Education',
#  'Entertainment',
#  'Healthcare']

# %% [markdown]
# handle missing value

# %%
data_2018.isnull().sum()
# Out:
# Company Name     0
# Industry         0
# Round/Series     0
# Amount           0
# Location         0
# About Company    0
# dtype: int64

# %% [markdown]
# Missig value of 28% in column amount is a significant portion, let ` imputing with the median` which a practical approach that prevents data loss while providing a reasonable estimate.

# %%
# Statistics summary
data_2018['Amount'].describe().T
# Out:
# count          525.0
# mean      13020215.9
# std       66462609.1
# min            877.2
# 25%         730994.2
# 50%        1300000.0
# 75%        3000000.0
# max     1000000000.0
# Name: Amount, dtype: float64

# %%
amount_invested = data_2018["Amount"].values.reshape(-1,1)

imputer = SimpleImputer(strategy="median")

data_2018["Amount"] = imputer.fit_transform(amount_invested)

# %%
data_2018.isnull().sum()
# Out:
# Company Name     0
# Industry         0
# Round/Series     0
# Amount           0
# Location         0
# About Company    0
# dtype: int64

# %% [markdown]
# To make merging and analysis easier, we will add a column called `Year Funded` that contains the year each startup received funding.

# %%
data_2018.describe().T
# Out:
#         count       mean        std   min      25%       50%       75%  \
# Amount  525.0 13020215.9 66462609.1 877.2 730994.2 1300000.0 3000000.0
#
#                 max
# Amount 1000000000.0

# %% [markdown]
# track the year od fundings by creating colum with 2018 as value

# %%
data_2018['Year Funded']= 2018

# %%
data_2018.sample(15)
# Out:
#                                        Company Name    Industry  \
# 72                          BUGWORKS Research India  Technology
# 62                                  MyDentistChoice  Healthcare
# 47                                       Fitternity  Technology
# 490                                       Mate Labs  Technology
# 325                                          Toffee   Marketing
# 340                                           mfine  Healthcare
# 424                                           GuruQ  Technology
# 429                                       Loans4SME     Finance
# 26                                            Pando   Transport
# 202                                   Emflux Motors   Transport
# 406                           Traveo Soft Pvt. Ltd.  Technology
# 234                                      HealthPlix  Technology
# 98                           Next Digital Solutions  Technology
# 349  Wicked Ride Adventure Services Private Limited   Transport
# 304                                   Avail Finance     Finance
#
#                  Round/Series     Amount   Location  \
# 72                   Series A  9000000.0  Bangalore
# 62                       Seed   500000.0  Hyderabad
# 47                       Seed  2000000.0     Mumbai
# 490                      Seed   550000.0  Bangalore
# 325                      Seed  1500000.0    Gurgaon
# 340                  Series A  4200000.0  Bengaluru
# 424                      Seed   365497.1  New Delhi
# 429                      Seed  1300000.0     Mumbai
# 26                       Seed  2000000.0    Chennai
# 202                      Seed   364846.0  Bengaluru
# 406               Undisclosed    17543.9  Bangalore
# 234                  Series A  3000000.0  Bangalore
# 98                      Angel     1462.0       Kota
# 349  Venture - Series Unknown 10000000.0  Bangalore
# 304                  Series A 17200000.0  Bangalore
#
#                                          About Company  Year Funded
# 72               BUGWORKS is a drug discovery company.         2018
# 62   MyDentistChoice is a direct sales and distribu...         2018
# 47   India's largest online fitness platform that p...         2018
# 490  Mate Labs is a machine learning solutions plat...         2018
# 325  Toffee is a bite size, micro-event & contextua...         2018
# 340                    Hospital & Health Care Start up         2018
# 424  A one of its kind digital integrated platform ...         2018
# 429      Loans4SME is an alternative lending platform.         2018
# 26   A startup which digitizes logistics operations...         2018
# 202  Emflux Motors is committed to bring clean and ...         2018
# 406      AI based Business Travel & Expense management         2018
# 234                 HealthPlix is a healthtech startup         2018
# 98   Next Digital Solutions is website design & Dig...         2018
# 349                Peer-to-Peer motor vehicles sharing         2018
# 304  Avail is a mobile-first platform aiming to fin...         2018

# %% [markdown]
# Data Summary after cleaning

# %% [markdown]
# ![Data 2018 Summary Image](Images\2018DataWrangler2.png)

# %% [markdown]
#     5.3.2 2019 Data

# %% [markdown]
# ![Data 2018 Summary Image](Images\2019beforeCleaning.png)

# %% [markdown]
# 5.3.2.1 Data Inspection

# %%
data_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %%
data_2019.sample(15)
# Out:
#        Company/Brand  Founded HeadQuarter                        Sector  \
# 65      Cubical Labs   2013.0         NaN                           IoT
# 37        Observe.AI      NaN   Bangalore                            AI
# 52          TapChief   2016.0   Bangalore                           NaN
# 83           Froogal      NaN   Hyderabad  Marketing & Customer loyalty
# 59         WishADish      NaN       Delhi                   Food & tech
# 2           Eduisfun      NaN      Mumbai                        Edtech
# 74             Credr   2014.0      Mumbai                    Automobile
# 26  Toffee Insurance   2017.0     Haryana          Insurance technology
# 46        Rein Games      NaN       Noida                    Technology
# 16            Byju's   2011.0         NaN                        Edtech
# 86        GoMechanic   2016.0       Delhi       Automobile & Technology
# 76            Phable   2018.0         NaN                    Healthtech
# 18           Witblox   2014.0         NaN                        Edtech
# 70              Zebu   2015.0         NaN                 Cybersecurity
# 62            PiBeam      NaN     Chennai               Automotive tech
#
#                                          What it does  \
# 65                  Home automation solution provider
# 37                        Creates a voice AI platform
# 52  It connects individuals in need of advice in a...
# 83  A cloud based Customer Loyalty & Engagement Pl...
# 59       Provides management solution for restaurants
# 2             It aims to make learning fun via games.
# 74  A marketplace to buy and sell used bikes and s...
# 26   Provides variety of insurance plans and policies
# 46  It develops, publishes and distributes games a...
# 16                   Provides online learning classes
# 86  Find automobile repair and maintenance service...
# 76  It creates an engagement loop between doctors,...
# 18          Offers a range of robotics learning tools
# 70  Platform uses encryption technology to allow b...
# 62  It is engaged in building sustainable and affo...
#
#                                              Founders  \
# 65                            Dhruv Ratra, Swati Vyas
# 37                                            Swapnil
# 52      Shashank Murali, Binay Krishna, Arjun Krishna
# 83                Jeevan Chowdary M, Harshit Harchani
# 59                      Sawan Kumar, Bhavya Bhambhani
# 2                                       Jatin Solanki
# 74                                             Mittal
# 26                          Nishant Jain, Rohan Kumar
# 46  Vaibhav Gupta, Himanshu Devra, Pranav Chaudhar...
# 16                                    Byju Raveendran
# 86  Amit Bhasin, Kushal Karwa, Nitin Rana, Rishabh...
# 76                                        Sumit Sinha
# 18                                          Amit Modi
# 70         Team of Waterloo-based software developers
# 62                                   Visakh Sasikumar
#
#                                              Investor     Amount($)  \
# 65                                   Rockstud Capital   Undisclosed
# 37                             Scale Venture Partners   $26,000,000
# 52                                    Blume Ventures.    $1,500,000
# 83                           US-based angel investors    $1,000,000
# 59                                        Undisclosed    $6,000,000
# 2      Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 74  Omidyar Network, Eight Roads Ventures, GrowthS...    $6,000,000
# 26                                     IVM Intersurer    $5,500,000
# 46  Manipal Education and Medical Group (MEMG) fam...   $50,000,000
# 16  South Africa’s Naspers Ventures, the CPP Inves...  $540,000,000
# 86                                    Sequoia Capital    $5,000,000
# 76  LetsVenture, 91 Springboard, IKP Knowledge, An...      $220,000
# 18                              Mumbai Angels Network      $182,700
# 70                                        Undisclosed    $4,000,000
# 62                                   GAIL (India) Ltd   $50,000,000
#
#             Stage
# 65       Series B
# 37       Series A
# 52   Pre series A
# 83   Pre series A
# 59            NaN
# 2   Fresh funding
# 74            NaN
# 26       Series A
# 46   Pre series A
# 16            NaN
# 86       Series B
# 76            NaN
# 18            NaN
# 70     Seed round
# 62            NaN

# %% [markdown]
# 5.3.2.2 Data Inspection

# %% [markdown]
# Insight from above
#
# - We have 87 Unique companies
# - Most columns are string data type excpt Founded column
# - We have missing values in Founded 29(33%), Headquarter 19(21%), Sector6(6%), Founders, Stage 46(52%)
# - City with most startup in 2019 data is Bnagalore (24%), Mumbai (13%) and Delhi (11%), the missing Values is 21%
# - From amount column undisclosed is having 13%

# %% [markdown]
# To speed up the data cleaning process, let uses d=function
#
# 1. For Descriptive statistics of a variable
# 2. For Data distribution of a variable (histogram)
# 3. For Check for missing values in a variable and ploting it

# %%
# To find descriptive statistics of ou data
def descriptive_statistics(variable):
    return variable.describe()

# To plot the data distribution of out data using a histogram
def plot_data_distribution(variable):
    plt.hist(variable)
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.title('Histogram')
    plt.show()

# To check for missing values in a variable
def check_missing_values(variable):
    return variable.isnull().sum()

# To detect outliers
def detect_outliers(data, column):
    colors = sns.color_palette(['#FF9933', '#FFFFFF', '#138808'])
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers
# ploting missing values 
def plot_missing_values_heatmap(df):
    # indicating missing values
    missing_values = df.isnull()

    colors = sns.color_palette(['#FF671F', '#FFFFFF', '#046A38'])  # Saffron, White, Green(Indian color) as am working with the data related to India
    # Plotting 
    sns.heatmap(missing_values, cmap=colors)
    plt.title('Missing Values Heatmap')
    plt.xlabel('Columns')
    plt.ylabel('Rows')
    plt.show()
def check_unique_value_in_column(dataset, column):
    return dataset[column].unique().tolist()

# %% [markdown]
# 5.3.2.2 Unique values in eacah columns of data

# %%
check_unique_value_in_column(data_2019, 'Company/Brand')
# Out:
# ['Bombay Shaving',
#  'Ruangguru',
#  'Eduisfun',
#  'HomeLane',
#  'Nu Genes',
#  'FlytBase',
#  'Finly',
#  'Kratikal',
#  'Quantiphi',
#  'Lenskart',
#  'Cub McPaws',
#  'Appnomic',
#  'Kaleidofin',
#  'JobSquare',
#  'Open Secret',
#  'LivFin',
#  "Byju's",
#  'Zest Money',
#  'Witblox',
#  'Azah Personal Care Pvt. Ltd.',
#  'SalaryFits',
#  'Pristyn Care',
#  'Springboard',
#  'DROR Labs Pvt. Ltd',
#  'Medlife',
#  'Seekify',
#  'Toffee Insurance',
#  'Fireflies .ai',
#  'HungerBox',
#  'Bijak',
#  'Licious',
#  'truMe',
#  'Pumpkart',
#  'Asteria Aerospace',
#  'Rivigo',
#  'HappyEasyGo',
#  'Zetwerk',
#  'Observe.AI',
#  'Freshokartz',
#  'Lil’ Goodness and sCool meal',
#  'Trell',
#  'VMate',
#  'Bombay Shirt Company',
#  'Slintel',
#  'MyGameMate',
#  'Afinoz',
#  'Rein Games',
#  'Ecozen',
#  'Box8',
#  'Awign Enterprises',
#  'Purplle',
#  'Freightwalla',
#  'TapChief',
#  'eJOHRI',
#  'Ninjacart',
#  'Binca Games',
#  'KredX',
#  'm.Paani',
#  'Origo',
#  'WishADish',
#  'Ecom Express',
#  'Stanza Living',
#  'PiBeam',
#  'Euler Motors',
#  'Moms Co',
#  'Cubical Labs',
#  'Lawyered',
#  'Cuemath',
#  'Nivesh.com',
#  'Zebu',
#  'Smart Institute',
#  'CarDekho',
#  'Shadowfax',
#  'Credr',
#  'Sportido',
#  'Phable',
#  'Sarva',
#  'IndyFint',
#  'Zolostays',
#  'Ola',
#  'Zoomcar',
#  'Froogal',
#  'Infra.Market',
#  'Oyo',
#  'GoMechanic',
#  'Spinny',
#  'Ess Kay Fincorp']

# %%
check_unique_value_in_column(data_2019, 'Founded')
# Out:
# [nan,
#  2014.0,
#  2004.0,
#  2013.0,
#  2010.0,
#  2018.0,
#  2019.0,
#  2017.0,
#  2011.0,
#  2015.0,
#  2016.0,
#  2012.0,
#  2008.0]

# %%
check_unique_value_in_column(data_2019, 'HeadQuarter')
# Out:
# [nan,
#  'Mumbai',
#  'Chennai',
#  'Telangana',
#  'Pune',
#  'Bangalore',
#  'Noida',
#  'Delhi',
#  'Ahmedabad',
#  'Gurugram',
#  'Haryana',
#  'Chandigarh',
#  'Jaipur',
#  'New Delhi',
#  'Surat',
#  'Uttar pradesh',
#  'Hyderabad',
#  'Rajasthan']

# %%
check_unique_value_in_column(data_2019, 'Sector')
# Out:
# ['Ecommerce',
#  'Edtech',
#  'Interior design',
#  'AgriTech',
#  'Technology',
#  'SaaS',
#  'AI & Tech',
#  'E-commerce',
#  'E-commerce & AR',
#  'Fintech',
#  'HR tech',
#  'Food tech',
#  'Health',
#  'Healthcare',
#  'Safety tech',
#  'Pharmaceutical',
#  'Insurance technology',
#  'AI',
#  'Foodtech',
#  'Food',
#  'IoT',
#  'E-marketplace',
#  'Robotics & AI',
#  'Logistics',
#  'Travel',
#  'Manufacturing',
#  'Food & Nutrition',
#  'Social Media',
#  nan,
#  'E-Sports',
#  'Cosmetics',
#  'B2B',
#  'Jewellery',
#  'B2B Supply Chain',
#  'Games',
#  'Food & tech',
#  'Accomodation',
#  'Automotive tech',
#  'Legal tech',
#  'Mutual Funds',
#  'Cybersecurity',
#  'Automobile',
#  'Sports',
#  'Healthtech',
#  'Yoga & wellness',
#  'Virtual Banking',
#  'Transportation',
#  'Transport & Rentals',
#  'Marketing & Customer loyalty',
#  'Infratech',
#  'Hospitality',
#  'Automobile & Technology',
#  'Banking']

# %%
check_unique_value_in_column(data_2019, 'Founders')
# Out:
# ['Shantanu Deshpande',
#  'Adamas Belva Syah Devara, Iman Usman.',
#  'Jatin Solanki',
#  'Srikanth Iyer, Rama Harinath',
#  'Narayana Reddy Punyala',
#  'Nitin Gupta',
#  'Vivek AG, Veekshith C Rai',
#  'Pavan Kushwaha, Paratosh Bansal, Dip Jung Thapa',
#  'Renuka Ramnath',
#  'Peyush Bansal, Amit Chaudhary, Sumeet Kapahi',
#  'Abhay Bhat, Kinnar Shah',
#  'D Padmanabhan',
#  'Puneet Gupta, Sucharita Mukherjee',
#  'Ishit Jethwa',
#  'Ahana Gautam, Udit Kejriwal',
#  'Rakesh Malhotra',
#  'Byju Raveendran',
#  'Chapman, Priya Sharma, Ashish Anantharaman',
#  'Amit Modi',
#  'Mohammed, Shashwat Diesh',
#  'Renato Araujo',
#  'Harsimarbir Singh, Dr Vaibhav Kapoor, Dr Garima Sawhney',
#  'Gautam Tambay, Parul Gupta',
#  'Dhiraj Naubhar, Dheeraj Bansal',
#  'Tushar Kumar, Prashant Singh',
#  'Arihant Jain, Ajeet Kushwaha',
#  'Nishant Jain, Rohan Kumar',
#  'Sam Udotong',
#  'Sandipan Mitra, Uttam Kumar',
#  'Nukul Upadhye, Mahesh Jakhotia, Jitender Bedwal, Daya Rai, Nikhil Tripathi',
#  'Vivek Gupta, Abhay Hanjura',
#  'Babu Dayal, Pramod Uniyal, Lalit Mehta',
#  'KS Bhatia',
#  'Neel Mehta, Nihar Vartak',
#  'Deepak Garg, Gazal Kalra',
#  'Vivek Prabhakar, Boris Zha',
#  'Amit Acharya, Srinath Ramakkrushnan',
#  'Swapnil',
#  'Rajendra Lora',
#  nan,
#  'Pulkit Agrawal, Prashant Sachan, Arun Lodhi, Bimal Kartheek Rebba',
#  'Akshay Narvekar',
#  'Deepak Anchala',
#  'Parshavv Jain& Raju Kushwaha',
#  'Rachna Suneja',
#  'Vaibhav Gupta, Himanshu Devra, Pranav Chaudhary, Nishtha Gupta',
#  'Devendra Gupta, Prateek Singhal, Vivek Pandey',
#  'Amit Raj, Anshul Gupta',
#  'Annanya Sarthak, Gurpreet Singh, Praveen Sah',
#  'Manish Taneja, Rahul Dash',
#  'Sanjay Bhatia, Bharat Tanvi, Punit Java',
#  'Shashank Murali, Binay Krishna, Arjun Krishna',
#  'Jignesh Mehta, Shailen Mehta',
#  'Thirukumaran Nagarajanin, Vasudevan Chinnathambi',
#  'Rubianca Wadhwa, Sahil Wadhwa',
#  'Manish Kumar',
#  'Akanksha Hazari',
#  'Mayank Dhanuka, Sunoor Kaul',
#  'Sawan Kumar, Bhavya Bhambhani',
#  'Krishnan, Manju Dhawan, K Satyanarayana, Sanjeev Saxena',
#  'Sandeep Dalmia, Anindya Dutta',
#  'Visakh Sasikumar',
#  'Saurav Kumar',
#  'Malika Sadani',
#  'Dhruv Ratra, Swati Vyas',
#  'Ashish Bhatia, Himanshu Gupta',
#  'Manan Khurma',
#  'Anurag Garg, Sridhar Srinivasan',
#  'Team of Waterloo-based software developers',
#  'Amit Jain',
#  'Abhishek Bansal, Vaibhav Khandelwal',
#  'Mittal',
#  'Neeraj Aggarwala, Akhil Ramachandran',
#  'Sumit Sinha',
#  'Sarvesh Shashi',
#  'Paddy Padmanabhan',
#  'Akhil Sikri, Nikhil Sikri, Sneha Choudhry',
#  'Bhavish Aggarwal, Ankit Bhati',
#  'Greg Moran, David Back',
#  'Pavan Kushwaha',
#  'Jeevan Chowdary M, Harshit Harchani',
#  'Aaditya Sharda, Souvik Sengupta',
#  'Ritesh Agarwal',
#  'Amit Bhasin, Kushal Karwa, Nitin Rana, Rishabh Karwa',
#  'Niraj Singh, Ramanshu Mahaur, Ganesh Pawar, Mohit Gupta',
#  'Rajendra Setia']

# %%
check_unique_value_in_column(data_2019, 'Investor')
# Out:
# ['Sixth Sense Ventures',
#  'General Atlantic',
#  'Deepak Parekh, Amitabh Bachchan, Piyush Pandey',
#  'Evolvence India Fund (EIF), Pidilite Group, FJ Labs',
#  'Innovation in Food and Agriculture (IFA)',
#  'Undisclosed',
#  'Social Capital, AngelList India, Gemba Capital, Omphalos Ventures,\xa0\xa091springboard via Atal Innovation Mission, Niti Aayog.',
#  'Gilda VC, Art Venture, Rajeev Chitrabhanu.',
#  'Multiples Alternate Asset Management',
#  'SoftBank',
#  'Venture Catalysts',
#  'Avataar Ventures',
#  'Oikocredit',
#  'Titan Capital',
#  'Matrix Partners',
#  'German development finance institution DEG',
#  'South Africa’s Naspers Ventures, the CPP Investment Board',
#  'Goldman Sachs.',
#  'Mumbai Angels Network',
#  'Kunal Bahl, Rohit Bansal.',
#  'Brazilian VC Fund Confrapar',
#  'Sequoia India, Hummingbird Ventures, Greenoaks Capital, AngelList.',
#  'Reach Capital',
#  'Inflection Point Ventures',
#  'Wilson Global Opportunities Fund',
#  'Sequoia Capita',
#  'IVM Intersurer',
#  'Canaan Partners',
#  'Paytm, Asian VC fund NPTK, Sabre Partners, Neoplux.',
#  'Omnivore and Omidyar Network India, Sequoia Capital',
#  'Vertex Growth Fund',
#  'Rajan Kaistha',
#  'Dinesh Dua',
#  'Reliance Industries',
#  'SAIF Partners India VI Ltd, Spring Canter Investment Ltd',
#  'Korea Investment Partners (KIP), Samsung Venture Investment Corporation (SVIC), UOB Venture, 10 Fund, CVCapital, Zero2IPO Ventures, M&S Partners',
#  'Lightspeed and Greenoaks Capital, Sequoia India, Accel and Kae Capital',
#  'Scale Venture Partners',
#  'ThinkLab',
#  'Sajan Pillai, Muthu Krishnan,',
#  'Ruizheng Investment, Tej Kapoor, Krinshavataram Venkata Vinjamuri, Harsh Shah',
#  'Alibaba',
#  'Lightbox Ventures',
#  'Stellaris Ventures',
#  'Jindagi Live Angels,',
#  'Fintech innovation lab',
#  'Manipal Education and Medical Group (MEMG) family office, Titan Capital',
#  'Innovation in Food & Agriculture Fund (IFA Fund)',
#  'Trifecta Capital',
#  'Work10M, Michael and Susan Dell Foundation, Eagle10, Unitus Ventures.',
#  'Goldman Sachs',
#  'Amplo, FJ Labs, Rogue One Capital',
#  'Blume Ventures.',
#  'Rajesh Ranavat',
#  'Walmart, Flipkart',
#  'Sunil Gavaskar',
#  'Tiger Global Management',
#  'AC Ventures, Henkel',
#  'Oikocredit, Caspian SME Impact Fund IV,\xa0\xa0Triodos Investment Management',
#  'CDC Group',
#  'Alteria Capital',
#  'GAIL (India) Ltd',
#  'Blume Ventures, Emergent Ventures',
#  'Saama Capital, DSG Consumer Partners',
#  'Rockstud Capital',
#  'Pramendra Tomar, Ratish Pandey, Munish Bhatia, Sumit Aggarwal',
#  'Manta Ray Ventures Limited, Google’s Capital G, Sequoia India.',
#  'Vertex Ventures',
#  'Windrose Capital',
#  'HNI investors',
#  'Ping An Global Voyager Fund, Hillhouse Capital, Sequoia Capital',
#  'Flipkart, Eight Roads Ventures, NGP Capital, Qualcomm Ventures, Mirae Asset Naver Fund, World Bank-backed IFC',
#  'Omidyar Network, Eight Roads Ventures, GrowthStory, AngelList',
#  'Inflection Point Ventures, SucSEED Venture Partners.',
#  'LetsVenture, 91 Springboard, IKP Knowledge, Angel investors, AbInbev-Serge DeVos, Wouter Peeters.',
#  'Venture fund, Fireside Ventures.',
#  'Saravanan Adiseshan',
#  'Kia Motors, Hyundai',
#  'Zoomcar Inc',
#  'Gilda VC, Art Venture, Rajeev Chitrabhanu',
#  'US-based angel investors',
#  'Tiger Global, Nexus Venture Partners, Accel Partners, Dhruv Agarwala',
#  'MyPreferred Transformation, Avendus Finance, SoftBank',
#  'Sequoia Capital',
#  'Norwest Venture Partners, General Catalyst, Fundamentum, Accel Partners',
#  'TPG, Norwest Venture Partners, Evolvence India']

# %%
check_unique_value_in_column(data_2019, 'Amount($)')
# Out:
# ['$6,300,000',
#  '$150,000,000',
#  '$28,000,000',
#  '$30,000,000',
#  '$6,000,000',
#  'Undisclosed',
#  '$1,000,000',
#  '$20,000,000',
#  '$275,000,000',
#  '$22,000,000',
#  '$5,000,000',
#  '$140,500',
#  '$540,000,000',
#  '$15,000,000',
#  '$182,700',
#  '$12,000,000',
#  '$11,000,000',
#  '$15,500,000',
#  '$1,500,000',
#  '$5,500,000',
#  '$2,500,000',
#  '$140,000',
#  '$230,000,000',
#  '$49,400,000',
#  '$32,000,000',
#  '$26,000,000',
#  '$150,000',
#  '$400,000',
#  '$2,000,000',
#  '$100,000,000',
#  '$8,000,000',
#  '$100,000',
#  '$50,000,000',
#  '$120,000,000',
#  '$4,000,000',
#  '$6,800,000',
#  '$36,000,000',
#  '$5,700,000',
#  '$25,000,000',
#  '$600,000',
#  '$70,000,000',
#  '$60,000,000',
#  '$220,000',
#  '$2,800,000',
#  '$2,100,000',
#  '$7,000,000',
#  '$311,000,000',
#  '$4,800,000',
#  '$693,000,000',
#  '$33,000,000']

# %%
check_unique_value_in_column(data_2019, 'Stage')
# Out:
# [nan,
#  'Series C',
#  'Fresh funding',
#  'Series D',
#  'Pre series A',
#  'Series A',
#  'Series G',
#  'Series B',
#  'Post series A',
#  'Seed funding',
#  'Seed fund',
#  'Series E',
#  'Series F',
#  'Series B+',
#  'Seed round',
#  'Pre-series A']

# %% [markdown]
# Missing Values (Indentifcation, Handling)

# %% [markdown]
# Visulazing the Null value in data

# %%
plot_missing_values_heatmap(data_2019)

# %% [markdown]
# The `Green` color is showing the missing value in dataset

# %% [markdown]
#     Unique values in some column we will use in analysis

# %% [markdown]
# Company column

# %%
# No missing Values found from the Vizualization

# %% [markdown]
# Founded column

# %%
array = data_2019['Founded'].values.reshape(-1,1)
imputer = SimpleImputer(strategy='most_frequent')
data_2019['Founded'] = imputer.fit_transform(array).ravel() # .ravel() is used to flatten the 2D array returned by fit_transform to a 1D array

# %%
data_2019['Founded'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Headqurter Columns

# %%
# Missing Values was found
check_missing_values(data_2019['HeadQuarter'])
# Out:
# 19

# %% [markdown]
# Handling by replacing by imputing most frequency

# %%
imputer = SimpleImputer(strategy='most_frequent')
data_2019['HeadQuarter'] = imputer.fit_transform(data_2019[['HeadQuarter']]).ravel()

# %%
check_missing_values(data_2019['HeadQuarter'])
# Out:
# 0

# %% [markdown]
# Sector Column

# %%
data_2019["Sector"].unique().tolist()
# Out:
# ['Ecommerce',
#  'Edtech',
#  'Interior design',
#  'AgriTech',
#  'Technology',
#  'SaaS',
#  'AI & Tech',
#  'E-commerce',
#  'E-commerce & AR',
#  'Fintech',
#  'HR tech',
#  'Food tech',
#  'Health',
#  'Healthcare',
#  'Safety tech',
#  'Pharmaceutical',
#  'Insurance technology',
#  'AI',
#  'Foodtech',
#  'Food',
#  'IoT',
#  'E-marketplace',
#  'Robotics & AI',
#  'Logistics',
#  'Travel',
#  'Manufacturing',
#  'Food & Nutrition',
#  'Social Media',
#  nan,
#  'E-Sports',
#  'Cosmetics',
#  'B2B',
#  'Jewellery',
#  'B2B Supply Chain',
#  'Games',
#  'Food & tech',
#  'Accomodation',
#  'Automotive tech',
#  'Legal tech',
#  'Mutual Funds',
#  'Cybersecurity',
#  'Automobile',
#  'Sports',
#  'Healthtech',
#  'Yoga & wellness',
#  'Virtual Banking',
#  'Transportation',
#  'Transport & Rentals',
#  'Marketing & Customer loyalty',
#  'Infratech',
#  'Hospitality',
#  'Automobile & Technology',
#  'Banking']

# %%
data_2019['Sector'].isnull().sum()
# Out:
# 5

# %% [markdown]
# imputting missing values

# %%
imputer = SimpleImputer(strategy='most_frequent')
data_2019['Sector'] = imputer.fit_transform(data_2019[['Sector']]).ravel()

# %%
check_missing_values(data_2019['Sector'])
# Out:
# 0

# %% [markdown]
# This unique values in this column indicate the diverse sectors of service among the start-ups. For better analysis, we will group similar sectors into broader categories.

# %%
def Sector_redistribution2019(Sector):
    if re.search(r'Mutual Funds|finance|credit|financial services|Funding Platform|accounting|insurance|blockchain|trading platform|crowdfunding|consumer lending|banking|wealth management|credit cards|fintech|fraud detection|cryptocurrency', Sector, re.IGNORECASE):
        return 'Finance'
    elif re.search(r'transport|Travel|automotive|air transport|logistics|autonomous vehicles|transportation|delivery|aerospace|electric vehicle|delivery service|last mile transportation', Sector, re.IGNORECASE):
        return 'Transport'
    elif re.search(r'Safety tech|Infratech|technology|AI|AI & Tech|Robotics & AI|it|File Sharing|Crowdsourcing|Battery|Computer|Android|Information Services|Enterprise Resource Planning (ERP)|artificial intelligence|cloud|internet|software|big data|iot|nanotechnology|embedded systems|smart cities|search engine|mobile|apps|cloud computing|saas|information technology|biotechnology|internet of things|3d printing', Sector, re.IGNORECASE):
        return 'Technology'
    elif re.search(r'Pharmaceutical|health|medical|hospital|biotechnology|biopharma|Child Care|health diagnostics|health insurance|alternative medicine|dental|medical device|veterinary|health care', Sector, re.IGNORECASE):
        return 'Healthcare'
    elif re.search(r'Ecommerce|e-commerce|marketplace|retail|online portals|e-commerce platforms', Sector, re.IGNORECASE):
        return 'E-Commerce'
    elif re.search(r'education|e-learning|Edtech|edtech|continuing education|children|career planning', Sector, re.IGNORECASE):
        return 'Education'
    elif re.search(r'entertainment|Games|sports|fitness|Basketball|wellness|media|digital media|digital entertainment|gaming|online games|fantasy sports|music|music streaming|esports|audio|broadcasting|news|social media', Sector, re.IGNORECASE):
        return 'Entertainment'
    elif re.search(r'Marketing|marketing|brand marketing|Classifieds|digital marketing|advertising|market research', Sector, re.IGNORECASE):
        return 'Marketing'
    elif re.search(r'consumer|consumer goods|consumer applications|consumer electronics|fashion|cosmetics|shoes|beauty|wellness|fitness|dietary supplements|home decor|Jewellery|catering|cooking|hospitality|tourism|rental|dating|events|wedding|cosmetics|eyewear|shopping|restaurants|food and beverage|food delivery|food processing|organic food|snack food|tea|food|beverage', Sector, re.IGNORECASE):
        return 'Consumer Services'
    elif re.search(r'industrial|manufacturing|industrial automation|facilities support services|cleantech|clean energy|renewable energy|packaging services|energy|3d printing|clean energy', Sector, re.IGNORECASE):
        return 'Industrial'
    elif re.search(r'agriculture|farming|agtech|farmers market|agriculture', Sector, re.IGNORECASE):
        return 'Agriculture'
    elif re.search(r'human resources|Accomodation|hr|training|customer service', Sector, re.IGNORECASE):
        return 'Human Resources'
    elif re.search(r'consulting|customer service|Interior design|Commercial|B2B|Collaboration|environmental consulting|business development|commercial real estate|business intelligence|outsourcing|analytics|business services|creative agency', Sector, re.IGNORECASE):
        return 'Business Services'
    elif re.search(r'Legal tech|legaltech|legal', Sector, re.IGNORECASE):
        return 'Justince'

    else:
        return Sector

# List of categories
categories = data_2019['Sector'].astype(str)
# Categorize each item in the list
categorized_sector = {category: Sector_redistribution2019(category) for category in categories}

# Print categorized items
for item, category in categorized_sector.items():
    print(f"{item}: {category}")
# Out:
# Ecommerce: E-Commerce
# Edtech: Education
# Interior design: Business Services
# AgriTech: Technology
# Technology: Technology
# SaaS: Technology
# AI & Tech: Technology
# E-commerce: E-Commerce
# E-commerce & AR: E-Commerce
# Fintech: Finance
# HR tech: Human Resources
# Food tech: Consumer Services
# Health: Healthcare
# Healthcare: Healthcare
# Safety tech: Technology
# Pharmaceutical: Healthcare
# Insurance technology: Finance
# AI: Technology
# Foodtech: Consumer Services
# Food: Consumer Services
# IoT: Technology
# E-marketplace: E-Commerce
# Robotics & AI: Technology
# Logistics: Transport
# Travel: Transport
# Manufacturing: Industrial
# Food & Nutrition: Technology
# Social Media: Entertainment
# E-Sports: Entertainment
# Cosmetics: Consumer Services
# B2B: Business Services
# Jewellery: Consumer Services
# B2B Supply Chain: Technology
# Games: Entertainment
# Food & tech: Consumer Services
# Accomodation: Human Resources
# Automotive tech: Transport
# Legal tech: Justince
# Mutual Funds: Finance
# Cybersecurity: Technology
# Automobile: Technology
# Sports: Entertainment
# Healthtech: Healthcare
# Yoga & wellness: Entertainment
# Virtual Banking: Finance
# Transportation: Transport
# Transport & Rentals: Transport
# Marketing & Customer loyalty: Marketing
# Infratech: Technology
# Hospitality: Technology
# Automobile & Technology: Technology
# Banking: Finance

# %%
# Apply the Industry_redistribution function to the 'Industry' column and update it
data_2019['Sector'] = data_2019['Sector'].apply(Sector_redistribution2019)

# %%
data_2019["Sector"].unique().tolist()
# Out:
# ['E-Commerce',
#  'Education',
#  'Business Services',
#  'Technology',
#  'Finance',
#  'Human Resources',
#  'Consumer Services',
#  'Healthcare',
#  'Transport',
#  'Industrial',
#  'Entertainment',
#  'Justince',
#  'Marketing']

# %%
data_2019.sample(15)
# Out:
#            Company/Brand  Founded HeadQuarter             Sector  \
# 25               Seekify   2019.0       Delhi         Technology
# 42  Bombay Shirt Company   2012.0      Mumbai         E-Commerce
# 51          Freightwalla   2017.0      Mumbai  Business Services
# 22           Springboard   2013.0   Bangalore          Education
# 29                 Bijak   2019.0   Bangalore         Technology
# 15                LivFin   2017.0       Delhi            Finance
# 64               Moms Co   2015.0   New Delhi         E-Commerce
# 27         Fireflies .ai   2015.0   Bangalore         Technology
# 9               Lenskart   2010.0       Delhi         E-Commerce
# 26      Toffee Insurance   2017.0     Haryana            Finance
# 55           Binca Games   2014.0      Mumbai      Entertainment
# 85                   Oyo   2013.0    Gurugram         Technology
# 44            MyGameMate   2015.0   Bangalore      Entertainment
# 12            Kaleidofin   2018.0     Chennai            Finance
# 72              CarDekho   2008.0      Jaipur         Technology
#
#                                          What it does  \
# 25       Customer Experience (CX) Automation platform
# 42                          Online custom shirt brand
# 51  Provides digital platform for businesses to pl...
# 22  Offers online courses and extensive mentor-bas...
# 29         B2B platform for agricultural commodities.
# 15  Grants small business loans, supply chain fina...
# 64  It is into mother and baby care-focused consum...
# 27  Developer of an artificial intelligence-powere...
# 9                             It is a eyewear company
# 26   Provides variety of insurance plans and policies
# 55  It offers games that are available across Indi...
# 85                Provides rooms for comfortable stay
# 44  eSports platform where players can access vari...
# 12  Platform that provides complete financial solu...
# 72       Enables people to buy and sell new/old cars.
#
#                                              Founders  \
# 25                       Arihant Jain, Ajeet Kushwaha
# 42                                    Akshay Narvekar
# 51            Sanjay Bhatia, Bharat Tanvi, Punit Java
# 22                         Gautam Tambay, Parul Gupta
# 29  Nukul Upadhye, Mahesh Jakhotia, Jitender Bedwa...
# 15                                    Rakesh Malhotra
# 64                                      Malika Sadani
# 27                                        Sam Udotong
# 9        Peyush Bansal, Amit Chaudhary, Sumeet Kapahi
# 26                          Nishant Jain, Rohan Kumar
# 55                      Rubianca Wadhwa, Sahil Wadhwa
# 85                                     Ritesh Agarwal
# 44                       Parshavv Jain& Raju Kushwaha
# 12                  Puneet Gupta, Sucharita Mukherjee
# 72                                          Amit Jain
#
#                                              Investor     Amount($)  \
# 25                                     Sequoia Capita    $1,500,000
# 42                                  Lightbox Ventures    $8,000,000
# 51                  Amplo, FJ Labs, Rogue One Capital    $4,000,000
# 22                                      Reach Capital   $11,000,000
# 29  Omnivore and Omidyar Network India, Sequoia Ca...    $2,500,000
# 15         German development finance institution DEG    $5,000,000
# 64               Saama Capital, DSG Consumer Partners    $5,000,000
# 27                                    Canaan Partners    $5,000,000
# 9                                            SoftBank  $275,000,000
# 26                                     IVM Intersurer    $5,500,000
# 55                                     Sunil Gavaskar   Undisclosed
# 85  MyPreferred Transformation, Avendus Finance, S...  $693,000,000
# 44                               Jindagi Live Angels,      $100,000
# 12                                         Oikocredit    $5,000,000
# 72  Ping An Global Voyager Fund, Hillhouse Capital...   $70,000,000
#
#             Stage
# 25   Seed funding
# 42            NaN
# 51       Series A
# 22  Post series A
# 29      Seed fund
# 15            NaN
# 64       Series B
# 27            NaN
# 9        Series G
# 26       Series A
# 55            NaN
# 85            NaN
# 44            NaN
# 12       Series A
# 72       Series D

# %% [markdown]
# Investor Column

# %%
data_2019["Investor"].unique().tolist()
# Out:
# ['Sixth Sense Ventures',
#  'General Atlantic',
#  'Deepak Parekh, Amitabh Bachchan, Piyush Pandey',
#  'Evolvence India Fund (EIF), Pidilite Group, FJ Labs',
#  'Innovation in Food and Agriculture (IFA)',
#  'Undisclosed',
#  'Social Capital, AngelList India, Gemba Capital, Omphalos Ventures,\xa0\xa091springboard via Atal Innovation Mission, Niti Aayog.',
#  'Gilda VC, Art Venture, Rajeev Chitrabhanu.',
#  'Multiples Alternate Asset Management',
#  'SoftBank',
#  'Venture Catalysts',
#  'Avataar Ventures',
#  'Oikocredit',
#  'Titan Capital',
#  'Matrix Partners',
#  'German development finance institution DEG',
#  'South Africa’s Naspers Ventures, the CPP Investment Board',
#  'Goldman Sachs.',
#  'Mumbai Angels Network',
#  'Kunal Bahl, Rohit Bansal.',
#  'Brazilian VC Fund Confrapar',
#  'Sequoia India, Hummingbird Ventures, Greenoaks Capital, AngelList.',
#  'Reach Capital',
#  'Inflection Point Ventures',
#  'Wilson Global Opportunities Fund',
#  'Sequoia Capita',
#  'IVM Intersurer',
#  'Canaan Partners',
#  'Paytm, Asian VC fund NPTK, Sabre Partners, Neoplux.',
#  'Omnivore and Omidyar Network India, Sequoia Capital',
#  'Vertex Growth Fund',
#  'Rajan Kaistha',
#  'Dinesh Dua',
#  'Reliance Industries',
#  'SAIF Partners India VI Ltd, Spring Canter Investment Ltd',
#  'Korea Investment Partners (KIP), Samsung Venture Investment Corporation (SVIC), UOB Venture, 10 Fund, CVCapital, Zero2IPO Ventures, M&S Partners',
#  'Lightspeed and Greenoaks Capital, Sequoia India, Accel and Kae Capital',
#  'Scale Venture Partners',
#  'ThinkLab',
#  'Sajan Pillai, Muthu Krishnan,',
#  'Ruizheng Investment, Tej Kapoor, Krinshavataram Venkata Vinjamuri, Harsh Shah',
#  'Alibaba',
#  'Lightbox Ventures',
#  'Stellaris Ventures',
#  'Jindagi Live Angels,',
#  'Fintech innovation lab',
#  'Manipal Education and Medical Group (MEMG) family office, Titan Capital',
#  'Innovation in Food & Agriculture Fund (IFA Fund)',
#  'Trifecta Capital',
#  'Work10M, Michael and Susan Dell Foundation, Eagle10, Unitus Ventures.',
#  'Goldman Sachs',
#  'Amplo, FJ Labs, Rogue One Capital',
#  'Blume Ventures.',
#  'Rajesh Ranavat',
#  'Walmart, Flipkart',
#  'Sunil Gavaskar',
#  'Tiger Global Management',
#  'AC Ventures, Henkel',
#  'Oikocredit, Caspian SME Impact Fund IV,\xa0\xa0Triodos Investment Management',
#  'CDC Group',
#  'Alteria Capital',
#  'GAIL (India) Ltd',
#  'Blume Ventures, Emergent Ventures',
#  'Saama Capital, DSG Consumer Partners',
#  'Rockstud Capital',
#  'Pramendra Tomar, Ratish Pandey, Munish Bhatia, Sumit Aggarwal',
#  'Manta Ray Ventures Limited, Google’s Capital G, Sequoia India.',
#  'Vertex Ventures',
#  'Windrose Capital',
#  'HNI investors',
#  'Ping An Global Voyager Fund, Hillhouse Capital, Sequoia Capital',
#  'Flipkart, Eight Roads Ventures, NGP Capital, Qualcomm Ventures, Mirae Asset Naver Fund, World Bank-backed IFC',
#  'Omidyar Network, Eight Roads Ventures, GrowthStory, AngelList',
#  'Inflection Point Ventures, SucSEED Venture Partners.',
#  'LetsVenture, 91 Springboard, IKP Knowledge, Angel investors, AbInbev-Serge DeVos, Wouter Peeters.',
#  'Venture fund, Fireside Ventures.',
#  'Saravanan Adiseshan',
#  'Kia Motors, Hyundai',
#  'Zoomcar Inc',
#  'Gilda VC, Art Venture, Rajeev Chitrabhanu',
#  'US-based angel investors',
#  'Tiger Global, Nexus Venture Partners, Accel Partners, Dhruv Agarwala',
#  'MyPreferred Transformation, Avendus Finance, SoftBank',
#  'Sequoia Capital',
#  'Norwest Venture Partners, General Catalyst, Fundamentum, Accel Partners',
#  'TPG, Norwest Venture Partners, Evolvence India']

# %%
data_2019["Investor"].dtype
# Out:
# dtype('O')

# %% [markdown]
# Amount column

# %% [markdown]
# Exploring unique value to understand what i need to clean

# %%
data_2019['Amount($)'].unique().tolist()
# Out:
# ['$6,300,000',
#  '$150,000,000',
#  '$28,000,000',
#  '$30,000,000',
#  '$6,000,000',
#  'Undisclosed',
#  '$1,000,000',
#  '$20,000,000',
#  '$275,000,000',
#  '$22,000,000',
#  '$5,000,000',
#  '$140,500',
#  '$540,000,000',
#  '$15,000,000',
#  '$182,700',
#  '$12,000,000',
#  '$11,000,000',
#  '$15,500,000',
#  '$1,500,000',
#  '$5,500,000',
#  '$2,500,000',
#  '$140,000',
#  '$230,000,000',
#  '$49,400,000',
#  '$32,000,000',
#  '$26,000,000',
#  '$150,000',
#  '$400,000',
#  '$2,000,000',
#  '$100,000,000',
#  '$8,000,000',
#  '$100,000',
#  '$50,000,000',
#  '$120,000,000',
#  '$4,000,000',
#  '$6,800,000',
#  '$36,000,000',
#  '$5,700,000',
#  '$25,000,000',
#  '$600,000',
#  '$70,000,000',
#  '$60,000,000',
#  '$220,000',
#  '$2,800,000',
#  '$2,100,000',
#  '$7,000,000',
#  '$311,000,000',
#  '$4,800,000',
#  '$693,000,000',
#  '$33,000,000']

# %% [markdown]
# From the summary wher saw that 13% is undisclosed

# %%
data_2019['Amount($)'].describe()
# Out:
# count              89
# unique             50
# top       Undisclosed
# freq               12
# Name: Amount($), dtype: object

# %% [markdown]
# remove $ in amount and converst dtype to numeric

# %%
data_2019['Amount($)'] = data_2019['Amount($)'].str.replace('$','').replace(',', '', regex=True)
data_2019['Amount($)'] = pd.to_numeric(data_2019['Amount($)'], errors='coerce')

# %%
data_2019['Amount($)'] = data_2019['Amount($)'].replace('Undisclosed', np.nan)

# %% [markdown]
# Handle missing values

# %%
# handle missing value by imputting median strategy
imputer = SimpleImputer(strategy ='median') 
data_2019['Amount($)'] = imputer.fit_transform(data_2019[['Amount($)']])

# %%
check_missing_values(data_2019['Amount($)'])
# Out:
# 0

# %% [markdown]
# detecting and handling the Outlier

# %% [markdown]
# handhle Ourtliers

# %%
# Box Plot to visualize outliers

plt.figure(figsize=(8, 6))
sns.boxplot(x=data_2019['Amount($)'], color='#FF9933')
plt.title('Box Plot - Amount($)')
plt.xlabel('Amount($)')
plt.show()

# %%
detect_outliers(data_2019, 'Amount($)')
# Out:
#         Company/Brand  Founded HeadQuarter             Sector  \
# 1           Ruangguru   2014.0      Mumbai          Education
# 9            Lenskart   2010.0       Delhi         E-Commerce
# 16             Byju's   2011.0   Bangalore          Education
# 33  Asteria Aerospace   2011.0   Bangalore         Technology
# 41              VMate   2015.0   Bangalore          Education
# 48               Box8   2011.0      Mumbai  Consumer Services
# 72           CarDekho   2008.0      Jaipur         Technology
# 73          Shadowfax   2015.0   Bangalore          Transport
# 80                Ola   2010.0   Bangalore          Transport
# 85                Oyo   2013.0    Gurugram         Technology
#
#                                          What it does  \
# 1   A learning platform that provides topic-based ...
# 9                             It is a eyewear company
# 16                   Provides online learning classes
# 33  Develops drones that are used by the military,...
# 41                             A short video platform
# 48                       Enables to order food online
# 72       Enables people to buy and sell new/old cars.
# 73                   A platform for delivery services
# 80                  It enables one to book cab online
# 85                Provides rooms for comfortable stay
#
#                                         Founders  \
# 1          Adamas Belva Syah Devara, Iman Usman.
# 9   Peyush Bansal, Amit Chaudhary, Sumeet Kapahi
# 16                               Byju Raveendran
# 33                      Neel Mehta, Nihar Vartak
# 41                                           NaN
# 48                        Amit Raj, Anshul Gupta
# 72                                     Amit Jain
# 73           Abhishek Bansal, Vaibhav Khandelwal
# 80                 Bhavish Aggarwal, Ankit Bhati
# 85                                Ritesh Agarwal
#
#                                              Investor   Amount($)     Stage
# 1                                    General Atlantic 150000000.0  Series C
# 9                                            SoftBank 275000000.0  Series G
# 16  South Africa’s Naspers Ventures, the CPP Inves... 540000000.0       NaN
# 33                                Reliance Industries 230000000.0       NaN
# 41                                            Alibaba 100000000.0       NaN
# 48                                   Trifecta Capital 120000000.0       NaN
# 72  Ping An Global Voyager Fund, Hillhouse Capital...  70000000.0  Series D
# 73  Flipkart, Eight Roads Ventures, NGP Capital, Q...  60000000.0  Series D
# 80                                Kia Motors, Hyundai 311000000.0       NaN
# 85  MyPreferred Transformation, Avendus Finance, S... 693000000.0       NaN

# %% [markdown]
# I have decise to keep the outliers as its the most amount can be received by a startup, in case a start received multiple Investments

# %% [markdown]
# Stage column

# %%
data_2019["Stage"].value_counts()
# Out:
# Stage
# Series A         10
# Pre series A      8
# Series B          8
# Series D          4
# Series C          3
# Fresh funding     1
# Series G          1
# Post series A     1
# Seed funding      1
# Seed fund         1
# Series E          1
# Series F          1
# Series B+         1
# Seed round        1
# Pre-series A      1
# Name: count, dtype: int64

# %%
# cleaning Funding round names as categorized based similarity
categorized_stage = {
    "Fresh funding" :"Seed",
    "Seed funding":"Seed",
    "Seed fund" :"Seed",
    "Pre series A": "Pre-series A",
    "Series B+" : "Series B",
    "Seed round" :"Seed"}
data_2019['Stage'] = data_2019['Stage'].replace(categorized_stage)

# %%
data_2019["Stage"].value_counts()
# Out:
# Stage
# Series A         10
# Pre-series A      9
# Series B          9
# Seed              4
# Series D          4
# Series C          3
# Series G          1
# Post series A     1
# Series E          1
# Series F          1
# Name: count, dtype: int64

# %% [markdown]
# Handle Missing Value

# %% [markdown]
# the From the Viz, whe notice the missing value

# %%
check_missing_values(data_2019['Stage'])
# Out:
# 46

# %%
imputer = SimpleImputer(strategy='most_frequent')
data_2019['Stage'] = imputer.fit_transform(data_2019[['Stage']]).ravel() # .ravel() is used to flatten the 2D array returned by fit_transform to a 1D array

# %%
check_missing_values(data_2019['Stage'])
# Out:
# 0

# %% [markdown]
# handle the missing value for the Founders columns

# %%
check_missing_values(data_2019['Founders'])
# Out:
# 3

# %%
imputer = SimpleImputer(strategy='most_frequent')
data_2019['Founders'] = imputer.fit_transform(data_2019[['Founders']]).ravel() # .ravel() is used to flatten the 2D array returned by fit_transform to a 1D array

# %%
check_missing_values(data_2019['Founders'])
# Out:
# 0

# %%
data_2019['Year Funded'] = 2019

# %% [markdown]
# Visualiza again the missing values

# %%
plot_missing_values_heatmap(data_2019)

# %% [markdown]
# No Duplication was found

# %% [markdown]
#     5.3.3 Data 2020

# %% [markdown]
# ![Data 2020 Summary Image](Images\2020beforeCleaning.png)

# %%
data_2020.sample(3)
# Out:
#              Company_Brand  Founded HeadQuarter         Sector  \
# 822            Craftsvilla      NaN      Mumbai    Marketplace
# 428  Quintype Technologies   2014.0   Bangalore           Tech
# 571                Yumlane   2016.0      Mumbai  Cloud Kitchen
#
#                                           What_it_does  \
# 822                 Online marketplace for ethnic wear
# 428  Building a suite of digital publishing solutio...
# 571  Online retailer that offers a range of on-the-...
#
#                       Founders                            Investor    Amount  \
# 822  Monica Gupta. Manoj Gupta                  Supera Investments 3900000.0
# 428               Amit Rathore  IIFL Asset Management, Raghav Bahl  325000.0
# 571               Hitesh Ahuja                      Jetty Ventures 1000000.0
#
#             Stage column10
# 822          None     None
# 428      Series A     None
# 571  Pre series A     None

# %% [markdown]
# Duplicates

# %%
data_2020= data_2020.drop_duplicates()

# %% [markdown]
# dropping column10, is 99% missing values

# %%
data_2020= data_2020.drop(['column10'], axis=1)

# %% [markdown]
# Missing values

# %%
plot_missing_values_heatmap(data_2020)

# %% [markdown]
# Founded column

# %%
data_2020['Founders'].dtype
# Out:
# dtype('O')

# %%
# Replace None (or NaN) with most_frequent

most_frequent = data_2020['Founders'].mode()[0]

# Replace None (or NaN) with the most frequent value
data_2020['Founders'] = data_2020['Founders'].replace({None: most_frequent, np.nan: most_frequent})

# %%
check_missing_values(data_2020['Founders'])
# Out:
# 0

# %% [markdown]
# headQuarter

# %%
check_unique_value_in_column(data_2020,'HeadQuarter')
# Out:
# ['Chennai',
#  'Bangalore',
#  'Pune',
#  'New Delhi',
#  'Indore',
#  'Hyderabad',
#  'Gurgaon',
#  'Belgaum',
#  'Noida',
#  'Mumbai',
#  'Andheri',
#  'Jaipur',
#  'Ahmedabad',
#  'Kolkata',
#  'Tirunelveli, Tamilnadu',
#  'Thane',
#  None,
#  'Singapore',
#  'Gurugram',
#  'Gujarat',
#  'Haryana',
#  'Kerala',
#  'Jodhpur',
#  'Jaipur, Rajastan',
#  'Delhi',
#  'Frisco, Texas, United States',
#  'California',
#  'Dhingsara, Haryana',
#  'New York, United States',
#  'Patna',
#  'San Francisco, California, United States',
#  'San Francisco, United States',
#  'San Ramon, California',
#  'Paris, Ile-de-France, France',
#  'Plano, Texas, United States',
#  'Sydney',
#  'San Francisco Bay Area, Silicon Valley, West Coast',
#  'Bangaldesh',
#  'London, England, United Kingdom',
#  'Sydney, New South Wales, Australia',
#  'Milano, Lombardia, Italy',
#  'Palmwoods, Queensland, Australia',
#  'France',
#  'San Francisco Bay Area, West Coast, Western US',
#  'Trivandrum, Kerala, India',
#  'Cochin',
#  'Samastipur, Bihar',
#  'Irvine, California, United States',
#  'Tumkur, Karnataka',
#  'Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom',
#  'Shanghai, China',
#  'Jiaxing, Zhejiang, China',
#  'Rajastan',
#  'Kochi',
#  'Ludhiana',
#  'Dehradun',
#  'San Franciscao',
#  'San Francisco',
#  'Tangerang, Jawa Barat, Indonesia',
#  'Berlin',
#  'Seattle',
#  'Riyadh',
#  'Seoul',
#  'New York',
#  'Bangkok',
#  'Kanpur',
#  'Chandigarh',
#  'Warangal',
#  'Hyderebad',
#  'Odisha',
#  'Bihar',
#  'Goa',
#  'Tamil Nadu',
#  'Uttar Pradesh',
#  'Bhopal',
#  'Banglore',
#  'Coimbatore',
#  'Bengaluru']

# %%
data_2020['HeadQuarter'].value_counts()
# Out:
# HeadQuarter
# Bangalore                                                   316
# Mumbai                                                      164
# Gurugram                                                     79
# Delhi                                                        62
# Chennai                                                      43
#                                                            ...
# Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom      1
# Shanghai, China                                               1
# Jiaxing, Zhejiang, China                                      1
# Rajastan                                                      1
# Sydney, New South Wales, Australia                            1
# Name: count, Length: 77, dtype: int64

# %%
most_frequent = data_2020['HeadQuarter'].mode()[0]
# Replace None (or NaN) with the most frequent value
data_2020['HeadQuarter'] = data_2020['HeadQuarter'].replace({None: most_frequent, np.nan: most_frequent})

# %%
check_missing_values(data_2020['HeadQuarter'])
# Out:
# 0

# %%
data_2020['HeadQuarter'] = data_2020['HeadQuarter'].map(lambda x: x.split(',')[0] if x is not None else x)

# %% [markdown]
# From this I can see the headquarter the located outside India, So group them in Outside India category

# %%
#  addresses to be mapped to "Outside India"
outside_india_addresses = [
    'San Francisco, California, United States',
    'London, England, United Kingdom',
    'San Francisco Bay Area, Silicon Valley, West Coast',
    'New York, United States',
    'San Francisco, United States',
    'Tangerang, Jawa Barat, Indonesia',
    'San Ramon, California ',
    'Frisco, Texas, United States ',
    'Paris, Ile-de-France, France',
    'Plano, Texas, United States',
    'Palmwoods, Queensland, Australia',
    'France',
    'San Ramon, California',
    'San Francisco Bay Area, West Coast, Western US',
    'Irvine, California, United States',
    'Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom',
    'Shanghai, China',
    'Jiaxing, Zhejiang, China',
    'Sydney, New South Wales, Australia',
    'California',
    'Singapore',
    'San Francisco',
    'San Franciscao',
    'Sydney',
    'Bangaldesh',
    'Frisco, Texas, United States',
    'New York',
    'Bangkok',
    'Seattle',
    'Milano, Lombardia, Italy',
    'Seoul',
    'Berlin'
]

for address in outside_india_addresses:
    data_2020.loc[data_2020['HeadQuarter'] == address, 'HeadQuarter'] = 'Outside India'

# %%
data_2020['HeadQuarter'].unique().tolist()
# Out:
# ['Chennai',
#  'Bangalore',
#  'Pune',
#  'New Delhi',
#  'Indore',
#  'Hyderabad',
#  'Gurgaon',
#  'Belgaum',
#  'Noida',
#  'Mumbai',
#  'Andheri',
#  'Jaipur',
#  'Ahmedabad',
#  'Kolkata',
#  'Tirunelveli',
#  'Thane',
#  'Outside India',
#  'Gurugram',
#  'Gujarat',
#  'Haryana',
#  'Kerala',
#  'Jodhpur',
#  'Delhi',
#  'Frisco',
#  'Dhingsara',
#  'Patna',
#  'San Ramon',
#  'Paris',
#  'Plano',
#  'San Francisco Bay Area',
#  'London',
#  'Milano',
#  'Palmwoods',
#  'Trivandrum',
#  'Cochin',
#  'Samastipur',
#  'Irvine',
#  'Tumkur',
#  'Newcastle Upon Tyne',
#  'Shanghai',
#  'Jiaxing',
#  'Rajastan',
#  'Kochi',
#  'Ludhiana',
#  'Dehradun',
#  'Tangerang',
#  'Riyadh',
#  'Kanpur',
#  'Chandigarh',
#  'Warangal',
#  'Hyderebad',
#  'Odisha',
#  'Bihar',
#  'Goa',
#  'Tamil Nadu',
#  'Uttar Pradesh',
#  'Bhopal',
#  'Banglore',
#  'Coimbatore',
#  'Bengaluru']

# %%
data_2020.isnull().sum()
# Out:
# Company_Brand      0
# Founded          213
# HeadQuarter        0
# Sector            13
# What_it_does       0
# Founders           0
# Investor          38
# Amount           253
# Stage            462
# dtype: int64

# %%
data_2020['Sector'].value_counts()
# Out:
# Sector
# Fintech                  80
# Edtech                   67
# FinTech                  51
# EdTech                   39
# E-commerce               33
#                          ..
# Jewellery                 1
# AR startup                1
# HR Tech startup           1
# Automotive Startup        1
# Automobile Technology     1
# Name: count, Length: 302, dtype: int64

# %%
data_2020['Sector'].isnull().sum()
# Out:
# 13

# %%
def clean_sector(value):
    if isinstance(value, str):
        value = value.lower()
        if value in ['none']:
            return np.nan
    return value

# Apply the custom function to the 'Amount' column
data_2020['Sector'] = data_2020['Sector'].apply(clean_sector)

# %%
most_frequent_value = data_2020['Sector'].mode()[0]
data_2020['Sector'].fillna(most_frequent_value, inplace=True)

# %%
data_2020['Sector'].isnull().sum()
# Out:
# 0

# %%
def Sectors_redistribution2020(Sector):
    if re.search(r'finance|credit|financial services|Funding Platform|accounting|insurance|blockchain|trading platform|crowdfunding|consumer lending|banking|wealth management|credit cards|fintech|fraud detection|cryptocurrency', Sector, re.IGNORECASE):
        return 'Finance'
    elif re.search(r'luxury car startup|transport|automotive|air transport|logistics|autonomous vehicles|transportation|delivery|aerospace|electric vehicle|delivery service|last mile transportation', Sector, re.IGNORECASE):
        return 'Transport'
    elif re.search(r'robotics|ai|tech platform|video platform|qsr startup|ar/vr startu|ev startup|deeptech|paas startup|proptech|scanning app|photonics startup|spacetech|video streaming platform|tech company|tech startup|networking platform|video sharing platform|aero company|telecommunication|technology|Enterprise Resource Planning (ERP)|it|File Sharing|Crowdsourcing|Battery|Computer|Android|Information Services|Enterprise Resource Planning (ERP)|artificial intelligence|cloud|internet|software|big data|iot|nanotechnology|embedded systems|smart cities|search engine|mobile|apps|cloud computing|saas|information technology|biotechnology|communities|internet of things|3d printing', Sector, re.IGNORECASE):
        return 'Technology'
    elif re.search(r'heathtech|med tech|skincare startup|health|medical|hospital|biotechnology|biopharma|Child Care|health diagnostics|health insurance|alternative medicine|dental|medical device|veterinary|health care', Sector, re.IGNORECASE):
        return 'Healthcare'
    elif re.search(r'e-commerce|marketplace|retail|online portals|e-commerce platforms', Sector, re.IGNORECASE):
        return 'E-Commerce'
    elif re.search(r'education|e-learning|edtech|continuing education|children|career planning', Sector, re.IGNORECASE):
        return 'Education'
    elif re.search(r'digital entertainment|video|renewable player|entertainment|sports|fitness|Basketball|wellness|media|digital media|digital entertainment|gaming|online games|fantasy sports|music|music streaming|esports|audio|broadcasting|news|social media', Sector, re.IGNORECASE):
        return 'Entertainment'
    elif re.search(r'digital marketing|media and entertainment|digital media|content management|marketing|brand marketing|Classifieds|digital marketing|advertising|market research', Sector, re.IGNORECASE):
        return 'Marketing'
    elif re.search(r'consumer|consumer goods|consumer applications|consumer electronics|fashion|cosmetics|shoes|beauty|wellness|fitness|dietary supplements|home decor|catering|cooking|hospitality|tourism|travel|rental|dating|events|wedding|cosmetics|eyewear|shopping|restaurants|food and beverage|food delivery|food processing|organic food|snack food|tea|food|beverage', Sector, re.IGNORECASE):
        return 'Consumer Services'
    elif re.search(r'industrial|manufacturing|industrial automation|facilities support services|cleantech|clean energy|renewable energy|packaging services|energy|3d printing|clean energy', Sector, re.IGNORECASE):
        return 'Industrial'
    elif re.search(r'agritech|agri tech|agriculture|farming|agtech|farmers market|agriculture', Sector, re.IGNORECASE):
        return 'Agriculture'
    elif re.search(r'job portal|Human Resources|human resources|work fulfillment|hr|training|customer service', Sector, re.IGNORECASE):
        return 'Human Resources'
    elif re.search(r'facilities support services||hospitality|car service|fm|real estate|co-working startu|tyre management|consulting|hygiene management|customer service|Commercial|B2B|Collaboration|environmental consulting|business development|commercial real estate|business intelligence|outsourcing|analytics|business services|creative agency', Sector, re.IGNORECASE):
        return 'Business Services'
    elif re.search(r'legaltech|legal', Sector, re.IGNORECASE):
        return 'Justince'
    else:
        return Sector

# List of categories
categories = data_2020['Sector']
categorized_items = {category: Sectors_redistribution2020(category) for category in categories}
for item, category in categorized_items.items():
    print(f"{item}: {category}")
# Out:
# agritech: Technology
# edtech: Education
# hygiene management: Business Services
# escrow: Business Services
# networking platform: Technology
# fintech: Finance
# crowdsourcing: Technology
# food & bevarages: Consumer Services
# healthtech: Healthcare
# fashion startup: Consumer Services
# food industry: Consumer Services
# food delivery: Transport
# virtual auditing startup: Technology
# e-commerce: E-Commerce
# gaming: Entertainment
# work fulfillment: Human Resources
# ai startup: Technology
# telecommunication: Technology
# logistics: Transport
# tech startup: Technology
# sports: Entertainment
# retail: Technology
# medtech: Education
# tyre management: Business Services
# cloud company: Technology
# software company: Technology
# venture capitalist: Technology
# renewable player: Entertainment
# iot startup: Technology
# saas startup: Technology
# aero company: Technology
# marketing company: Marketing
# retail startup: Technology
# co-working startup: Business Services
# finance company: Finance
# tech company: Technology
# solar monitoring company: Technology
# video sharing platform: Technology
# gaming startup: Entertainment
# video streaming platform: Technology
# consumer appliances: Consumer Services
# blockchain startup: Finance
# conversational ai platform: Technology
# real estate: Business Services
# saas platform: Technology
# ai platform: Technology
# fusion beverages: Consumer Services
# hr tech: Human Resources
# job portal: Human Resources
# hospitality: Technology
# digital media: Technology
# dairy startup: Technology
# content management: Marketing
# spacetech: Technology
# transportation: Transport
# trading platform: Finance
# ai company: Technology
# photonics startup: Technology
# entertainment: Technology
# cosmetics: Consumer Services
# scanning app: Technology
# skincare startup: Healthcare
# food and beverages: Consumer Services
# biotechnology company: Technology
# foodtech: Consumer Services
# proptech: Technology
# cleantech: Industrial
# fitness startup: Technology
# healthcare: Healthcare
# paas startup: Technology
# beverages: Consumer Services
# social media: Entertainment
# automobiles: Technology
# deeptech: Technology
# ev startup: Technology
# ar/vr startup: Technology
# recruitment startup: Technology
# qsr startup: Technology
# video platform: Technology
# fertility tech: Technology
# luxury car startup: Transport
# fm: Business Services
# food: Consumer Services
# nutrition sector: Technology
# tech platform: Technology
# video: Entertainment
# retail tech: Technology
# heathtech: Healthcare
# sles and marketing: Marketing
# legaltech: Business Services
# car service: Business Services
# bike marketplace: E-Commerce
# agri tech: Agriculture
# reatil startup: Business Services
# ar platform: Business Services
# consumer goods: Consumer Services
# content marketplace: E-Commerce
# interior design: Business Services
# rental space: Consumer Services
# soil-tech: Business Services
# ayurveda tech: Business Services
# packaging solution startup: Business Services
# sanitation solutions: Technology
# home design: Business Services
# insuretech: Business Services
# solar solution: Business Services
# jewellery startup: Business Services
# multinational conglomerate company: Business Services
# deeptech startup: Technology
# social network: Business Services
# publication: Business Services
# tech: Business Services
# fashion: Consumer Services
# finance: Finance
# venture capital: Technology
# entreprenurship: Business Services
# food devlivery: Consumer Services
# warehouse: Business Services
# online financial service: Business Services
# eyeglasses: Business Services
# battery design: Technology
# online credit management startup: Finance
# beverage: Consumer Services
# traveltech: Consumer Services
# agriculture: Agriculture
# startup laboratory: Business Services
# personal care startup: Business Services
# customer service company: Human Resources
# saas  startup: Technology
# marketing startup: Marketing
# service industry: Business Services
# ai: Technology
# jewellery: Business Services
# ar startup: Business Services
# hr tech startup: Technology
# automotive startup: Transport
# food startup: Consumer Services
# edtech startup: Technology
# car trade: Business Services
# edttech: Business Services
# manufacturing: Industrial
# automation: Business Services
# solar saas: Technology
# wl & rac protection: Business Services
# social commerce: Business Services
# home interior services: Business Services
# agritech startup: Technology
# api platform: Business Services
# deep tech: Business Services
# electricity: Technology
# automotive company: Transport
# fmcg: Business Services
# insurance tech: Finance
# video personalization: Entertainment
# biomaterial startup: Business Services
# health: Healthcare
# it: Technology
# craft beer: Business Services
# education: Education
# investment: Business Services
# linguistic spiritual: Technology
# construction: Business Services
# battery manufacturer: Technology
# nano distribution network: Business Services
# ai health: Technology
# dating app: Consumer Services
# media: Entertainment
# healthcare/edtech: Healthcare
# agritech/commerce: Technology
# mobility tech: Technology
# social e-commerce: E-Commerce
# food & logistics: Transport
# nutrition tech: Technology
# hr: Human Resources
# iot: Technology
# ar/vr: Business Services
# appliance: Business Services
# food tech: Consumer Services
# mental health: Healthcare
# ecommerce: Business Services
# saas: Technology
# automobile: Technology
# b2b marketplace: E-Commerce
# fashion tech: Consumer Services
# health & wellness: Healthcare
# cloud kitchen: Technology
# iot/automobile: Technology
# eye wear: Business Services
# digital tech: Technology
# data intelligence: Business Services
# co-living: Business Services
# food & beverages: Consumer Services
# automotive: Transport
# b2b: Business Services
# defense tech: Business Services
# marketplace: E-Commerce
# construction tech: Business Services
# nutrition: Technology
# coworking: Business Services
# micro-mobiity: Technology
# auto-tech: Business Services
# beauty: Consumer Services
# robotics: Technology
# yoga & wellness: Entertainment
# logitech: Technology
# med tech: Healthcare
# life sciences: Business Services
# retail aggregator: Technology
# deep tech ai: Technology
# biotech: Technology
# blockchain: Finance
# hrtech: Human Resources
# mobility/transport: Transport
# travel: Consumer Services
# rental: Consumer Services
# ai & debt: Technology
# saas/edtech: Technology
# transport: Transport
# co-working: Business Services
# insurtech: Business Services
# cryptocurrency: Finance
# automotive tech: Transport
# legal: Business Services
# fitness: Technology
# ev: Business Services
# supply chain, agritech: Technology
# pharma: Business Services
# insurance technology: Finance
# foodtech & logistics: Transport
# housing: Business Services
# pharmaceutical: Business Services
# data analytics: Business Services
# investment tech: Business Services
# financial services: Finance
# biopharma: Healthcare
# dairy: Technology
# beauty & wellness: Entertainment
# travel & saas: Technology
# tourism & ev: Consumer Services
# media tech: Entertainment
# location analytics: Business Services
# e store: Business Services
# data science: Business Services
# insurance: Finance
# health and fitness: Technology
# technology: Technology
# interior & decor: Business Services
# emobility: Technology
# automation tech: Business Services
# media & networking: Entertainment
# e-market: Business Services
# ai & data science: Technology
# travel tech: Consumer Services
# automotive and rentals: Transport
# e-tail: Technology
# accomodation: Business Services
# ai & media: Technology
# machine learning: Business Services
# content marktplace: Business Services
# visual media: Entertainment
# hygiene: Business Services
# vr & saas: Technology
# sales & services: Business Services
# ai & deep learning: Technology
# housing & rentals: Consumer Services
# estore: Business Services
# marketing: Marketing
# e tailor: Technology
# e-mobility: Technology
# ad-tech: Business Services
# neo-banking: Finance
# transport automation: Transport
# techonology: Business Services
# transport & rentals: Transport
# ai robotics: Technology
# preschool daycare: Business Services
# food diet: Consumer Services
# b2b agritech: Technology
# e-connect: Business Services
# tech hub: Business Services
# consultancy: Business Services
# pharmacy: Business Services
# deisgning: Business Services
# taxation: Business Services
# automobile technology: Technology

# %%
# Apply the Industry_redistribution function to the 'Industry' column and update it
data_2020['Sector'] = data_2020['Sector'].apply(Sectors_redistribution2020)
data_2020['Sector'].unique().tolist()
# Out:
# ['Technology',
#  'Education',
#  'Business Services',
#  'Finance',
#  'Consumer Services',
#  'Healthcare',
#  'Transport',
#  'E-Commerce',
#  'Entertainment',
#  'Human Resources',
#  'Marketing',
#  'Industrial',
#  'Agriculture']

# %% [markdown]
# Founded column

# %%
check_missing_values(data_2020['Founded'])
# Out:
# 213

# %%
most_frequent = data_2020['Founded'].mode()[0]
data_2020['Founded'] = data_2020['Founded'].replace({None: most_frequent, np.nan: most_frequent})

# %% [markdown]
# HeadQuarter colum

# %%
most_frequent = data_2020['HeadQuarter'].mode()[0]
data_2020['HeadQuarter'] = data_2020['HeadQuarter'].replace({None: most_frequent, np.nan: most_frequent})

# %% [markdown]
# Investor Column

# %%
check_missing_values(data_2020['Investor'])
# Out:
# 38

# %%
most_frequent = data_2020['Investor'].mode()[0]
data_2020['Investor'] = data_2020['Investor'].replace({None: most_frequent, np.nan: most_frequent})

# %% [markdown]
# Amount Column

# %%
#Statistical 
data_2020["Amount"].describe()
# Out:
# count           799.0
# mean      112699397.5
# std      2479695497.0
# min           12700.0
# 25%         1000000.0
# 50%         3000000.0
# 75%        11000000.0
# max     70000000000.0
# Name: Amount, dtype: float64

# %%
data_2020["Amount"].unique().tolist()
# Out:
# [200000.0,
#  100000.0,
#  nan,
#  400000.0,
#  340000.0,
#  600000.0,
#  45000000.0,
#  1000000.0,
#  2000000.0,
#  1200000.0,
#  660000000.0,
#  120000.0,
#  7500000.0,
#  5000000.0,
#  500000.0,
#  3000000.0,
#  10000000.0,
#  145000000.0,
#  100000000.0,
#  21000000.0,
#  4000000.0,
#  20000000.0,
#  560000.0,
#  275000.0,
#  4500000.0,
#  15000000.0,
#  390000000.0,
#  7000000.0,
#  5100000.0,
#  700000000.0,
#  2300000.0,
#  700000.0,
#  19000000.0,
#  9000000.0,
#  40000000.0,
#  750000.0,
#  1500000.0,
#  7800000.0,
#  50000000.0,
#  80000000.0,
#  30000000.0,
#  1700000.0,
#  2500000.0,
#  40000.0,
#  33000000.0,
#  35000000.0,
#  300000.0,
#  25000000.0,
#  3500000.0,
#  200000000.0,
#  6000000.0,
#  1300000.0,
#  4100000.0,
#  575000.0,
#  800000.0,
#  28000000.0,
#  18000000.0,
#  3200000.0,
#  900000.0,
#  250000.0,
#  4700000.0,
#  75000000.0,
#  8000000.0,
#  121000000.0,
#  55000000.0,
#  3300000.0,
#  11000000.0,
#  16000000.0,
#  5400000.0,
#  150000000.0,
#  4200000.0,
#  22000000.0,
#  52000000.0,
#  1100000.0,
#  118000000.0,
#  1600000.0,
#  18500000.0,
#  70000000000.0,
#  800000000.0,
#  400000000.0,
#  150000.0,
#  176000000.0,
#  60000000.0,
#  470000.0,
#  240000.0,
#  3000000000.0,
#  74000000.0,
#  62000000.0,
#  2100000.0,
#  500000000.0,
#  12500000.0,
#  2200000000.0,
#  5060000.0,
#  225000000.0,
#  24700000.0,
#  7700000.0,
#  19067328.0,
#  51000000.0,
#  115000.0,
#  54000.0,
#  20000.0,
#  803146.0,
#  238000.0,
#  10220000.0,
#  1020000.0,
#  12000000.0,
#  13400000.0,
#  170000000.0,
#  2900000.0,
#  543000.0,
#  90000000.0,
#  3400000.0,
#  23000000.0,
#  8090000.0,
#  1030000.0,
#  5040000.0,
#  360000.0,
#  1400000.0,
#  650000.0,
#  54000000.0,
#  42500000.0,
#  11370000.0,
#  325000.0,
#  410000.0,
#  450000.0,
#  682000.0,
#  4050000.0,
#  1050000.0,
#  1080000.0,
#  4300000.0,
#  6800000.0,
#  2110000.0,
#  764000.0,
#  603000.0,
#  409000.0,
#  292000.0,
#  286000.0,
#  136000.0,
#  546000.0,
#  887000.0,
#  43000.0,
#  40900.0,
#  2200000.0,
#  5660000.0,
#  350000.0,
#  110000.0,
#  122000000.0,
#  11635000.0,
#  2800000.0,
#  1065000.0,
#  669000.0,
#  16076000.0,
#  649600.0,
#  6700000.0,
#  220000.0,
#  266500.0,
#  2879000.0,
#  26500000.0,
#  351000.0,
#  46761000.0,
#  175000.0,
#  11241000.0,
#  804000.0,
#  1340000.0,
#  467000.0,
#  133000.0,
#  3823000.0,
#  934000.0,
#  293000.0,
#  198000.0,
#  927000.0,
#  971000.0,
#  3060000.0,
#  1862000.0,
#  232000.0,
#  2888000.0,
#  1328000.0,
#  15500000.0,
#  56000000.0,
#  2250000.0,
#  16753000.0,
#  3700000.0,
#  1470000.0,
#  530000.0,
#  267000.0,
#  3344000.0,
#  7200000.0,
#  2743000.0,
#  6082000.0,
#  6609000.0,
#  27700000.0,
#  5940000.0,
#  3964000.0,
#  5500000.0,
#  197000.0,
#  4327000.0,
#  459000.0,
#  3937000.0,
#  1313500.0,
#  229800.0,
#  5305000.0,
#  264000.0,
#  1750000.0,
#  5967000.0,
#  2980000.0,
#  323000.0,
#  1326000.0,
#  27000000.0,
#  5200000.0,
#  2530000.0,
#  792000.0,
#  11363000.0,
#  1715000.0,
#  329000.0,
#  5271000.0,
#  8700000.0,
#  3226000.0,
#  5900000.0,
#  44000000.0,
#  3879000.0,
#  13000000.0,
#  8800000.0,
#  9500000.0,
#  920000.0,
#  35600000.0,
#  9400000.0,
#  790000.0,
#  480000.0,
#  160000.0,
#  8200000.0,
#  4257000.0,
#  1410000.0,
#  349800.0,
#  786000.0,
#  2004000.0,
#  123000000.0,
#  248000.0,
#  24000000.0,
#  14259000.0,
#  24500000.0,
#  3800000.0,
#  18370000.0,
#  68525000.0,
#  4800000.0,
#  1834000.0,
#  23850000.0,
#  43000000.0,
#  21600000.0,
#  4598000.0,
#  13137000.0,
#  115000000.0,
#  3900000.0,
#  670000.0,
#  8500000.0,
#  3148000.0,
#  2600000.0,
#  4049500.0,
#  10500000.0,
#  6500000.0,
#  43700000.0,
#  13800000.0,
#  306900.0,
#  420000.0,
#  627300.0,
#  113000000.0,
#  32000000.0,
#  110000000.0,
#  1397000.0,
#  448500.0,
#  7975700.0,
#  330000.0,
#  5600000.0,
#  1402000.0,
#  21500000.0,
#  296000000.0,
#  4900000.0,
#  1402400.0,
#  12618300.0,
#  9900000.0,
#  982530.0,
#  70185200.0,
#  210000000.0,
#  84000000.0,
#  39000000.0,
#  2700000.0,
#  1403400.0,
#  105000000.0,
#  103000000.0,
#  281300.0,
#  12700.0,
#  25000.0,
#  97500000.0,
#  507000.0,
#  8400000.0,
#  18300000.0,
#  125000000.0,
#  181000.0,
#  280000.0,
#  14700000.0,
#  13200000.0,
#  8043000.0]

# %% [markdown]
# handle Null values

# %%
data_2020['Amount'].isnull().sum()
# Out:
# 253

# %%
#Imputing missing values in the amount column using simple imputer method
array= data_2020["Amount"].values.reshape(-1,1)
imputer=SimpleImputer(strategy="median")

data_2020["Amount"]=imputer.fit_transform(array)

# %% [markdown]
# stage column

# %%
data_2020['Stage'].isnull().sum()
# Out:
# 462

# %%
most_frequent = data_2020['Stage'].mode()[0]
data_2020['Stage'] = data_2020['Stage'].replace({None: most_frequent, np.nan: most_frequent})

# %%
data_2020['Stage'].value_counts()
# Out:
# Stage
# Series A                 558
# Seed                      79
# Seed Round                69
# Series B                  57
# Pre series A              54
# Pre-series A              53
# Series C                  50
# Series D                  22
# Debt                      18
# Pre Series A              12
# Pre-seed                  11
# Seed round                 9
# Series E                   6
# Bridge                     6
# Series F                   4
# Pre-series B               4
# Angel Round                4
# Pre seed round             4
# Pre-seed Round             2
# Pre series B               2
# Pre-Seed                   2
# Seed Funding               2
# Series B2                  2
# Pre-series C               2
# Seed funding               2
# Pre-Series B               2
# Seed Round & Series A      1
# Series C, D                1
# Mid series                 1
# Series D1                  1
# Seed Investment            1
# Pre series C               1
# Pre-series                 1
# Bridge Round               1
# Series H                   1
# Seed A                     1
# Pre- series A              1
# Series E2                  1
# Pre series A1              1
# Edge                       1
# Pre seed Round             1
# Series A-1                 1
# Name: count, dtype: int64

# %%
# categorize the stage 
data_2020.replace({"Stage": {"Seed Round" : "Seed",
                            "Pre series A": "Pre-series A",
                            "Pre Series A" : "Pre-series A" ,
                            "Seed round" :   "Seed",
                            "Pre seed round" :"Pre-seed",
                            "Series B2" :    "Series B",
                            "Pre series B" : "Pre-series B",
                            "Seed Funding" : "Seed",
                            "Pre-Series B" : "Pre-series B",
                            "Pre-Seed"  :    "Pre-seed",
                            "Seed funding" : "Seed",
                            "Pre-seed Round" :"Pre-seed",
                            "Series E2" :     "Series E",
                            "Pre series A1" : "Pre-series A",
                            "Series D1" :     "Series",
                            "Pre seed Round" :"Pre-seed",
                            "Pre series C"  : "Pre-Series C",
                            "Bridge Round" :  "Bridge",
                            "Series A-1" :    "Series",
                            "Pre- series A":  "Pre-series A",
                            "Seed Investment" :"Seed"}},inplace =True)

# %%
data_2020["Stage"].isnull().sum()
# Out:
# 0

# %% [markdown]
# track the year of funding

# %%
data_2020['Year Funded'] = 2020

# %%
plot_missing_values_heatmap(data_2020)

# %% [markdown]
#     5.3.4 Data 2021

# %%
data_2021.sample(5)
# Out:
#            Company_Brand  Founded HeadQuarter  \
# 369           YourPhysio   2020.0      Nagpur
# 377            Elucidata   2015.0   New Delhi
# 1073           Homeville   2017.0      Mumbai
# 514           Uvi Health   2020.0   Bangalore
# 599   Good Health Clinic   2021.0   Hyderabad
#
#                                  Sector  \
# 369                          HealthTech
# 377                       BioTechnology
# 1073  Information Technology & Services
# 514                          Healthcare
# 599                          HealthCare
#
#                                            What_it_does  \
# 369   YourPhysio is a healthcare company on a missio...
# 377   Elucidata Corporation uses data analytics to t...
# 1073  A technology company focused on helping people...
# 514   Digital health platform delivering personalize...
# 599                    Full Stack Digital Health Clinic
#
#                                           Founders  \
# 369         Dr Sheetal Mundhada, Ashutosh Mundhada
# 377   Abhishek Jha, Richard Kibbey, Swetabh Pathak
# 1073                             Madhusudan Sharma
# 514                                    Mehak Malik
# 599                                 Samarth Sindhi
#
#                              Investor      Amount         Stage
# 369     Better Capital, Titan Capital    $350,000      Pre-seed
# 377        Hyperplane Venture Capital  $5,000,000  Pre-series A
# 1073  9Unicorns, Varanium NexGen Fund    $7000000          None
# 514                     Titan Capital     $330000      Pre-seed
# 599                   Khosla Ventures    $5000000          None

# %%
data_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What_it_does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount         1206 non-null   object
#  8   Stage          781 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 85.1+ KB

# %% [markdown]
# - Missing values in Founded, HeadQuarter, Founders, Investor, Amount and Stage columns
# - most colummns are object
#
# Action to take is clean each column one by one

# %%
# duplicates
data_2021.duplicated().sum()
# Out:
# 19

# %%
# our duplicates
data_2021[data_2021.duplicated()]
# Out:
#           Company_Brand  Founded             HeadQuarter  \
# 107           Curefoods   2020.0               Bangalore
# 109            Bewakoof   2012.0                  Mumbai
# 111             FanPlay   2020.0          Computer Games
# 117      Advantage Club   2014.0                  Mumbai
# 119              Ruptok   2020.0               New Delhi
# 243            Trinkerr   2021.0               Bangalore
# 244               Zorro   2021.0                Gurugram
# 245       Ultraviolette   2021.0               Bangalore
# 246          NephroPlus   2009.0               Hyderabad
# 247             Unremot   2020.0               Bangalore
# 248         FanAnywhere   2021.0               Bangalore
# 249          PingoLearn   2021.0                    Pune
# 250                Spry   2021.0                  Mumbai
# 251             Enmovil   2015.0               Hyderabad
# 252       ASQI Advisors   2019.0                  Mumbai
# 253  Insurance Samadhan   2018.0               New Delhi
# 254     Evenflow Brands   2020.0                  Mumbai
# 255          MasterChow   2020.0        Food & Beverages
# 256  Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
#
#                                                 Sector  \
# 107                                   Food & Beverages
# 109                                  Apparel & Fashion
# 111                                     Computer Games
# 117                                             HRTech
# 119                                            FinTech
# 243                                    Capital Markets
# 244                                     Social network
# 245                                         Automotive
# 246                             Hospital & Health Care
# 247                  Information Technology & Services
# 248                                 Financial Services
# 249                                         E-learning
# 250                                              Music
# 251                  Information Technology & Services
# 252                                 Financial Services
# 253                                          Insurance
# 254                                     Consumer Goods
# 255                                          Hauz Khas
# 256  Primary Business is Development and Manufactur...
#
#                                           What_it_does  \
# 107  Healthy & nutritious foods and cold pressed ju...
# 109  Bewakoof is a lifestyle fashion brand that mak...
# 111  A real money game app specializing in trivia g...
# 117  Advantage Club is India's largest employee eng...
# 119  Ruptok fintech Pvt. Ltd. is an online gold loa...
# 243  Trinkerr is India's first social trading platf...
# 244               Pseudonymous social network platform
# 245  Create and Inspire the future of sustainable u...
# 246  A vision and passion of redefining healthcare ...
# 247      Unremot is a personal office for consultants!
# 248                             Celebrity NFT platform
# 249  PingoLearn offers language learning courses wi...
# 250  THE BEST ROYALTY-FREE MUSIC TO CREATE TRENDING...
# 251  Enmovil delivers a Business Intelligence Platf...
# 252  Bringing Blockchain technology intro mainstrea...
# 253  The insurance industry will help in representa...
# 254  Identify and partner with the upcoming eCommer...
# 255                A ready-to-cook Asian cuisine brand
# 256                                       Varun Khanna
#
#                                           Founders  \
# 107                                   Ankit Nagori
# 109                               Prabhkiran Singh
# 111                                         YC W21
# 117             Sourabh Deorah, Smiti Bhatt Deorah
# 119                                    Ankur Gupta
# 243                Manvendra Singh, Gaurav Agarwal
# 244  Jasveer Singh, Abhishek Asthana, Deepak Kumar
# 245            Subramaniam Narayan, Niraj Rajmohan
# 246                                 Vikram Vuppala
# 247                            Shiju Radhakrishnan
# 248                    Varun Chaudhary, Amit Kumar
# 249             Mohit Menghani, Shubham Maheshwari
# 250                Gaurav Dagaonkar, Meghna Mittal
# 251     Ravi Bulusu, Nanda Kishore, Venkat Moganty
# 252                                  Swapnil Pawar
# 253                     Deepak Bhuvenshwari Uniyal
# 254                  Utsav Agarwal, Pulkit Chhabra
# 255                  Vidur Kataria, Sidhanth Madan
# 256             Morgan Stanley Private Equity Asia
#
#                                               Investor        Amount  \
# 107                Iron Pillar, Nordstar, Binny Bansal     $13000000
# 109                                         InvestCorp      $8000000
# 111                        Pritesh Kumar, Bharat Gupta      Upsparks
# 117           Y Combinator, Broom Ventures, Kunal Shah      $1700000
# 119                                     Eclear Leasing      $1000000
# 243                                        Accel India      $6600000
# 244  Vijay Shekhar Sharma, Ritesh Agarwal, Ankiti Bose     $32000000
# 245                                    TVS Motor, Zoho    $150000000
# 246                              IIFL Asset Management     $24000000
# 247                          Inflection Point Ventures       $700000
# 248        Oasis Capital, Scorpio VC, DeltaHub Capital  $Undisclosed
# 249  Titan Capital, Haresh Chawla, AngelList Syndicate       $200000
# 250                          9Unicorns, Ashneer Grover      $1500000
# 251                                  Anicut Angel Fund      $1300000
# 252                              Founders Room Capital      $1000000
# 253                                     9Unicorns, ZNL       $725000
# 254                                               None       $500000
# 255                                       WEH Ventures       $461000
# 256                                          $22000000      Series C
#
#             Stage
# 107          None
# 109          None
# 111      $1200000
# 117          None
# 119          None
# 243      Series A
# 244          Seed
# 245      Series C
# 246      Series E
# 247          Seed
# 248          Seed
# 249          None
# 250          Seed
# 251  Pre-series A
# 252  Pre-series A
# 253  Pre-series A
# 254          None
# 255          Seed
# 256          None

# %%
# remove duplicate
data_2021 = data_2021.drop_duplicates().reset_index(drop=True)

# %%
data_2021
# Out:
#        Company_Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics   2019.0   Bangalore             AI startup
# 1             upGrad   2015.0      Mumbai                 EdTech
# 2        Lead School   2012.0      Mumbai                 EdTech
# 3            Bizongo   2015.0      Mumbai         B2B E-commerce
# 4           FypMoney   2021.0    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1185        Gigforce   2019.0    Gurugram  Staffing & Recruiting
# 1186          Vahdam   2015.0   New Delhi       Food & Beverages
# 1187    Leap Finance   2019.0   Bangalore     Financial Services
# 1188    CollegeDekho   2015.0    Gurugram                 EdTech
# 1189          WeRize   2019.0   Bangalore     Financial Services
#
#                                            What_it_does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# 2     LEAD School offers technology based school tra...
# 3     Bizongo is a business-to-business online marke...
# 4     FypMoney is Digital NEO Bank for Teenagers, em...
# ...                                                 ...
# 1185                  A gig/on-demand staffing company.
# 1186  VAHDAM is among the world’s first vertically i...
# 1187  International education loans for high potenti...
# 1188  Collegedekho.com is Student’s Partner, Friend ...
# 1189  India’s first socially distributed full stack ...
#
#                                                Founders  \
# 0                           Pramod Ghadge, Shahid Memon
# 1     Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                            Smita Deorah, Sumeet Mehta
# 3               Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                         Kapil Banwari
# ...                                                 ...
# 1185                        Chirag Mittal, Anirudh Syal
# 1186                                         Bala Sarda
# 1187                         Arnav Kumar, Vaibhav Singh
# 1188                                       Ruchir Arora
# 1189                      Vishal Chopra, Himanshu Gupta
#
#                                            Investor        Amount  \
# 0                       BEENEXT, Entrepreneur First    $1,200,000
# 1          Unilazer Ventures, IIFL Asset Management  $120,000,000
# 2                  GSV Ventures, Westbridge Capital   $30,000,000
# 3                            CDC Group, IDG Capital   $51,000,000
# 4     Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000
# ...                                             ...           ...
# 1185                                Endiya Partners      $3000000
# 1186                                       IIFL AMC     $20000000
# 1187                                   Owl Ventures     $55000000
# 1188               Winter Capital, ETS, Man Capital     $26000000
# 1189                 3one4 Capital, Kalaari Capital      $8000000
#
#              Stage
# 0     Pre-series A
# 1             None
# 2         Series D
# 3         Series C
# 4             Seed
# ...            ...
# 1185  Pre-series A
# 1186      Series D
# 1187      Series C
# 1188      Series B
# 1189      Series A
#
# [1190 rows x 9 columns]

# %% [markdown]
# Handle Missing values

# %%
plot_missing_values_heatmap(data_2021)

# %% [markdown]
# Founded column

# %%
#  'Founded' column
data_2021['Founded'].isnull().sum()
# Out:
# 1

# %%
# Imputing missing values as its only one missing values there

array = data_2021['Founded'].values.reshape(-1,1)
imputer = SimpleImputer(strategy='most_frequent')

data_2021['Founded'] = imputer.fit_transform(array)

# %%
data_2021['Founded'].isnull().sum()
# Out:
# 0

# %% [markdown]
# HeadQuater column

# %%
check_missing_values(data_2021['HeadQuarter'])
# Out:
# 1

# %%
most_frequent = data_2021['HeadQuarter'].mode()[0]
data_2021['HeadQuarter'] = data_2021['HeadQuarter'].replace({None: most_frequent, np.nan: most_frequent})

# %%
check_missing_values(data_2021['HeadQuarter'])
# Out:
# 0

# %%
data_2021['HeadQuarter'].unique().tolist()
# Out:
# ['Bangalore',
#  'Mumbai',
#  'Gurugram',
#  'New Delhi',
#  'Hyderabad',
#  'Jaipur',
#  'Ahmadabad',
#  'Chennai',
#  'Small Towns, Andhra Pradesh',
#  'Goa',
#  'Rajsamand',
#  'Ranchi',
#  'Faridabad, Haryana',
#  'Gujarat',
#  'Pune',
#  'Thane',
#  'Computer Games',
#  'Cochin',
#  'Noida',
#  'Chandigarh',
#  'Gurgaon',
#  'Vadodara',
#  'Food & Beverages',
#  'Pharmaceuticals\t#REF!',
#  'Gurugram\t#REF!',
#  'Kolkata',
#  'Ahmedabad',
#  'Mohali',
#  'Haryana',
#  'Indore',
#  'Powai',
#  'Ghaziabad',
#  'Nagpur',
#  'West Bengal',
#  'Patna',
#  'Samsitpur',
#  'Lucknow',
#  'Telangana',
#  'Silvassa',
#  'Thiruvananthapuram',
#  'Faridabad',
#  'Roorkee',
#  'Ambernath',
#  'Panchkula',
#  'Surat',
#  'Coimbatore',
#  'Andheri',
#  'Mangalore',
#  'Telugana',
#  'Bhubaneswar',
#  'Kottayam',
#  'Beijing',
#  'Panaji',
#  'Satara',
#  'Orissia',
#  'Jodhpur',
#  'New York',
#  'Santra',
#  'Mountain View, CA',
#  'Trivandrum',
#  'Jharkhand',
#  'Kanpur',
#  'Bhilwara',
#  'Guwahati',
#  'Online Media\t#REF!',
#  'Kochi',
#  'London',
#  'Information Technology & Services',
#  'The Nilgiris',
#  'Gandhinagar']

# %% [markdown]
# Founders column

# %%
check_missing_values(data_2021['Founders'])
# Out:
# 4

# %% [markdown]
# column Stage

# %%
# stage  column
data_2021['Stage'].value_counts()
# Out:
# Stage
# Seed             241
# Pre-series A     154
# Series A         125
# Series B          49
# Pre-seed          47
# Series C          44
# Debt              27
# Series D          21
# Series E          17
# Pre-series B      10
# Series F           6
# Pre-series A1      4
# Pre-series         2
# $300000            2
# Series H           2
# Series G           2
# Bridge             2
# Series A+          1
# Series F2          1
# Series B3          1
# PE                 1
# Series F1          1
# Seed+              1
# Early seed         1
# Series D1          1
# $6000000           1
# $1000000           1
# Seies A            1
# $1200000           1
# Series A2          1
# Series I           1
# Name: count, dtype: int64

# %% [markdown]
# let look up on row with amout stage

# %%
amount_values = [ '$1200000','$300000', '$6000000', '$1000000']

filtered_data = data_2021[data_2021['Stage'].isin(amount_values)]
filtered_data
# Out:
#         Company_Brand  Founded     HeadQuarter                  Sector  \
# 98            FanPlay   2020.0  Computer Games          Computer Games
# 519       Little Leap   2020.0       New Delhi                  EdTech
# 532             BHyve   2020.0          Mumbai         Human Resources
# 655      MYRE Capital   2020.0          Mumbai  Commercial Real Estate
# 658  Saarthi Pedagogy   2015.0       Ahmadabad                  EdTech
#
#                                           What_it_does  \
# 98   A real money game app specializing in trivia g...
# 519                Soft Skills that make Smart Leaders
# 532  A Future of Work Platform for diffusing Employ...
# 655                Democratising Real Estate Ownership
# 658  India's fastest growing Pedagogy company, serv...
#
#                                               Founders  \
# 98                                              YC W21
# 519  Holistic Development Programs for children in ...
# 532                                  Backed by 100x.VC
# 655            Own rent yielding commercial properties
# 658                                           Pedagogy
#
#                             Investor                           Amount  \
# 98       Pritesh Kumar, Bharat Gupta                         Upsparks
# 519                     Vishal Gupta                     ah! Ventures
# 532  Omkar Pandharkame, Ketaki Ogale   ITO Angel Network, LetsVenture
# 655                      Aryaman Vir                             None
# 658                   Sushil Agarwal  JITO Angel Network, LetsVenture
#
#         Stage
# 98   $1200000
# 519   $300000
# 532   $300000
# 655  $6000000
# 658  $1000000

# %% [markdown]
# Amount column

# %% [markdown]
# lets swap the value of this rows

# %%
# values swapping by function and Apply function to swap 'Amount($)' and 'Stage' columns
def valueSwap(data, row_index, column1, column2):
    data_modified = data.copy()
    value1 = data_modified.at[row_index, column1]
    value2 = data_modified.at[row_index, column2]
    data_modified.at[row_index, column1] = value2
    data_modified.at[row_index, column2] = value1
    return data_modified

data_2021 = valueSwap(data_2021, 98, 'Amount', 'Stage')
data_2021 = valueSwap(data_2021, 519, 'Amount', 'Stage')
data_2021 = valueSwap(data_2021, 532, 'Amount', 'Stage')
data_2021 = valueSwap(data_2021, 655, 'Amount', 'Stage')
data_2021 = valueSwap(data_2021, 658, 'Amount', 'Stage')

modified_rows = data_2021.loc[[98, 519, 532, 655, 658]]

modified_rows
# Out:
#         Company_Brand  Founded     HeadQuarter                  Sector  \
# 98            FanPlay   2020.0  Computer Games          Computer Games
# 519       Little Leap   2020.0       New Delhi                  EdTech
# 532             BHyve   2020.0          Mumbai         Human Resources
# 655      MYRE Capital   2020.0          Mumbai  Commercial Real Estate
# 658  Saarthi Pedagogy   2015.0       Ahmadabad                  EdTech
#
#                                           What_it_does  \
# 98   A real money game app specializing in trivia g...
# 519                Soft Skills that make Smart Leaders
# 532  A Future of Work Platform for diffusing Employ...
# 655                Democratising Real Estate Ownership
# 658  India's fastest growing Pedagogy company, serv...
#
#                                               Founders  \
# 98                                              YC W21
# 519  Holistic Development Programs for children in ...
# 532                                  Backed by 100x.VC
# 655            Own rent yielding commercial properties
# 658                                           Pedagogy
#
#                             Investor    Amount  \
# 98       Pritesh Kumar, Bharat Gupta  $1200000
# 519                     Vishal Gupta   $300000
# 532  Omkar Pandharkame, Ketaki Ogale   $300000
# 655                      Aryaman Vir  $6000000
# 658                   Sushil Agarwal  $1000000
#
#                                Stage
# 98                          Upsparks
# 519                     ah! Ventures
# 532   ITO Angel Network, LetsVenture
# 655                             None
# 658  JITO Angel Network, LetsVenture

# %%
# check the row with the stage that is amount
data_2021['Stage'].unique()
# Out:
# array(['Pre-series A', None, 'Series D', 'Series C', 'Seed', 'Series B',
#        'Series E', 'Pre-seed', 'Series A', 'Pre-series B', 'Debt',
#        'Upsparks', 'Bridge', 'Seed+', 'Series F2', 'Series A+',
#        'Series G', 'Series F', 'Series H', 'Series B3', 'PE', 'Series F1',
#        'Pre-series A1', 'ah! Ventures', 'ITO Angel Network, LetsVenture',
#        'Early seed', 'Series D1', 'JITO Angel Network, LetsVenture',
#        'Seies A', 'Pre-series', 'Series A2', 'Series I'], dtype=object)

# %%
# Replace values

data_2021['Stage'].replace('Series B+', 'Series B', inplace=True)
data_2021['Stage'].replace('Pre-series1', 'Pre-series', inplace=True)
data_2021['Stage'].replace('Pre-Series B', 'Series A', inplace=True)
data_2021['Stage'].replace(' Series B', 'Series B', inplace=True)

# %%
data_2021['Stage'].unique()
# Out:
# array(['Pre-series A', None, 'Series D', 'Series C', 'Seed', 'Series B',
#        'Series E', 'Pre-seed', 'Series A', 'Pre-series B', 'Debt',
#        'Upsparks', 'Bridge', 'Seed+', 'Series F2', 'Series A+',
#        'Series G', 'Series F', 'Series H', 'Series B3', 'PE', 'Series F1',
#        'Pre-series A1', 'ah! Ventures', 'ITO Angel Network, LetsVenture',
#        'Early seed', 'Series D1', 'JITO Angel Network, LetsVenture',
#        'Seies A', 'Pre-series', 'Series A2', 'Series I'], dtype=object)

# %%
def update_value(value):

    replacements = {
        r'None|Upsparks|Bridge|Unknown, Unknown|ah! Ventures|ITO Angel Network|LetsVenture|JITO Angel Network': 'Unknown', }

    for pattern, replacement in replacements.items():
        value = re.sub(pattern, replacement, str(value))

    return value

data_2021['Stage'] = data_2021['Stage'].apply(update_value)

# %%
data_2021['Stage'].unique().tolist()
# Out:
# ['Pre-series A',
#  'Unknown',
#  'Series D',
#  'Series C',
#  'Seed',
#  'Series B',
#  'Series E',
#  'Pre-seed',
#  'Series A',
#  'Pre-series B',
#  'Debt',
#  'Seed+',
#  'Series F2',
#  'Series A+',
#  'Series G',
#  'Series F',
#  'Series H',
#  'Series B3',
#  'PE',
#  'Series F1',
#  'Pre-series A1',
#  'Unknown, Unknown',
#  'Early seed',
#  'Series D1',
#  'Seies A',
#  'Pre-series',
#  'Series A2',
#  'Series I']

# %%
filtered_data
# Out:
#         Company_Brand  Founded     HeadQuarter                  Sector  \
# 98            FanPlay   2020.0  Computer Games          Computer Games
# 519       Little Leap   2020.0       New Delhi                  EdTech
# 532             BHyve   2020.0          Mumbai         Human Resources
# 655      MYRE Capital   2020.0          Mumbai  Commercial Real Estate
# 658  Saarthi Pedagogy   2015.0       Ahmadabad                  EdTech
#
#                                           What_it_does  \
# 98   A real money game app specializing in trivia g...
# 519                Soft Skills that make Smart Leaders
# 532  A Future of Work Platform for diffusing Employ...
# 655                Democratising Real Estate Ownership
# 658  India's fastest growing Pedagogy company, serv...
#
#                                               Founders  \
# 98                                              YC W21
# 519  Holistic Development Programs for children in ...
# 532                                  Backed by 100x.VC
# 655            Own rent yielding commercial properties
# 658                                           Pedagogy
#
#                             Investor                           Amount  \
# 98       Pritesh Kumar, Bharat Gupta                         Upsparks
# 519                     Vishal Gupta                     ah! Ventures
# 532  Omkar Pandharkame, Ketaki Ogale   ITO Angel Network, LetsVenture
# 655                      Aryaman Vir                             None
# 658                   Sushil Agarwal  JITO Angel Network, LetsVenture
#
#         Stage
# 98   $1200000
# 519   $300000
# 532   $300000
# 655  $6000000
# 658  $1000000

# %% [markdown]
# amount column

# %%
data_2021['Amount'].unique().tolist()
# Out:
# ['$1,200,000',
#  '$120,000,000',
#  '$30,000,000',
#  '$51,000,000',
#  '$2,000,000',
#  '$188,000,000',
#  '$200,000',
#  'Undisclosed',
#  '$1,000,000',
#  '$3,000,000',
#  '$100,000',
#  '$700,000',
#  '$9,000,000',
#  '$40,000,000',
#  '$49,000,000',
#  '$400,000',
#  '$300,000',
#  '$25,000,000',
#  '$160,000,000',
#  '$150,000',
#  '$1,800,000',
#  '$5,000,000',
#  '$850,000',
#  '$53,000,000',
#  '$500,000',
#  '$1,100,000',
#  '$6,000,000',
#  '$800,000',
#  '$10,000,000',
#  '$21,000,000',
#  '$7,500,000',
#  '$26,000,000',
#  '$7,400,000',
#  '$1,500,000',
#  '$600,000',
#  '$800,000,000',
#  '$17,000,000',
#  '$3,500,000',
#  '$15,000,000',
#  '$215,000,000',
#  '$2,500,000',
#  '$350,000,000',
#  '$5,500,000',
#  '$83,000,000',
#  '$110,000,000',
#  '$500,000,000',
#  '$65,000,000',
#  '$150,000,000,000',
#  '$300,000,000',
#  '$2,200,000',
#  '$35,000,000',
#  '$140,000,000',
#  '$4,000,000',
#  '$13,000,000',
#  None,
#  '$Undisclosed',
#  '$2000000',
#  '$800000',
#  '$6000000',
#  '$2500000',
#  '$9500000',
#  '$13000000',
#  '$5000000',
#  '$8000000',
#  '$1000000',
#  '$1200000',
#  '$200000',
#  '$12000000',
#  '$1500000',
#  '$1700000',
#  '$5500000',
#  '$400000',
#  '$150000000',
#  '$4000000',
#  '$100000000',
#  '$500000',
#  '$15000000',
#  '$10000000',
#  '$40000000',
#  '$225000000',
#  '$6700000',
#  '$1300000',
#  '$20000000',
#  '$250000',
#  '$21000000',
#  '$52000000',
#  '$3800000',
#  '$17500000',
#  '$42000000',
#  '$2300000',
#  '$7000000',
#  '$30000000',
#  '$450000000',
#  '$28000000',
#  '$300000',
#  '$3500000',
#  '$8500000',
#  '$25000000',
#  '$3000000',
#  '$37000000',
#  '$370000000',
#  '$700000',
#  '$16000000',
#  '$100000',
#  '$44000000',
#  '$770000',
#  '$125000000',
#  '$35000000',
#  '$50000000',
#  '$4900000',
#  '$145000000',
#  '$22000000',
#  '$70000000',
#  '$6600000',
#  '$32000000',
#  '$24000000',
#  '$725000',
#  '$461000',
#  'Series C',
#  'Seed',
#  '$96000000',
#  '$60000000',
#  '$500000000',
#  '$266000000',
#  '$4500000',
#  '$325000000',
#  '$6500000',
#  '$1600000',
#  '$150000',
#  '$225000',
#  '$85000000',
#  '$235000',
#  '$260000',
#  '$2900000',
#  '$53000000',
#  '$1100000',
#  '$86000000',
#  '$130000',
#  '$$100,00',
#  '$111000000',
#  '$265000',
#  '$76000000',
#  '$100,000,000',
#  '$75,000,000',
#  '$3,800,000',
#  '$12,000,000',
#  '$1,600,000',
#  '$260,000',
#  '$1,000,000,000',
#  '$18,000,000',
#  '$20,000,000',
#  '$350,000',
#  '$95,000,000',
#  '$4,100,000',
#  '$5,200,000',
#  '$8,000,000',
#  '$1,400,000',
#  '$2,600,000',
#  '$900,000',
#  '$250,000',
#  '$16,000,000',
#  '$7,000,000',
#  '$11,000,000',
#  '$280,000,000',
#  '$50,000,000',
#  '$14,300,000',
#  '$81,000,000',
#  '$1,300,000',
#  '$8,200,000',
#  '$70,000,000',
#  '$720,000',
#  '$600000',
#  '$9000000',
#  '$1800000',
#  '$330000',
#  '$undisclosed',
#  '$200000000',
#  '$36000000',
#  '$67000000',
#  '$10200000',
#  '$220000000',
#  '$108000000',
#  '$75000000',
#  '$450000',
#  '$660000000',
#  '$45000000',
#  '$3200000',
#  '$370000',
#  'Pre-series A',
#  '$48000000',
#  '$3600000',
#  '$11000000',
#  '$192000000',
#  '$65000000',
#  '$1400000',
#  '$1900000',
#  '$41000000',
#  '$144000000',
#  '$5200000',
#  '$270000000',
#  '$140000',
#  '$250000000',
#  '$320000',
#  '$350000000',
#  '$4800000',
#  '$38000000',
#  '$125000',
#  '$26000000',
#  '$64000000',
#  '$620000',
#  '$900000',
#  '$2600000',
#  '$1,250,000',
#  '$400,000,000',
#  '$1,700,000',
#  '$27,000,000',
#  '$234,000,000',
#  '$460,000,000',
#  '$13,500,000',
#  '$5,100,000',
#  '$195,000,000',
#  '$125,000',
#  '$45,000,000',
#  '$200,000,000',
#  '$7,300,000',
#  '$6,300,000',
#  '$12,500,000',
#  '$24,000,000',
#  '$140,000',
#  '$16,500,000',
#  '$340,000',
#  '$43,000,000',
#  '$150,000,000',
#  '$3300000',
#  '$92000000',
#  '$17000000',
#  '$135000000',
#  '$$1,55,000',
#  '$2100000',
#  '$840000000',
#  '$248000000',
#  '$4300000',
#  '$570000',
#  '$2200000',
#  '$4700000',
#  '$300000000',
#  '$260000000',
#  '$140000000',
#  '$175000000',
#  '$19000000',
#  '$810000',
#  '$7500000',
#  '$600000000',
#  '$90000000',
#  '$5700000',
#  '$6750000',
#  '$78000000',
#  '$5400000',
#  '$115000000',
#  '$255000000',
#  '$18000000',
#  '$570000000',
#  '$550000',
#  '$2700000',
#  '$4200000',
#  '$31000000',
#  '$540000',
#  '$14000000',
#  '$340000',
#  '$',
#  '$6200000',
#  '$750000',
#  '$6300000',
#  '$23000000',
#  '$55000000']

# %%
check_amount = ['Undisclosed','None','$Undisclosed','Series C','Seed','$undisclosed','Pre-series A','$']
filtered_amount = data_2021[data_2021['Amount'].isin(check_amount)]
filtered_amount
# Out:
#               Company_Brand  Founded HeadQuarter                    Sector  \
# 7               Qube Health   2016.0      Mumbai                HealthTech
# 8                  Vitra.ai   2020.0   Bangalore              Tech Startup
# 21                    Uable   2020.0   Bangalore                    EdTech
# 39                 TruNativ   2019.0      Mumbai          Food & Beverages
# 54                   AntWak   2019.0   Bangalore                    EdTech
# ...                     ...      ...         ...                       ...
# 1129              Godamwale   2016.0      Mumbai  Logistics & Supply Chain
# 1141  Atomberg Technologies   2012.0      Mumbai      Consumer Electronics
# 1142        Genext Students   2013.0      Mumbai                    EdTech
# 1147              OckyPocky   2015.0    Gurugram                    EdTech
# 1174        Sapio Analytics   2019.0      Mumbai         Computer Software
#
#                                            What_it_does  \
# 7     India's Most Respected Workplace Healthcare Ma...
# 8     Vitra.ai is an AI-based video translation plat...
# 21    Uable offers role based programmes to empower ...
# 39                   TruNativ Foods & Beverages Pvt Ltd
# 54    AntWak provides a video platform for e-learnin...
# ...                                                 ...
# 1129  Godamwale is tech enabled integrated logistics...
# 1141             A maker of energy-efficient smart fans
# 1142  LIVE online classes with expert tutors for K-1...
# 1147  OckyPocky is India's 1st interactive English l...
# 1174  Sapio helps government create policies driven ...
#
#                                                Founders  \
# 7                                           Gagan Kapur
# 8                                        Akash Nidhi PS
# 21                                       Saurabh Saxena
# 39                      Pranav Malhotra, Mamta Malhotra
# 54    Basav Nagur, Joybroto Ganguly, Sudhanshu Shekh...
# ...                                                 ...
# 1129          Basant Kumar, Vivek Tiwari, Ranbir Nandan
# 1141                         Manoj Meena, Sibabrata Das
# 1142                    Ali Asgar Kagzi, Piyush Dhanuka
# 1147                                       Amit Agrawal
# 1174  Hardik Somani, Ashwin Srivastava, Shripal Jain...
#
#                                    Investor        Amount         Stage
# 7                 Inflection Point Ventures   Undisclosed  Pre-series A
# 8                         Inflexor Ventures   Undisclosed       Unknown
# 21            Chiratae Ventures, JAFCO Asia   Undisclosed          Seed
# 39                                9Unicorns   Undisclosed          Seed
# 54           Vaibhav Domkundwar, Kunal Shah   Undisclosed          Seed
# ...                                     ...           ...           ...
# 1129                         1000000\t#REF!          Seed       Unknown
# 1141                         Ka Enterprises  $Undisclosed       Unknown
# 1142                      Navneet Education  $Undisclosed       Unknown
# 1147  Sujeet Kumar, SucSEED Indovation Fund  $Undisclosed          Seed
# 1174            Rachit Poddar, Rajesh Gupta  $Undisclosed       Unknown
#
# [143 rows x 9 columns]

# %%
data_2021['Amount'].dtype
# Out:
# dtype('O')

# %%
data_2021['Amount'] = data_2021['Amount'].replace(check_amount, np.nan)
data_2021['Amount'] = data_2021['Amount'].str.replace('[$,]', '', regex=True)

# %%
# remove # sign in from as keep in mind the our amount is in dollar sign
data_2021['Amount'] = data_2021['Amount'].str.replace(',', '')
data_2021['Amount'] = data_2021['Amount'].replace('None', '')
data_2021['Amount'] = data_2021['Amount'].replace("'$", '')
data_2021['Amount'] = data_2021['Amount'].replace("'", '')

# %%
data_2021['Amount'].unique().tolist()
# Out:
# ['1200000',
#  '120000000',
#  '30000000',
#  '51000000',
#  '2000000',
#  '188000000',
#  '200000',
#  nan,
#  '1000000',
#  '3000000',
#  '100000',
#  '700000',
#  '9000000',
#  '40000000',
#  '49000000',
#  '400000',
#  '300000',
#  '25000000',
#  '160000000',
#  '150000',
#  '1800000',
#  '5000000',
#  '850000',
#  '53000000',
#  '500000',
#  '1100000',
#  '6000000',
#  '800000',
#  '10000000',
#  '21000000',
#  '7500000',
#  '26000000',
#  '7400000',
#  '1500000',
#  '600000',
#  '800000000',
#  '17000000',
#  '3500000',
#  '15000000',
#  '215000000',
#  '2500000',
#  '350000000',
#  '5500000',
#  '83000000',
#  '110000000',
#  '500000000',
#  '65000000',
#  '150000000000',
#  '300000000',
#  '2200000',
#  '35000000',
#  '140000000',
#  '4000000',
#  '13000000',
#  None,
#  '9500000',
#  '8000000',
#  '12000000',
#  '1700000',
#  '150000000',
#  '100000000',
#  '225000000',
#  '6700000',
#  '1300000',
#  '20000000',
#  '250000',
#  '52000000',
#  '3800000',
#  '17500000',
#  '42000000',
#  '2300000',
#  '7000000',
#  '450000000',
#  '28000000',
#  '8500000',
#  '37000000',
#  '370000000',
#  '16000000',
#  '44000000',
#  '770000',
#  '125000000',
#  '50000000',
#  '4900000',
#  '145000000',
#  '22000000',
#  '70000000',
#  '6600000',
#  '32000000',
#  '24000000',
#  '725000',
#  '461000',
#  '96000000',
#  '60000000',
#  '266000000',
#  '4500000',
#  '325000000',
#  '6500000',
#  '1600000',
#  '225000',
#  '85000000',
#  '235000',
#  '260000',
#  '2900000',
#  '86000000',
#  '130000',
#  '10000',
#  '111000000',
#  '265000',
#  '76000000',
#  '75000000',
#  '1000000000',
#  '18000000',
#  '350000',
#  '95000000',
#  '4100000',
#  '5200000',
#  '1400000',
#  '2600000',
#  '900000',
#  '11000000',
#  '280000000',
#  '14300000',
#  '81000000',
#  '8200000',
#  '720000',
#  '330000',
#  '200000000',
#  '36000000',
#  '67000000',
#  '10200000',
#  '220000000',
#  '108000000',
#  '450000',
#  '660000000',
#  '45000000',
#  '3200000',
#  '370000',
#  '48000000',
#  '3600000',
#  '192000000',
#  '1900000',
#  '41000000',
#  '144000000',
#  '270000000',
#  '140000',
#  '250000000',
#  '320000',
#  '4800000',
#  '38000000',
#  '125000',
#  '64000000',
#  '620000',
#  '1250000',
#  '400000000',
#  '27000000',
#  '234000000',
#  '460000000',
#  '13500000',
#  '5100000',
#  '195000000',
#  '7300000',
#  '6300000',
#  '12500000',
#  '16500000',
#  '340000',
#  '43000000',
#  '3300000',
#  '92000000',
#  '135000000',
#  '155000',
#  '2100000',
#  '840000000',
#  '248000000',
#  '4300000',
#  '570000',
#  '4700000',
#  '260000000',
#  '175000000',
#  '19000000',
#  '810000',
#  '600000000',
#  '90000000',
#  '5700000',
#  '6750000',
#  '78000000',
#  '5400000',
#  '115000000',
#  '255000000',
#  '570000000',
#  '550000',
#  '2700000',
#  '4200000',
#  '31000000',
#  '540000',
#  '14000000',
#  '6200000',
#  '750000',
#  '23000000',
#  '55000000']

# %%
data_2021.iloc[[658]]
# Out:
#         Company_Brand  Founded HeadQuarter  Sector  \
# 658  Saarthi Pedagogy   2015.0   Ahmadabad  EdTech
#
#                                           What_it_does  Founders  \
# 658  India's fastest growing Pedagogy company, serv...  Pedagogy
#
#            Investor   Amount             Stage
# 658  Sushil Agarwal  1000000  Unknown, Unknown

# %%
data_2021['Amount'].dtype
# Out:
# dtype('O')

# %%
data_2021['Amount'].unique()
# Out:
# array(['1200000', '120000000', '30000000', '51000000', '2000000',
#        '188000000', '200000', nan, '1000000', '3000000', '100000',
#        '700000', '9000000', '40000000', '49000000', '400000', '300000',
#        '25000000', '160000000', '150000', '1800000', '5000000', '850000',
#        '53000000', '500000', '1100000', '6000000', '800000', '10000000',
#        '21000000', '7500000', '26000000', '7400000', '1500000', '600000',
#        '800000000', '17000000', '3500000', '15000000', '215000000',
#        '2500000', '350000000', '5500000', '83000000', '110000000',
#        '500000000', '65000000', '150000000000', '300000000', '2200000',
#        '35000000', '140000000', '4000000', '13000000', None, '9500000',
#        '8000000', '12000000', '1700000', '150000000', '100000000',
#        '225000000', '6700000', '1300000', '20000000', '250000',
#        '52000000', '3800000', '17500000', '42000000', '2300000',
#        '7000000', '450000000', '28000000', '8500000', '37000000',
#        '370000000', '16000000', '44000000', '770000', '125000000',
#        '50000000', '4900000', '145000000', '22000000', '70000000',
#        '6600000', '32000000', '24000000', '725000', '461000', '96000000',
#        '60000000', '266000000', '4500000', '325000000', '6500000',
#        '1600000', '225000', '85000000', '235000', '260000', '2900000',
#        '86000000', '130000', '10000', '111000000', '265000', '76000000',
#        '75000000', '1000000000', '18000000', '350000', '95000000',
#        '4100000', '5200000', '1400000', '2600000', '900000', '11000000',
#        '280000000', '14300000', '81000000', '8200000', '720000', '330000',
#        '200000000', '36000000', '67000000', '10200000', '220000000',
#        '108000000', '450000', '660000000', '45000000', '3200000',
#        '370000', '48000000', '3600000', '192000000', '1900000',
#        '41000000', '144000000', '270000000', '140000', '250000000',
#        '320000', '4800000', '38000000', '125000', '64000000', '620000',
#        '1250000', '400000000', '27000000', '234000000', '460000000',
#        '13500000', '5100000', '195000000', '7300000', '6300000',
#        '12500000', '16500000', '340000', '43000000', '3300000',
#        '92000000', '135000000', '155000', '2100000', '840000000',
#        '248000000', '4300000', '570000', '4700000', '260000000',
#        '175000000', '19000000', '810000', '600000000', '90000000',
#        '5700000', '6750000', '78000000', '5400000', '115000000',
#        '255000000', '570000000', '550000', '2700000', '4200000',
#        '31000000', '540000', '14000000', '6200000', '750000', '23000000',
#        '55000000'], dtype=object)

# %% [markdown]
# clean the row with amount '$1000000'

# %%
# Cleaning the 'Amount($)' column by removing single quotes and converting the values to numeric

data_2021['Amount']  = data_2021['Amount'].replace({"'": "",'$': ''}, regex=True)

# %%
data_2021['Amount'].unique()
# Out:
# array(['1200000', '120000000', '30000000', '51000000', '2000000',
#        '188000000', '200000', nan, '1000000', '3000000', '100000',
#        '700000', '9000000', '40000000', '49000000', '400000', '300000',
#        '25000000', '160000000', '150000', '1800000', '5000000', '850000',
#        '53000000', '500000', '1100000', '6000000', '800000', '10000000',
#        '21000000', '7500000', '26000000', '7400000', '1500000', '600000',
#        '800000000', '17000000', '3500000', '15000000', '215000000',
#        '2500000', '350000000', '5500000', '83000000', '110000000',
#        '500000000', '65000000', '150000000000', '300000000', '2200000',
#        '35000000', '140000000', '4000000', '13000000', None, '9500000',
#        '8000000', '12000000', '1700000', '150000000', '100000000',
#        '225000000', '6700000', '1300000', '20000000', '250000',
#        '52000000', '3800000', '17500000', '42000000', '2300000',
#        '7000000', '450000000', '28000000', '8500000', '37000000',
#        '370000000', '16000000', '44000000', '770000', '125000000',
#        '50000000', '4900000', '145000000', '22000000', '70000000',
#        '6600000', '32000000', '24000000', '725000', '461000', '96000000',
#        '60000000', '266000000', '4500000', '325000000', '6500000',
#        '1600000', '225000', '85000000', '235000', '260000', '2900000',
#        '86000000', '130000', '10000', '111000000', '265000', '76000000',
#        '75000000', '1000000000', '18000000', '350000', '95000000',
#        '4100000', '5200000', '1400000', '2600000', '900000', '11000000',
#        '280000000', '14300000', '81000000', '8200000', '720000', '330000',
#        '200000000', '36000000', '67000000', '10200000', '220000000',
#        '108000000', '450000', '660000000', '45000000', '3200000',
#        '370000', '48000000', '3600000', '192000000', '1900000',
#        '41000000', '144000000', '270000000', '140000', '250000000',
#        '320000', '4800000', '38000000', '125000', '64000000', '620000',
#        '1250000', '400000000', '27000000', '234000000', '460000000',
#        '13500000', '5100000', '195000000', '7300000', '6300000',
#        '12500000', '16500000', '340000', '43000000', '3300000',
#        '92000000', '135000000', '155000', '2100000', '840000000',
#        '248000000', '4300000', '570000', '4700000', '260000000',
#        '175000000', '19000000', '810000', '600000000', '90000000',
#        '5700000', '6750000', '78000000', '5400000', '115000000',
#        '255000000', '570000000', '550000', '2700000', '4200000',
#        '31000000', '540000', '14000000', '6200000', '750000', '23000000',
#        '55000000'], dtype=object)

# %%
data_2021['Amount'] = pd.to_numeric(data_2021['Amount'])

# %%
Outliers2021 = detect_outliers(data_2021, 'Amount')
Outliers2021
# Out:
#       Company_Brand  Founded                        HeadQuarter  \
# 1            upGrad   2015.0                             Mumbai
# 3           Bizongo   2015.0                             Mumbai
# 5     Urban Company   2014.0                          New Delhi
# 15         Tessolve   1993.0                          Bangalore
# 16     Smart Joules   2014.0                          New Delhi
# ...             ...      ...                                ...
# 1138      Pine Labs   1998.0                              Noida
# 1150       HomeLane   2014.0                          Bangalore
# 1157           Peak   2014.0  Information Technology & Services
# 1176      Delhivery   2011.0                           Gurugram
# 1187   Leap Finance   2019.0                          Bangalore
#
#                                  Sector  \
# 1                                EdTech
# 3                        B2B E-commerce
# 5                         Home services
# 15                          Electronics
# 16                     Renewable Energy
# ...                                 ...
# 1138  Information Technology & Services
# 1150                    Interior Design
# 1157     Manchester, Greater Manchester
# 1176           Logistics & Supply Chain
# 1187                 Financial Services
#
#                                            What_it_does  \
# 1        UpGrad is an online higher education platform.
# 3     Bizongo is a business-to-business online marke...
# 5     Urban Company (Formerly UrbanClap) is a home a...
# 15    Tessolve Semiconductor offers engineering in s...
# 16        Smart Joules is an energy management company.
# ...                                                 ...
# 1138  A merchant platform company that provides fina...
# 1150  Tech-empowered teams have delivered over 20,00...
# 1157  Peak helps the world's smartest companies put ...
# 1176  Delhivery is a leading logistics and supply ch...
# 1187  International education loans for high potenti...
#
#                                                Founders  \
# 1     Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 3               Aniket Deb, Ankit Tomar, Sachin Agrawal
# 5     Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 15    P Raja Manickam, Srinivas Chinamilli, Veerappan V
# 16       Arjun P Gupta, Ujjal Majumdar, Sidhartha Gupta
# ...                                                 ...
# 1138                                         Amrish Rau
# 1150                                      Srikanth Iyer
# 1157                                        Atul Sharma
# 1176                                        Sahil Barua
# 1187                         Arnav Kumar, Vaibhav Singh
#
#                                         Investor      Amount     Stage
# 1       Unilazer Ventures, IIFL Asset Management 120000000.0   Unknown
# 3                         CDC Group, IDG Capital  51000000.0  Series C
# 5                                     Vy Capital 188000000.0   Unknown
# 15                           Novo Tellus Capital  40000000.0   Unknown
# 16               Raintree Family Office, ADB arm  49000000.0   Unknown
# ...                                          ...         ...       ...
# 1138             Invesco Developing Markets Fund 100000000.0   Unknown
# 1150  IIFL AMC, Oman India Joint Investment Fund  50000000.0  Series E
# 1157                      SoftBank Vision Fund 2  75000000.0  Series C
# 1176                                    Addition  76000000.0  Series I
# 1187                                Owl Ventures  55000000.0  Series C
#
# [170 rows x 9 columns]

# %% [markdown]
# AM not removing outlier as amount the a company can receive as total investement from multiple investors, as seen some startup receive multiple investment

# %% [markdown]
# hanlde missing values

# %%
# handle missing value by imputting median strategy
imputer = SimpleImputer(strategy ='median') 

data_2021['Amount'] = imputer.fit_transform(data_2021[['Amount']])

# %%
data_2021['Stage'].isnull().sum()
# Out:
# 0

# %% [markdown]
# categorized the stage column

# %%
data_2021['Stage'].unique()
# Out:
# array(['Pre-series A', 'Unknown', 'Series D', 'Series C', 'Seed',
#        'Series B', 'Series E', 'Pre-seed', 'Series A', 'Pre-series B',
#        'Debt', 'Seed+', 'Series F2', 'Series A+', 'Series G', 'Series F',
#        'Series H', 'Series B3', 'PE', 'Series F1', 'Pre-series A1',
#        'Unknown, Unknown', 'Early seed', 'Series D1', 'Seies A',
#        'Pre-series', 'Series A2', 'Series I'], dtype=object)

# %% [markdown]
# Investor column

# %%
data_2021['Investor'].unique()
# Out:
# array(['BEENEXT, Entrepreneur First',
#        'Unilazer Ventures, IIFL Asset Management',
#        'GSV Ventures, Westbridge Capital', 'CDC Group, IDG Capital',
#        'Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal', 'Vy Capital',
#        'CIIE.CO, KIIT-TBI', 'Inflection Point Ventures',
#        'Inflexor Ventures', None,
#        '9Unicorns Accelerator Fund, Metaform Ventures',
#        'SucSEED Indovation, IIM Calcutta Innovation Park',
#        'Safe Planet Medicare', 'Impact Partners, C4D Partners',
#        'Tiger Global Management, InnoVen Capital', 'Novo Tellus Capital',
#        'Raintree Family Office, ADB arm',
#        'Mumbai Angels, Narendra Shyamsukha', 'Paradigm, Kunal Shah',
#        'Matrix Partners India, GIC', 'Chiratae Ventures, JAFCO Asia',
#        'Mumbai Angels Network, Expert DOJO', 'GVFL',
#        'Kotak Mahindra Bank, FMO', 'Kalaari Capital',
#        'NB Ventures, IAN Fund',
#        'Sequoia Capital India, Hummingbird Ventures',
#        'Gaurav Munjal, Snehil Khanor', 'JITO Angel Network, SOSV',
#        'Chiratae Ventures, YourNest Venture Capital', 'STRIVE VC',
#        'Venture Catalysts', 'Jaipuria Family Office', 'Amazon',
#        'Riso Capital', 'MTG Ventures',
#        'Qualcomm Ventures, Warburg Pincus', '9Unicorns', 'Morgan Stanley',
#        'Alfa Ventures, Agility Venture Partners',
#        'Stellaris Venture Partners, Ramakant Sharma', 'Spanache',
#        'DSG Consumer Partners, Saama Capital', 'Hindustan Media Ventures',
#        'Stellaris Venture Partners, Omidyar Network India, Flourish Ventures',
#        'Angelbay Holdings, Faad Network',
#        'Alteria Capital, Chiratae Ventures',
#        'WaterBridge Ventures, Info Edge',
#        'Carmignac, Falcon Edge Capital', 'Vaibhav Domkundwar, Kunal Shah',
#        'Chiratae Ventures, Bharat Innovation Fund',
#        'Acko Technology, Services, LetsVenture',
#        'Bertelsmann India Investments, Fullerton Financial Holdings',
#        'Dragoneer Investment Group, Tiger Global Management',
#        'http://100x.vc/',
#        'TPG Growth, Caisse de Depot et Placement du Quebec',
#        'Centrum Financial Services', 'Chiratae Ventures, BEENEXT',
#        'Harsha Bhogle', 'GetVantage, Prakash Katama',
#        'Tiger Global Management, Y Combinator Continuity Fund',
#        'Michael & Susan Dell Foundation', 'Marquee fintech founders',
#        'Falcon Edge India, Norwest Venture Partners',
#        'SOSV, Omphalos Ventures India', 'Twitter Ventures, Pawan Munjal',
#        'CitiusTech', 'Arena Holdings, Think Investments',
#        'T Choithrams BVI, Ardor',
#        'Kogta Financial India Limited, ICICI Bank',
#        'SucSEED Venture Partners, TMT Connekt',
#        'SAIF Partners, Venture Highway', 'Global Founders Capital',
#        'JAFCO Asia, Chiratae Ventures', 'Y Combinator',
#        'Artha Venture Fund', 'Jitendra Gupta, Amrish Rau',
#        'FJ Labs, Brian Norgard', 'Indian Angel Network',
#        'Jitendra Gupta, Harsh Shah',
#        'Elevation Partners, Emergent Ventures',
#        'Kalaari Capital, Dream Capital', 'Lumikai',
#        'Matrix Partners India', 'C4D Partners', 'Bertelsmann India',
#        'Iron Pillar, Nordstar, Binny Bansal',
#        'FMC, Omnivore, Blume Ventures', 'InvestCorp',
#        'Pritesh Kumar, Bharat Gupta',
#        'Y Combinator, 9Unicorns, Titan Capital',
#        'Unicorn India Ventures, SEA Fund, Devdatt Shah',
#        'Matrix Partners India, Elevation Capital',
#        'Avaana Capital, Orios Ventures', 'Punit Balan',
#        'Y Combinator, Broom Ventures, Kunal Shah',
#        'Skycatcher, AET Fund, BAce Capital, Dream Incubator, 1Up Ventures',
#        'Eclear Leasing', 'First Cheque, Letsventure',
#        'Sequoia Capital India, BEENEXT', 'Velocity',
#        'Tribe Capital, Moore Strategic Ventures (MSV)',
#        'Fireside Ventures', 'Inflection Point Ventures, ONGC',
#        'Y Combinator, Incubate Fund India',
#        'Titan Capital, Rockstud Capital,  John Abraham, WEH Ventures',
#        'Info Edge Ventures', 'NB Ventures', 'Accel',
#        'Binny Bansal, Kunal Shah', 'TradeCred', 'Unicorn India Ventures',
#        'UC Inclusive Credit, Western Capital',
#        'IIFL India Private Equity Fund, Smiti Holding & Trading Company',
#        'Faering Capital', 'responsAbility Investments, Blue Orchard',
#        'Sanchit Agarwal, Sujan Sinha, Michael Cooke',
#        'CRV, Nexus Venture Partners',
#        'Salesforce Ventures, Sierra Ventures, Sequoia Capital India’s Surge',
#        'Micelio Fund, growX ventures',
#        'IIFL Wealth, Asset Management, Northern Arc Capital',
#        'Better Capital, Ashish Achrekar', 'IAN', 'Alpha Wave Incubation',
#        'Point One Capital, Yatra Angel Network (YAN), Opus Consulting, Manipal Technologies.',
#        'Microsoft', 'Shell Ventures, Yamaha, Kunal Shah',
#        'We Founder Circle',
#        'Saama Capital, DSG Consumer Partners, Sharrp Ventures',
#        'Tiger Global’s Scott Schleifer', 'Elevation Capital',
#        'Venture Catalysts, Auxano Capital, Venture Garage, Yoga Capital, Ah!Ventures, Lead Angels',
#        'Sixth Sense Ventures', '9Unicorns, Sequoia Capital India’s Surge',
#        'Anicut Angel Fund, 9 Unicorns', 'Info Edge, FalconEdge',
#        'WestCap Group, Tomales Bay Capital',
#        'Chiratae Ventures, Better Capital',
#        'Siguler Guff, Baillie Gifford',
#        'IIFL AMC, Mankind Pharma Family Office, Aroa Ventures',
#        'ITI Growth Opportunities', 'Amrac Investment Trust',
#        'Bhavin Turakhia', 'Amara Raja Batteries',
#        'India Infoline Finance', 'Venture Highway', 'BEENEXT, Orios',
#        'Axilor', 'Westbridge Capital, Tanglin Venture Partners',
#        '100X.VC\ufeff,\ufeff Titan Capital, Rahul Mathur, Gaurav Mandlecha',
#        'IIFL, Amicus Capital, Ananta Capital',
#        'Venture Highway, Endiya Partners',
#        'Verlinvest, Sequoia Capital India', 'Anicut Angel Fund',
#        'Tiger Global',
#        'Alphabit Fund, Fulgur Ventures, Stacks Accelerator, SBX Capital',
#        'Roots Ventures, Velo Partners', 'Nexus Venture Partners',
#        'Mumbai Angels Network, Huddle, Lumis Partners',
#        'SucSEED Indovation Fund',
#        'Potencia Ventures, Bisk Ventures, LetsVenture, Ronnie Screwvala, Arihant Patni',
#        'Better Capital, First Cheque, Titan Capital', 'Evolvence Capital',
#        'SARA ELGI',
#        'Nubank, Global Founders Capital, Sequoia Capital India, Matrix Partners India',
#        'ah! Ventures High Tables',
#        'Eight Roads Ventures, Think Investments, Mankekar Family Office',
#        'A91 Partners', 'Chiratae Ventures', 'Sequoia’s Surge',
#        'Lead Angels, Titan Capital, Pravega Ventures',
#        'Accel Partners, Elevation Capital',
#        'Inflection Point Ventures, Rockstud Capital, FirstPort Capital, Bliss Flow Investments Pvt Ltd',
#        'Anicut Angel Fund, Axilor Ventures',
#        'Ecosystem Ventures, CMM group',
#        'Mumbai Angels Network, Social Alpha', 'Disrupt ADQ, QIC',
#        'Valar Ventures, IA Ventures', 'Sequoia Capital India', 'Zomato',
#        'Lightspeed, Times Group, Tanglin Venture Partners',
#        'Binny Bansal, Deep Kalra, Dr Ashish Gupta, Gokul Rajaram, Shirish Nadkarni',
#        'Tuscan Ventures, Ohm Stock Brokers, Artha Venture Fund',
#        'Signal Peak Ventures', 'Evolvence, Hero Enterprise',
#        'BlueOrchard Impact Investment Managers', 'Steadview Capital',
#        'MassMutual Ventures', 'YourNest VC', 'Accel India',
#        'Vijay Shekhar Sharma, Ritesh Agarwal, Ankiti Bose',
#        'TVS Motor, Zoho', 'IIFL Asset Management',
#        'Oasis Capital, Scorpio VC, DeltaHub Capital',
#        'Titan Capital, Haresh Chawla, AngelList Syndicate',
#        '9Unicorns, Ashneer Grover', 'Founders Room Capital',
#        '9Unicorns, ZNL', 'WEH Ventures', '$22000000', '$5000000',
#        'Kunal Shah, Deepinder Goyal, Abhiraj Singh Bhal',
#        'Guild Capital, RPSG Capital Ventures',
#        'General Catalyst, Eight Roads Ventures, Elevation Capital',
#        'NB Ventures, Earlsfield Capital', 'Varun Alagh, Sahil Barua',
#        'SoftBank Vision Fund 2', 'Tribe Capital, Prime Venture Partners',
#        'Jungle Ventures', 'Marquee international institutional investors',
#        'Alkeon Capital', 'Y Combinator, Harvard Management',
#        'Y Combinator\ufeff, \ufeffGoodwater Capital',
#        'Shrishti Sahu, Umang Vohra', 'Astra Ventures, Gaurav Jaitly',
#        'Capital A, Collective Artists Network',
#        'Aditya Singhal, Nishant Sinha', 'Pentathlon Ventures',
#        'Alpha Wave Ventures II, Tiger Global Management, SoftBank Vision Fund II',
#        'KRAFTON', 'Chiratae Ventures, Lenskart Vision Fund', 'Recur Club',
#        'DevX Venture Fund', 'DevX Venture Fund, Blume Founder Fund',
#        'Ajith Daneil', 'Aurum Proptech', 'Y-Combinator',
#        'The Good Glamm Group', 'Invus', 'Tiger Global, Prosus Ventures',
#        'Shuru Up, Ankit Kedia, Arun Gupta',
#        'Ankit Mehrotra, Saurabh Aggarwal', 'Sauce.vc',
#        '3one4 Capital, Sixth Sense Ventures',
#        'YCombinator, Justin Mateen, Pioneer Fund',
#        'Sojitz Corporation, Stride Ventures',
#        'IIFL Wealth, TPG Growth, Norwest Venture Partners',
#        'Nabventures, Avaana Capital', 'Fluid Ventures, Mulberry Silks',
#        'Rajesh Rajendran', 'Mike Novogratz, Neeraj Arora',
#        'Reliance Digital Health', 'Ritu Marya Family Office.',
#        'Ten Innovate', 'Tiger Global, Sequoia Capital',
#        'Shark Tank India', 'Premji Invest, Steadview Capital', 'Sequoia',
#        'Apis Insurtech Fund I', 'SK Tripathi, Sanjeev Gupta',
#        'Hardcastle Petrofer', 'Ocean View Investment, QED Fund',
#        'Omidyar Network, Tencent Holdings',
#        'ITI Growth Opportunities Fund, Unit-E Ventures',
#        'InnoVen Capital, Nexus Venture Partners', 'CIIE.CO',
#        'Orios Venture Partners', 'Omidyar Network India',
#        'Wipro venture capital arm', 'Yuj Ventures, Sixth Sense Ventures',
#        'Premji Invest, Mirae Asset Naver Asia Growth Fund, Alpine Capital',
#        'Inflection Point Ventures, SucSEED Venture Partners',
#        'Anas Rahman Junaid, Vinod Jose', 'Capital One, Arrowroot Capital',
#        'YourNest Venture Capital', 'Incubate Fund India',
#        'Kunal Shah, Greg Kidd', 'InnoVen Capital, TEAMFund',
#        'Venture Catalysts, 9Unicorns Accelerator Fund',
#        'Venture Highway, Rohit Bansal', 'Fresco Capital, Social Starts',
#        'Y Combinator, Rebright Partners',
#        'Rohit Goutamchand, India CXO Fund',
#        'Rajasthan Venture Capital Fund, ACPL Exports',
#        'Amplo, Insight Partners', 'Better Capital', 'Justin Mateen',
#        'View Trade Holding Corp',
#        'InnoVen Capital, Bertelsmann India Investments', 'ScoopWhoop',
#        'Canaan Valley Capital, Glade Brook Capital Partners',
#        'Vijay Shekhar Sharma, Dr Ritesh Malik',
#        'RTP Global, Harshil Mathur', 'Paragon Partners, NABVENTURES',
#        'EXPERT DOJO', 'Saama Capital, India Quotient',
#        'InCred Financial Services, Vivriti Capital, Northern Arc Capital',
#        'ah! Ventures', 'Somak Ghosh, M V Nair', 'Wurk',
#        'Plutus Wealth Management, Turtle Entertainment',
#        'Ambiga Subramanian, Goutham Ekollu', 'Accel, Owl Ventures',
#        'Rajan Anadan', 'Jesse Lucas',
#        'IDFC Private Equity, Bessemer Venture Partners',
#        'Sequoia Capital India, Accel',
#        'Venture Catalysts, Tahseen Consulting', 'Equanimity Ventures',
#        'BlueOrchard Finance S A, Gojo & Company',
#        'Better Capital, Titan Capital', 'Gojo & Company', 'Mumbai Angels',
#        'Pegasus Tech Ventures, Base Partners', '3one4 Capital, Accel',
#        'Hitesh Oberoi, Lightbox', 'YES Bank', 'Campus Fund',
#        'Hyperplane Venture Capital', 'Matrix Partners India, RTP Global',
#        'Info Edge, Ruizheng Investment', 'Quess Corp India',
#        'Sunil Kumar Singhvi, 9Unicorns Accelerator Fund',
#        'India Accelerator’s Angel Investor Network', 'Shell Foundation',
#        'Jimmy Singh', 'Kunal Shah, Deepak Abbot', 'Accel, Nexus Venture',
#        'Singapore Angel Network, Artha India Ventures',
#        'Starfish Growth Partners, Investpad', 'Hashed', 'Titan Capital',
#        "Zerodha's Rainmatter Capital, Better Capital",
#        'Sixth Sense Ventures, Colgate Palmolive',
#        'Lightbox, Evolvence India Fund', 'Tomorrow Capital',
#        'Inflection Point Ventures, DLabs',
#        'InnoVen Capital, Steadview Capital', 'BlackSoil Capital',
#        'PointOne Capital, Core91 VC', 'A91 Partners, Faering Capital',
#        'Blockchain Capital, SBI Ven Capital',
#        'Baring Private Equity Partners India, Talbros',
#        'Sequoia Capital India, 3one4 Capital',
#        'Prosus Ventures, RTP Global',
#        'U.S. International Development Finance Corp, responsAbility',
#        'Binance Labs, Zee Prime Capital', 'RP-Sanjiv Goenka Group',
#        'IvyCap Ventures', 'Zone Startups In', 'Blue Ashva Capital',
#        'Ribbit Capital, Kunal Shah', 'Ecom Express', 'InnoVen Capital',
#        'Satish Grampurohit', 'Amit Singhal, Raine Ventures',
#        'Octahedron Capital, Moonstone Capital',
#        'Tiger Global, Dragoneer Investment Group, Steadview Capital, General Atlantic',
#        'CDC Group, Aavishkaar Venture Capital', 'GSF, Pras Hanuma',
#        'Ajat Hukkoo, Piyush Chaplot', 'Mumbai Angels, Amitesh Pandey',
#        'Think Investments',
#        'Nexus Venture Partners, 23 High Networth Individuals (HNIs)',
#        'Yatra Angel Network, BEENEXT',
#        'Orios Venture Partners, Matrix Partners India', 'Trishneet Arora',
#        'ContCentric', 'Siana Capital', 'DST Global, General Catalyst',
#        'Anthill Ventures', 'InnoVen Capital, InnoVen Capita',
#        '3one4 Capital, DSP Group', 'Enzia Ventures, AngelList',
#        'Steadview Capital, Insight Partners',
#        'Invested Development, Pratithi Investment Trust',
#        'Dhianu Das, Agility Venture Partners', 'Hindustan Media Venture',
#        'Omnivore', 'Awign Enterprises',
#        'Siddharth Bhaskar Shah, Upsparks', 'S Chand',
#        'Goldman Sachs, Tata Capital', 'growX ventures, Venture Gurukool',
#        'Mount Judi India Growth Fund', 'GEF Capital’s South Asia Fund',
#        'Sunil Sethia, Sunil Kumar Singhvi, Manish Mardia',
#        'Sequoia Capital', 'Mechanism Capital, DACM',
#        'Northern Arc Capital, Niyogin Fintech Limited, Credit Saison India, Vivriti Capital',
#        'Pearl Investment LLC', '021 Capital, Sparrow Capital',
#        'Kotak Investment Advisors Limited, Gruhas Proptech', 'VANS Group',
#        'Sachin Tendulkar', 'Xentel Investments', 'Accel Partners',
#        'Waterbridge, Lumikai', 'Auxano, Falcon5', 'Infoedge ventures',
#        'JITO Angel Network', 'Jupiter', 'Unitus Ventures',
#        'GIC, Infoedge', 'pi Ventures',
#        'Northern Arc, Caspian Impact Investments', 'Sofina Ventures SA',
#        'Tiger Global, Flipkart Ventures',
#        'Inflection Point Ventures, Rockstud Capital, Pentathlon Ventures, Prophetic Ventures syndicate',
#        'Prime VP', 'Tribe Capital, IFC Emerging Asia Fund, VEF',
#        'Sequoia’s Surge, Y Combinator', 'Endiya Partners',
#        'Gokul Rajaram, Pureland Venture, Wavemaker Partners',
#        'Callapina Capital', 'Khosla Ventures',
#        'Accel Partners, Matrix India',
#        'Omidyar Network India, Innoven Capital', 'Temasek, Falcon Edge',
#        'Deep Kalra, Ashish Kashyap, Rajesh Magow',
#        'IAN, Social Alpha, Startup Oasis', 'Capital India',
#        'FirstCry, Lightspeed Venture Partners',
#        'Accel, LetsVenture, 1Crowd', 'SAB Holdings',
#        'Lightspeed Venture Partners, Elevation Capital',
#        'Mumbai Angels Network', 'Jayanti Kanani',
#        'LeapFrog, Khosla Ventures', 'Ananta Capital',
#        'Northern Arc, Vivriti Capital', 'TATA Cleantech Capital',
#        'Aqua-Spark', 'Climate Angels Fund',
#        'Sequoia’s Surge, Nexus Venture Partners',
#        'Entrepreneur First (EF), GrowX Ventures', 'Zephyr Peacock',
#        'ADM Capital', 'SoftBank Vision Fund, Hindustan Media Venture',
#        '100x Entrepreneurs', 'Healthcare veterans, PIEDS',
#        'Bank of Baroda', 'YCombinator', 'IAN Fund', 'Vishal Gupta',
#        'Mirae Asset, H&M', 'Kotak Securities', 'Klub',
#        'Balaji Srinivasan', '$1000000', 'BASF Venture Capital GmbH',
#        'Rebright Partners, Flourish Ventures', 'Sequoia Surge',
#        'Titan Capital, Sequoia Capital', 'Parthiv Group',
#        'Omkar Pandharkame, Ketaki Ogale',
#        'GetVantage, Velocity, Shiprocket Capital', 'Krafton Inc, Omidyar',
#        'Blume Ventures, Exfinity Venture Partners',
#        'Beyond Next Ventures, M Venture Partners', 'AdvantEdge Founders',
#        'Faering Capital, Sequoia Capital India, IIFL Alternate Asset Managers',
#        'Sixth Sense Ventures, NABVENTURES', 'Temasek, Multiples PE',
#        'Griffin Gaming Partners', 'Zinnia Global',
#        'InfoEdge Ventures, IAN Fund', 'IIFL, Mumbai Angels',
#        'BEENEXT, Sequoia’s Surge', 'Antler India', 'Bharat Inclusion',
#        'Fidelity, BlackRock', 'Blacksoil', 'Speciale Invest',
#        'Canbank Venture Capital Fund', 'W Health Ventures',
#        '021 Capital, Y Combinator', 'Anand Prakash Sharma',
#        'Axilor Ventures', 'velocity.in', 'March Capital, Tribe Capital',
#        'Learn Capital', 'RTP Global', 'IAN, Yuj Ventures',
#        'Sequoia’s Surge, Accel Partners', 'Uday Sodhi', 'Fidelity, GIC',
#        'Auxano', 'Angelist India',
#        'Stanford Angels and Entrepreneurs India, Anjali Bansal',
#        'Vy Capital, Wellington Management', 'Avon Cycles',
#        'Matrix Partners India, 021 Capital', 'HNIs, Angels',
#        'NewQuest Capital Partners, Motilal Oswal Private Equity',
#        'Lasons India', 'Pankaj Chaddah, Srivatsan Rajan', 'Paytm',
#        'BlackSoil, CLSA Capital Partners', 'Saama, Whiteboard Capital',
#        'Indian Angel Network, Titan Capital, Lead Angels',
#        'The Chennai Angels',
#        'Venture Highway, Stellaris Venture Partners',
#        'State Bank of India, Y Combinator', 'Sanjay Baldwa, Ajay Jain',
#        'InfoEdge', 'Nitin Passi, Ruchirans Jaipuria',
#        'Stride Ventures, InnoVen Capital',
#        'Venture Catalysts, Jeevak Gupta',
#        'Triodos Investment Management, SAIF Partners', 'N+1 Capital',
#        'DST Global, RTP Global', 'Amit Singal, Manish Aggarwal',
#        'Trifecta Capital Advisors, Blume Ventures',
#        'Kumar Aakash, Amit Singhal', 'growX ventures',
#        'Shaival Desai, Alkemi Venture Partners',
#        'Aavishkaar Venture Capital, YWC Venture Capital',
#        'Alteria Capital', 'Tiga Investments, Baron Capital',
#        'Venture Catalysts, 9unicorns', 'Qualgro',
#        'Amit Lakhotia, Pravin Jadhav', 'Pravega Ventures',
#        'Greenoaks Capital, Elevation Capital',
#        'Sequoia Capital India, rocketship.vc', 'BLinC Invest',
#        'Spring Marketing Capital', 'Chaitanya Kalipatnapu, Kedar Gavane',
#        'Roha Investment Managers, angel investor Saumil Shah',
#        'TNF Ventures, Razorpay', 'Lok Capital, IIFL Asset Management',
#        'Nvidia Inception', 'Tiger Global Management, DST Global',
#        'Marquee investors', 'Ashish Hemrajani, Parikshit Dar',
#        'India Accelerator, Lyxel&Flamingo', 'Roshan Abbas, Ritesh Malik',
#        'Goat Capital, JAM Fund', 'General Catalyst, Jungle Ventures',
#        'Blackstone Group, ADQ', 'GoAhead Ventures',
#        'Paradigm Shift Capital, AngelList India', 'Arali Ventures',
#        'Anup Kumar Yama', 'Aryaman Vir', 'iSeed, Titan Capital',
#        'Research Innovation Incubation Design Labs', 'Sushil Agarwal',
#        'IvyCap Ventures, Endiya Partners',
#        'GUSEC Seed Fund, DeVX Venture Fund', 'Tiger Global, Sequoia',
#        'Quadria Capital', 'Blume Ventures, Whiteboard Capital',
#        'Ashwini Kakkar. 9Unicorns', 'Ashish Shah', 'Faad Network',
#        'Paragon Partners, Aavishkaar Capital', 'Krafton, Lumikai',
#        'Indovation Fund, Mumbai Angels', 'Gunosy, Blume Ventures',
#        'Edge Ventures, Elevation Capital', 'CDC Group',
#        'Titan Capital, Kunal Shah',
#        'Yamaha Motors, Omidyar Network India, Eight Roads Ventures',
#        'Norfund, The Rise Fund', 'Siti Cable',
#        'Crossbeam Venture Partners', 'Aavishkaar Capital', 'Mapmyindia',
#        'Jyoti Bansal', 'Accor',
#        'SRI Capital, Picus Capital, Alkemi Capital',
#        'Saama Capital, DSG Consumer Partners', 'Valar Ventures',
#        'Addition, SIG Global India Fund',
#        '9Unicorns Accelerator Fund, Indian Angel Network',
#        'Alfa Ventures', '1Crowd',
#        'TCV, D1 Capital Partners, Falcon Edge.',
#        'BanyanTree Finance Pvt. Ltd.', 'EXPERT DOJO, Mumbai Angels',
#        'Quona Capital', 'Ashv Finance, BlackSoil Capital',
#        'WaterBridge Ventures, SAIF Partners',
#        'Sweta Rau, 9Unicorns Accelerator Fund',
#        'Omnivore, Strive Ventures', 'Rajesh Sud, KULDEEP JAIN',
#        'PayU, Google', 'Sundi Natarajan, Srinivas Anumolu',
#        'Titan Capital, First Cheque', 'TPG Capital Asia, Epiq Capital',
#        'MaGEHold Pte. Ltd.', 'BlackRock, Owl Ventures',
#        'Asian Development Bank, Oman India Joint Investment Fund',
#        'JSW Ventures, Kalaari Capital',
#        'Unitus Ventures, Omidyar Network India',
#        'IvyCap Ventures, Pratithi Investment Trust',
#        'ACPI Investments, AdvantEdge Founders',
#        'RouteOne, Mankekar Family Office', 'India Quotient',
#        'TCN International Commerce', 'Alpine Capital, PremjiInvest',
#        'Bon Angels Venture Partners, Daesung Private Equity',
#        'Spring Marketing Capital, Verlinvest', 'Bain Capital',
#        'F-Prime Capital, Eight Roads Ventures India',
#        'Mumbai Angels, DNA Entertainment Networks',
#        'Hornbill Capital Advisers, Plutus Wealth Management',
#        'ADB Ventures, Jetty Ventures', 'Techstars, Ryan Johnson',
#        'Bessemer Venture Partners',
#        'Titan Capital, iSeed, First Cheque, 3.0 Fund.',
#        'Falcon Edge Capital, White Oak Global Advisors',
#        'Angel investors', 'Akya Ventures',
#        'Kayenne Ventures, Nordic Microfinance Initiative',
#        'Kae Capital, Pi Ventures', 'Elevar Equity, Accel India',
#        'Titan Capital, Y Combinator', 'Jitendra Gupta, Better Capital',
#        'Radiant Life Care Private Ltd, Life Healthcare',
#        'Mount Judi Ventures, growX Ventures, Season Two Ventures',
#        'Richard Rekhy', 'GAWA Capital, Gaja Capital',
#        'Better Capital, Bharat Inclusion Seed Fund', 'Krafton',
#        'Eight Roads Ventures India, Nexus Venture Partners',
#        'CDC Group, Partners Group',
#        'Matrix Partners India, Ankur Capital',
#        'U.S. International Development Finance Corp, Asian Development Bank',
#        'Hungama, Hindustan Talkies', 'Agility Venture Partners',
#        'Speciale Invest, Farid Ahsan',
#        'Bessemer Venture Partners, CDH Investments',
#        'Sequoia Capital India, Matrix Partners India',
#        'Chiratae Ventures, AET Fund',
#        'Omidyar Network, Falcon Edge Capital',
#        'Jetty Ventures, Srinivas Anumolu', 'Avendus', 'YourNest',
#        'National Skill Development Corporation, Rianta Capital',
#        'Sequoia Capital India, Rocketship.vc',
#        'Infosys, Qualcomm Ventures',
#        'Real Estate Accelerator Program (REAP), AngelList',
#        'Asian Development Bank, U.S. International Development Finance Corp',
#        'Kohlberg Kravis Roberts, Temasek Holdings',
#        'Shireen Rangaswamy, Dilesh Gathani',
#        'Rebright Partners, Wadhwani Foundation',
#        'Dinesh Godara, Aditya Talwar',
#        'Sistema Asia Capital, Evolvence India Fund',
#        'Rajesh Agarwal, Nandkishore Mundada',
#        'Kallol Banerjee, Jaydeep Barman',
#        'JITO Angel Network, LetsVenture',
#        'MyAsia VC, Orios Venture Partners',
#        'W Health Ventures, Pi Ventures',
#        'Artha India Ventures, Sriram Krishnan', 'GSV, Multiply Ventures',
#        'WorldBusiness Capital, Northern Arc',
#        'Tanglin Ventures, Better Capital, Whiteboard Capital',
#        'Y Combinator, Rehan A Khan', 'Balaji Srinivasan, Naval Ravikant',
#        'Devesh Sachdev, Bhavesh Manglani',
#        'Pradeep K Jaisingh, Jayant Mehrotra', 'Varun Alagh, Harish Daiya',
#        'IAN Fund, World Startup Factory',
#        'Omidyar Network India, Avaana Capital', 'Brex, Y-Combinator',
#        'Mark Cuban, MiH Ventures', 'IvyCap Ventures, IAN Fund',
#        'Gurj Aujla, Ashik K', 'Dream Sports',
#        'The Chatterjee Group, Prophetic Ventures',
#        'Harsh Jain, Lalit Keshre', 'Supriya Kumari, Premanshu Singh',
#        '9Unicorns Accelerator Fund, Sunder Nookala',
#        'Accel Partners, Falcon Edge Capital, Norwest Venture Partners',
#        'Pravesh Mehta', 'Gaurav Gupta, Vivek Srivatsav', 'Lead Angels',
#        'Induslaw, Reddy Futures', 'Yuj Ventures', 'Geekster',
#        'Manish Subramaniam, Upaya Social Ventures', 'Eaglewings Ventures',
#        'Appit Simple Infotek', 'Beyond Next Ventures',
#        'Ramakant Sharma, Elevation Capital',
#        'Keiretsu Forum, SucSEED Venture Partners',
#        'Lightspeed India Partners, CM Ventures',
#        'Skycatcher, Nexus Venture Partners',
#        'Avataar Venture Partners, Kalaari Capital',
#        'Alteria Capital, Matrix Partners India',
#        'Raghav Kapur, Indian Angel Network', 'GSF Accelerator',
#        'Rishi Kumar Bagla, Krishen Lal Khanna',
#        'Glade Brook Capital, Nexus, Y Combinator',
#        'Capital Group, Falcon Edge', 'Dinesh Agarwal, Amarjit Batra',
#        'Arcilla, Samir Khosla',
#        'SUNiCON Ventures, Shubhkam Ventures, Jito Angel network, FAAD Network',
#        'Baring PE India', 'Manuvel Malabar Jewellers', 'Nabventures',
#        'Y Combinator, Jetty Ventures, Earlsfield Capital, SMC Advisors, Kunal Shah',
#        'Kunal Shah, Snehal Fulzele', 'SternAegis Ventures',
#        'Blume Ventures, Orios Ventures',
#        'Warburg Pincus\ufeff, Prosus Ventures', 'BlackSoil',
#        'Akash Prakash, Madhu Jayakumar, Dipinder Sandhu, Shagun Khandelwal',
#        'OAKS Asset Management', 'Titan Capital, LetsVenture',
#        'Incofin, NabVentures, Orios', 'BEENEXT', 'SIG',
#        'Blume Ventures, Micelio Fund',
#        'CDC Group, Jungle Ventures, March Capital, Marshall Wace',
#        'Ashish Jain, Ajay Surana',
#        'We Founder Circle, Appyhigh, Mumbai Angels',
#        'Aroa Ventures, GVFL, Udaan', 'Investcorp, Omidyar Network',
#        '2000000',
#        'Riteesh Mohan Bakshi, Raghav Mohan Bakshi, Achin Kochar',
#        'Info Edge Ventures, Omnivore', 'Sequoia Capital , Together Fund',
#        'Alpha Wave Ventures, Falcon Edge Capital',
#        'Vivek Vaidya, Kevin Donlon, Ayush Singh',
#        'Kieretsu Forum, Lets Venture, Shell',
#        'Sixth Sense Ventures, Godrej Family office, Malpani Group',
#        'Y-Combinator, AME Cloud Ventures, Gokul Rajaram', 'Smallcase',
#        'The StarupLab, AngelBay',
#        'Dallas Venture Capital, Mars Growth Capital',
#        'Raj Nair, Gopinath Latpate',
#        'Y Combinator, Goat VC, JAM Fund, Goodwater Capital',
#        'Binny Bansal, General Catalyst',
#        'General Atlantic, Tiger Global, Moore Strategic Ventures',
#        'Ascent Capital',
#        'Northern Arc, Arthmate, Shine Star, E clear, Hinduja',
#        'Family Office of Kantamaneni, IIM Calcutta Innovation Park',
#        'Saama Capital\ufeff, \ufeffTitan Capital\ufeff, DSG Consumer Partners',
#        'Omidyar Network, Flourish Ventures, Elevar Equity, Accel',
#        'ah! Ventures, We Founder Circle',
#        'Sequoia Capital, Matrix Partners',
#        'Falcon Edge, DST Global, D1 Capital, Redbird Capital, Tiger Global',
#        'Abu Dhabi Growth Fund, Tiger Global', 'Accel, Bain Capital',
#        'Tiger Global, Insight Partners', 'Ronnie Screwvala',
#        'WestBridge Capital', 'Elevation, General Catalyst',
#        'Equanimity Ventures, 9Unicorns', 'Nueva',
#        'Blume Ventures, Nexus Venture Partners',
#        'Apoorva Sharma, The Chennai Angels, Karthik Bhat',
#        'Gokul Rajaram, Venture Catalysts', 'Kvanto Payment Services',
#        'Siana Capital, Inflexor Ventures, Stride Ventures',
#        'Oxshott Capital Partners, XN Exponent, Edelweiss',
#        'Kunal Shah, Better Capital', 'Lightrock India, Filter Capital',
#        'EKKI', 'Stakeboat Capital',
#        'Coinbase Ventures, Andreessen Horowitz', 'BEENEXT, 3one4 Capital',
#        'Let’s Venture, Better Capital',
#        'International Finance Corporation',
#        'Alia Bhatt, IAN Fund, Social Alpha, Draper Richards Kaplan Foundation',
#        'Sequoia Capital India, ICONIQ Capital, Perceptive Advisors',
#        'LetsVenture', 'India Accelerator', 'Qatar Investment Authority',
#        'Netcore Cloud, Vallabh Bhansali, Jimmy Mahtani',
#        'Petronas Ventures', 'Solana', 'Falcon Edge, Softbank',
#        'Enzia Ventures, Kunal Shah', 'Auxano Capital',
#        'Prashant Pansare, Supermorpheus', 'Docprime Technologies',
#        'LC Nueva AIF', 'Nitish Mittersain, Gaurav Munjal',
#        '9Unicorns, Venture Catalysts, Sandeep Singhal',
#        'Temasek, Google, SBI Investment', 'Elevar Equity',
#        'Aroa Ventures',
#        '9Unicorns, Symphony International Holdings Limited, Value Quest',
#        'Republic Crypto, Woodstock, DCG, Sahil Lavingia',
#        'Data Point Capital',
#        'Momentum 6, Basics Capital, Krypital Capital, Shima Capital, Magnus Capital',
#        'Norwest Venture Partners', 'Sabre Partners',
#        'Vertex Ventures, Omnivore',
#        'Base 10 Partners, Eight Roads Ventures', 'enture Catalyst, IPV',
#        'Tiger Global, Falcon Edge',
#        'BAce Capital, Heritas Capital, 3Lines Venture Capital',
#        'Leo Capital, Mayfield Fund',
#        'Plutus Wealth, Oaks Asset Management',
#        'Anil Thadani, Ashutosh Sinha, Roy van Leeuwen',
#        'Pi Ventures LLP, Tanas Capital, Prodapt Holdings', 'Vitol',
#        'Ruchirans Jaipuria, Rishi Kajaria', 'Manish Choksi, Varun Vakil',
#        'Nadir B Godrej', 'Celesta Capital', 'TransUnion, Blume Ventures',
#        'Blume, Alpha Wave Incubation',
#        'Habitat for Humanity International',
#        'Global Founders Capital, Enzia Ventures, Better Capital',
#        'Kora Capital, Stripe, Alua Capital', 'Iconiq Growth',
#        'Rukam Capital, DSG Consumer Partners, The Chennai Angels',
#        'MAS Financial Services', 'Rocketship.vc, Vulcan Capital',
#        'Tiger Global, Vitruvian Partners',
#        'Think Investments, Venture Highway',
#        'Alok Kohli, Sanjeev Bhargava',
#        'Venture Catalysts, Gruhas Proptech',
#        "LetsVenture, AngelList India, Founder's Room Circle",
#        'Dinesh Godara, Anuj Ahuja, Aditya', 'Z3Partners',
#        'Celesta Capital, Omidyar Network India', 'Pavestone Ventures',
#        'LetsVenture, Paradigm Shift VC, Binny Bansal',
#        'Sofina, Lightrock India, Temasek', 'Dia Mirza', 'DST Global',
#        'Pritt Investment Partners, 9Unicorns',
#        'Darq Capital, Jagadeesh Atukuri', 'Stellaris Venture Partners',
#        'StartupXseed Ventures', 'Xponentia Capital Partners',
#        'General Atlantic, Multiples', 'Vulcan Capital', 'InCorp India',
#        'Oikocredit, Nomura, The Bill & Melinda Gates Foundation',
#        'Kedaara', 'Moore Strategic Ventures, BEENEXT',
#        'Kalaari Capital, Incubate Fund India',
#        'Sequoia Capital, Lightspeed, TVS Capital Funds', 'ABC World Asia',
#        'IIFL AMC, Sistema Asia Fund, CX Partners, Singularity Growth Opportunities Fund',
#        'Prime Securities Limited', 'Fidelity, B Capital',
#        '9Unicorns, Varanium NexGen Fund',
#        'Sequoia Capital, Sandeep Nailwal',
#        'Old Fashion Research, Nothing Research, Tenzor capital',
#        'Aavishkaar Capital, Rajiv Dadlani Group', 'NEVF, AccelNest',
#        'The Treasury', '9Unicorns, Spearhead Capital, Venture Catalysts',
#        'Ramp, Rainfall Ventures, Roka Works, Y Combinator',
#        'India Angel Network',
#        'Responsibility, Blue Ashva Capital, Pravega Ventures',
#        'Dream Capital, Elysian Park Ventures', 'CDC Group, Creaegis',
#        'Lee Fixel’s venture capital firm, Addition',
#        'Y Combinator, JAFCO Asia, Incubate Fund India, marquee angels',
#        'The Xander Group', 'Aarin Capital', 'James Milner, Adam Lallana',
#        'LetsVenture, Ajay Garg, Tarun Sharma', 'Kunal Sarkar',
#        'Morgan Stanley Private Equity Asia', 'Westbridge Capital',
#        'Lightrock India', '$Undisclosed', 'JAM, Better Tomorrow Ventures',
#        'SOSV, Venture Catalysts', 'Incofin’s India Progress Fund',
#        '9Unicorns, Anthill Ventures', 'Jani Ventures INC',
#        'CreedCap Asia Advisors', 'Joseph Joy',
#        'DST Global, Falcon Edge, SoftBank Vision Fund 2',
#        'Trifecta Capital', "Titan Capital, AngelList's syndicate",
#        'Vineet Singh, Krishna D, Deependra Bisht, Alan Aim',
#        'Westbridge Capital, Sixth Sense Ventures', 'MaGEHold',
#        'Season Two Ventures, IndiaMart', 'Kunal Shah, Anant Maheshwari',
#        'WaterBridge Ventures, Enzia Ventures',
#        'Tree Line Investment Management', 'Orbimed Asia Partners',
#        'Zip Co', 'Eight Roads Ventures, GSV', 'Kunal Shah, Krishna Kumar',
#        'Vijay Shekhar Sharma, Rohit Kapoor, Amanpreet Bajaj, Lalit Singh',
#        'Stellaris Venture Partners, Chiratae Ventures',
#        'Lightspeed, Sequioa', 'TheVentures',
#        'Titan Capital, Archana Priyadarshini, Gaurav Ahuja',
#        'Jungle Ventures, CX Partners',
#        'Cygnus Medicare Group, Probal Ghoshal, Shuchin Bajaj',
#        'M2P Fintech',
#        'SucSEED  Indovation Fund, Uincept, Palimala Ventures',
#        'Anicut Angel Fund, Sauce.VC',
#        'Omidyar Network India, Chiratae Ventures',
#        'Elevation Capital, Accel India', 'Legatum Capital',
#        'Navneet Education', '1000000\t#REF!',
#        'Sonu Nigam, Whiteboard Capital', 'Aditya Duggar',
#        'Vertex Ventures, Stellaris Venture Partners',
#        'Omnivore, India Quotient', 'We Founder Circle, Dexter Angels',
#        'IIFL\ufeff, \ufeffAnicut Angel Fund\ufeff, \ufeffKae Capital\ufeff, TradeCred',
#        'Indian Angel Network, Axilor', 'Invesco Developing Markets Fund',
#        'Cholamandalam', 'Curesense Therapeutics', 'Ka Enterprises',
#        'IAN Fund, Malabar Angel Network, Native Angel Network',
#        'DSG Consumer Partners, Titan Capital',
#        'Sujeet Kumar, SucSEED Indovation Fund',
#        'Ameba Capital, 9Unicorns',
#        'Susquehanna International Group, Bessemer Venture Partners',
#        'IIFL AMC, Oman India Joint Investment Fund', 'Unilazer Ventures',
#        'Tribe Capital, Arkam Ventures, WEH, Kunal Shah',
#        'Venture Catalysts, Indian Angel Network',
#        'Elevation Capital, Matrix Partners India', 'Ashok Goyal',
#        'Cure.fit, Endiya Partners, Tanglin Venture',
#        'HOF Capital, Old Well Ventures, LetsVenture, 9Unicorns',
#        'Jinisha Sharma, Aditya Agarwal, Victoria, Abhishek Shroff',
#        'LetsVenture, 2am VC, magic.fund',
#        'Arvind Venugopal Nair, Amritendu Mukherjee',
#        'Rajasthan Venture Capital Fund',
#        'Covalent, Double Peak, GenBlock Capital, Ledger Prime, MEXC Global, Synaps',
#        'Vijayan', 'Gokul Rajaram, JPIN, Venture Catalysts UK, AngelList',
#        'Rachit Poddar, Rajesh Gupta',
#        'Virenxia Group, Rajesh Jain, Nitin Agarwal', 'Addition',
#        'Prashasta Seth',
#        'Matrix Partners India, Jitendra Gupta, RTP Global',
#        'Shaival Desai, Flowstate Ventures', 'Zoho', 'Transworld Group',
#        'IIFL AMC', 'Owl Ventures', 'Winter Capital, ETS, Man Capital',
#        '3one4 Capital, Kalaari Capital'], dtype=object)

# %%
# notice a numerical here investor named '2000000'ArithmeticError
data_2021[data_2021['Investor']== '2000000']
# Out:
#     Company_Brand  Founded HeadQuarter   Sector  \
# 883      EyeMyEye   2021.0    Gurugram  Eyewear
#
#                                           What_it_does     Founders Investor  \
# 883  Shop the latest Eyeglasses, Sunglasses, Power ...  Ganesh Iyer  2000000
#
#        Amount         Stage
# 883 2000000.0  Pre-series A

# %%
# Replace the value "2000000" with the keyword "Unknown" in the 'Investor' column
data_2021['Investor'] = data_2021['Investor'].replace('2000000', 'Unknown')

# %%
check_missing_values(data_2021['Investor'])
# Out:
# 61

# %%
data_2021['Investor'] = data_2021['Investor'].fillna('Unknown')

# %%
data_2021['Sector'].head(10)
# Out:
# 0        AI startup
# 1            EdTech
# 2            EdTech
# 3    B2B E-commerce
# 4           FinTech
# 5     Home services
# 6        HealthTech
# 7        HealthTech
# 8      Tech Startup
# 9        E-commerce
# Name: Sector, dtype: object

# %%
# lets track the funded year
data_2021['Year Funded'] = 2021

# %%
data_2021['HeadQuarter'] = data_2021['HeadQuarter'].fillna('Unknown')

data_2021['Founders'] = data_2021['Founders'].fillna('Unknown')

# %% [markdown]
# check miss value after cleaning

# %%
plot_missing_values_heatmap(data_2021)

# %% [markdown]
# check the duplicate for each

# %%
data_2018=data_2018.drop_duplicates()

# %%
data_2019=data_2019.drop_duplicates()

# %%
data_2020=data_2020.drop_duplicates()

# %%
data_2021=data_2021.drop_duplicates()

# %%
# Select the specified columns for analy
data_2018 = data_2018[['Company Name','Location','Industry','Amount','Round/Series', 'Year Funded']]
data_2019 = data_2019[['Company/Brand','HeadQuarter','Sector','Amount($)','Stage','Year Funded']]
data_2020 = data_2020[['Company_Brand','HeadQuarter','Sector','Amount','Stage','Year Funded']]
data_2021 = data_2021[['Company_Brand','HeadQuarter','Sector','Amount','Stage','Year Funded']]

# %% [markdown]
# columns rename to have the same columns in

# %%
#Renaming columns

data_2018.rename(columns={'Industry':'Sector','Round/Series':'Stage','Location':'HeadQuarter','Amount':'Amount($)'},inplace=True)

data_2019.rename(columns={'Company/Brand':'Company Name'},inplace=True)

data_2020.rename(columns={'Company_Brand':'Company Name','Amount':'Amount($)'},inplace=True)

data_2021.rename(columns={'Company_Brand':'Company Name' ,'Amount':'Amount($)'},inplace =True)

# %%
print(f'2018: {data_2018.columns}\n\n\
        2019: {data_2019.columns}\n\n\
        2020: {data_2020.columns}\n\n\
        2021: {data_2021.columns}')
# Out:
# 2018: Index(['Company Name', 'HeadQuarter', 'Sector', 'Amount($)', 'Stage',
#        'Year Funded'],
#       dtype='object')
#
#         2019: Index(['Company Name', 'HeadQuarter', 'Sector', 'Amount($)', 'Stage',
#        'Year Funded'],
#       dtype='object')
#
#         2020: Index(['Company Name', 'HeadQuarter', 'Sector', 'Amount($)', 'Stage',
#        'Year Funded'],
#       dtype='object')
#
#         2021: Index(['Company Name', 'HeadQuarter', 'Sector', 'Amount($)', 'Stage',
#        'Year Funded'],
#       dtype='object')

# %% [markdown]
# The data 2018 does not contained the Investor column

# %%
#Concating the dataset
combinedData = pd.concat([data_2018, data_2019, data_2020, data_2021], ignore_index=True)

# %%
combinedData.sample(20)
# Out:
#          Company Name HeadQuarter                             Sector  \
# 696            Clovia       Noida                         E-Commerce
# 1352            MYSUN       Delhi                  Business Services
# 1299    Credit Mantri     Chennai                            Finance
# 2646      ApplicateAI    Gurugram  Information Technology & Services
# 1172           Vegrow   Bangalore                         Technology
# 2719           Cusmat   Hyderabad                  Computer Software
# 231     True Elements        Pune                          Marketing
# 121            FLEECA      Jaipur                          Marketing
# 1071          Gamezop    Gurugram                      Entertainment
# 1708        LearnVern   Ahmadabad                             EdTech
# 1085           Tracxn   Bangalore                  Business Services
# 2199      Indi Energy     Roorkee           Renewables & Environment
# 1881      PlanetSpark    Gurugram               Education Management
# 1720           AntWak   Bangalore                             EdTech
# 417         Medimetry     Haryana                         Healthcare
# 1417            Recko   Bangalore                         Technology
# 752   Kitchens Centre   New Delhi                         Technology
# 202     Emflux Motors   Bengaluru                          Transport
# 2002          Eduvanz      Mumbai                            FinTech
# 397              Cred   Bengaluru                          Marketing
#
#       Amount($)         Stage  Year Funded
# 696   4000000.0  Pre-series C         2020
# 1352  4257000.0  Pre-series A         2020
# 1299   792000.0      Series A         2020
# 2646 30000000.0      Series A         2021
# 1172  2500000.0          Seed         2020
# 2719   100000.0  Pre-series A         2021
# 231    730994.2          Seed         2018
# 121   1300000.0          Seed         2018
# 1071  4300000.0      Series A         2020
# 1708  1000000.0       Unknown         2021
# 1085   887000.0      Series B         2020
# 2199  3500000.0          Seed         2021
# 1881 13000000.0      Series B         2021
# 1720  3500000.0          Seed         2021
# 417   1300000.0          Seed         2018
# 1417  6000000.0      Series A         2020
# 752   3000000.0  Pre-series A         2020
# 202    364846.0          Seed         2018
# 2002 10000000.0          Debt         2021
# 397   1300000.0          Seed         2018

# %%
# check the the
combinedData.duplicated().value_counts()
# Out:
# False    2845
# True       11
# Name: count, dtype: int64

# %%
combinedData[combinedData.duplicated(keep=False)]
# Out:
#           Company Name HeadQuarter         Sector   Amount($)     Stage  \
# 632          Pine Labs       Noida        Finance   3000000.0  Series A
# 827     Genius Teacher      Mumbai      Education   2000000.0  Series A
# 845     Genius Teacher      Mumbai      Education   2000000.0  Series A
# 847              Tring      Mumbai  Entertainment   3000000.0  Series A
# 1025  FPL Technologies        Pune        Finance  10000000.0  Series A
# 1037     Lido Learning      Mumbai      Education   7500000.0  Series B
# 1123  FPL Technologies        Pune        Finance  10000000.0  Series A
# 1301             Tring      Mumbai  Entertainment   3000000.0  Series A
# 1382     Capital Float   Bangalore        Finance  15000000.0  Series A
# 1408     Lido Learning      Mumbai      Education   7500000.0  Series B
# 1513              Yolo    Gurugram      Transport    600000.0      Seed
# 1546              Byju   Bangalore      Education 200000000.0  Series A
# 1575              Yolo    Gurugram      Transport    600000.0      Seed
# 1590         Pine Labs       Noida        Finance   3000000.0  Series A
# 1625     Capital Float   Bangalore        Finance  15000000.0  Series A
# 1646              Byju   Bangalore      Education 200000000.0  Series A
# 1998             Siply   Bangalore        FinTech   1000000.0      Seed
# 2048          BharatPe   New Delhi        FinTech   6000000.0      Debt
# 2063             Siply   Bangalore        FinTech   1000000.0      Seed
# 2494          BharatPe   New Delhi        FinTech   6000000.0      Debt
# 2620      Ola Electric   Bangalore     Automotive 200000000.0   Unknown
# 2723      Ola Electric   Bangalore     Automotive 200000000.0   Unknown
#
#       Year Funded
# 632          2020
# 827          2020
# 845          2020
# 847          2020
# 1025         2020
# 1037         2020
# 1123         2020
# 1301         2020
# 1382         2020
# 1408         2020
# 1513         2020
# 1546         2020
# 1575         2020
# 1590         2020
# 1625         2020
# 1646         2020
# 1998         2021
# 2048         2021
# 2063         2021
# 2494         2021
# 2620         2021
# 2723         2021

# %%
combinedData = combinedData.drop_duplicates()

# %%
combinedData.duplicated().value_counts()
# Out:
# False    2845
# Name: count, dtype: int64

# %% [markdown]
#     Data cleaning

# %% [markdown]
# Amount column

# %%
combinedData['Amount($)'].unique().tolist()
# Out:
# [250000.0,
#  584795.3216374269,
#  950292.3976608186,
#  2000000.0,
#  1300000.0,
#  1600000.0,
#  233918.12865497073,
#  730994.1520467836,
#  1461988.3040935672,
#  150000.0,
#  1100000.0,
#  7309.941520467835,
#  6000000.0,
#  650000.0,
#  511695.9064327485,
#  935672.5146198829,
#  292397.6608187134,
#  1000000.0,
#  5000000.0,
#  4000000.0,
#  438596.4912280701,
#  2800000.0,
#  1700000.0,
#  73099.41520467836,
#  182748.5380116959,
#  219298.24561403506,
#  500000.0,
#  1520467.83625731,
#  657894.7368421052,
#  13400000.0,
#  365497.0760233918,
#  385964.91228070174,
#  116959.06432748536,
#  877.1929824561403,
#  9000000.0,
#  100000.0,
#  20000.0,
#  120000.0,
#  497076.0233918128,
#  143145.0,
#  8771929.824561402,
#  742000000.0,
#  14619883.040935671,
#  29239766.081871342,
#  3980000.0,
#  10000.0,
#  1461.9883040935672,
#  3654970.7602339177,
#  1000000000.0,
#  7000000.0,
#  35000000.0,
#  8040935.672514619,
#  28500000.0,
#  3508771.929824561,
#  1754385.9649122804,
#  2400000.0,
#  30000000.0,
#  36549707.60233918,
#  23000000.0,
#  11000000.0,
#  643274.8538011695,
#  3240000.0,
#  877192.9824561402,
#  540000000.0,
#  9502923.976608187,
#  23391812.865497075,
#  900000.0,
#  10000000.0,
#  1500000.0,
#  1023391.812865497,
#  14000000.0,
#  1498538.0116959063,
#  100000000.0,
#  17543.859649122805,
#  76023391.8128655,
#  800000.0,
#  1041000.0,
#  15000.0,
#  1400000.0,
#  1200000.0,
#  2200000.0,
#  1800000.0,
#  3600000.0,
#  138888.88888888888,
#  300000.0,
#  6830000.0,
#  200000.0,
#  2192982.4561403506,
#  4300000.0,
#  364846.0,
#  400000.0,
#  102339.1812865497,
#  20467.83625730994,
#  146198.8304093567,
#  328947.3684210526,
#  13200000.0,
#  50000.0,
#  2049707.6023391811,
#  3000000.0,
#  1250000.0,
#  180000.0,
#  280701.7543859649,
#  1505847.9532163742,
#  4200000.0,
#  175000.0,
#  1450000.0,
#  2923.9766081871344,
#  4500000.0,
#  600000.0,
#  242690.05847953213,
#  175438.59649122806,
#  15000000.0,
#  482456.14035087713,
#  125000.0,
#  130000.0,
#  510233.91812865494,
#  1052631.5789473683,
#  17200000.0,
#  467836.25730994146,
#  3500000.0,
#  1973684.2105263157,
#  12000000.0,
#  40000000.0,
#  50000000.0,
#  22514619.883040935,
#  2046783.625730994,
#  41900000.0,
#  20614035.087719295,
#  3530000.0,
#  3300000.0,
#  8479532.16374269,
#  526315.7894736842,
#  4970760.233918129,
#  210000000.0,
#  37680000.0,
#  7456140.350877193,
#  32163742.690058477,
#  22000000.0,
#  70000.0,
#  225029239.76608184,
#  292397660.8187134,
#  58479532.163742684,
#  185000000.0,
#  65000000.0,
#  2412280.7017543856,
#  700000.0,
#  3070175.438596491,
#  29672514.619883038,
#  75000000.0,
#  1169590.6432748537,
#  1760000.0,
#  2700000.0,
#  4093567.251461988,
#  11695906.432748538,
#  750000.0,
#  2500000.0,
#  80000000.0,
#  25000000.0,
#  10672514.61988304,
#  5847953.216374269,
#  3700000.0,
#  5600000.0,
#  3801169.5906432746,
#  99230000.0,
#  70000000.0,
#  40000.0,
#  550000.0,
#  365000000.0,
#  127923.97660818712,
#  1140350.8771929825,
#  28000000.0,
#  3859649.122807017,
#  16520467.836257309,
#  11842105.263157893,
#  20467836.25730994,
#  14900000.0,
#  225000000.0,
#  7500.0,
#  6300000.0,
#  150000000.0,
#  20000000.0,
#  275000000.0,
#  140500.0,
#  182700.0,
#  15500000.0,
#  5500000.0,
#  140000.0,
#  230000000.0,
#  49400000.0,
#  32000000.0,
#  26000000.0,
#  8000000.0,
#  120000000.0,
#  6800000.0,
#  36000000.0,
#  5700000.0,
#  60000000.0,
#  220000.0,
#  2100000.0,
#  311000000.0,
#  4800000.0,
#  693000000.0,
#  33000000.0,
#  340000.0,
#  45000000.0,
#  660000000.0,
#  7500000.0,
#  145000000.0,
#  21000000.0,
#  560000.0,
#  275000.0,
#  390000000.0,
#  5100000.0,
#  700000000.0,
#  2300000.0,
#  19000000.0,
#  7800000.0,
#  200000000.0,
#  4100000.0,
#  575000.0,
#  18000000.0,
#  3200000.0,
#  4700000.0,
#  121000000.0,
#  55000000.0,
#  16000000.0,
#  5400000.0,
#  52000000.0,
#  118000000.0,
#  18500000.0,
#  70000000000.0,
#  800000000.0,
#  400000000.0,
#  176000000.0,
#  470000.0,
#  240000.0,
#  3000000000.0,
#  74000000.0,
#  62000000.0,
#  500000000.0,
#  12500000.0,
#  2200000000.0,
#  5060000.0,
#  24700000.0,
#  7700000.0,
#  19067328.0,
#  51000000.0,
#  115000.0,
#  54000.0,
#  803146.0,
#  238000.0,
#  10220000.0,
#  1020000.0,
#  170000000.0,
#  2900000.0,
#  543000.0,
#  90000000.0,
#  3400000.0,
#  8090000.0,
#  1030000.0,
#  5040000.0,
#  360000.0,
#  54000000.0,
#  42500000.0,
#  11370000.0,
#  325000.0,
#  410000.0,
#  450000.0,
#  682000.0,
#  4050000.0,
#  1050000.0,
#  1080000.0,
#  2110000.0,
#  764000.0,
#  603000.0,
#  409000.0,
#  292000.0,
#  286000.0,
#  136000.0,
#  546000.0,
#  887000.0,
#  43000.0,
#  40900.0,
#  5660000.0,
#  350000.0,
#  110000.0,
#  122000000.0,
#  11635000.0,
#  1065000.0,
#  669000.0,
#  16076000.0,
#  649600.0,
#  6700000.0,
#  266500.0,
#  2879000.0,
#  26500000.0,
#  351000.0,
#  46761000.0,
#  11241000.0,
#  804000.0,
#  1340000.0,
#  467000.0,
#  133000.0,
#  3823000.0,
#  934000.0,
#  293000.0,
#  198000.0,
#  927000.0,
#  971000.0,
#  3060000.0,
#  1862000.0,
#  232000.0,
#  2888000.0,
#  1328000.0,
#  56000000.0,
#  2250000.0,
#  16753000.0,
#  1470000.0,
#  530000.0,
#  267000.0,
#  3344000.0,
#  7200000.0,
#  2743000.0,
#  6082000.0,
#  6609000.0,
#  27700000.0,
#  5940000.0,
#  3964000.0,
#  197000.0,
#  4327000.0,
#  459000.0,
#  3937000.0,
#  1313500.0,
#  229800.0,
#  5305000.0,
#  264000.0,
#  1750000.0,
#  5967000.0,
#  2980000.0,
#  323000.0,
#  1326000.0,
#  27000000.0,
#  5200000.0,
#  2530000.0,
#  792000.0,
#  11363000.0,
#  1715000.0,
#  329000.0,
#  5271000.0,
#  8700000.0,
#  3226000.0,
#  5900000.0,
#  44000000.0,
#  3879000.0,
#  13000000.0,
#  8800000.0,
#  9500000.0,
#  920000.0,
#  35600000.0,
#  9400000.0,
#  790000.0,
#  480000.0,
#  160000.0,
#  8200000.0,
#  4257000.0,
#  1410000.0,
#  349800.0,
#  786000.0,
#  2004000.0,
#  123000000.0,
#  248000.0,
#  24000000.0,
#  14259000.0,
#  24500000.0,
#  3800000.0,
#  18370000.0,
#  68525000.0,
#  1834000.0,
#  23850000.0,
#  43000000.0,
#  21600000.0,
#  4598000.0,
#  13137000.0,
#  115000000.0,
#  3900000.0,
#  670000.0,
#  8500000.0,
#  3148000.0,
#  2600000.0,
#  4049500.0,
#  10500000.0,
#  6500000.0,
#  43700000.0,
#  13800000.0,
#  306900.0,
#  420000.0,
#  627300.0,
#  113000000.0,
#  110000000.0,
#  1397000.0,
#  448500.0,
#  7975700.0,
#  330000.0,
#  1402000.0,
#  21500000.0,
#  296000000.0,
#  4900000.0,
#  1402400.0,
#  12618300.0,
#  9900000.0,
#  982530.0,
#  70185200.0,
#  84000000.0,
#  39000000.0,
#  1403400.0,
#  105000000.0,
#  103000000.0,
#  281300.0,
#  12700.0,
#  25000.0,
#  97500000.0,
#  507000.0,
#  8400000.0,
#  18300000.0,
#  125000000.0,
#  181000.0,
#  280000.0,
#  14700000.0,
#  8043000.0,
#  188000000.0,
#  49000000.0,
#  160000000.0,
#  850000.0,
#  53000000.0,
#  7400000.0,
#  17000000.0,
#  215000000.0,
#  350000000.0,
#  83000000.0,
#  150000000000.0,
#  300000000.0,
#  140000000.0,
#  17500000.0,
#  42000000.0,
#  450000000.0,
#  37000000.0,
#  370000000.0,
#  770000.0,
#  6600000.0,
#  725000.0,
#  461000.0,
#  96000000.0,
#  266000000.0,
#  325000000.0,
#  225000.0,
#  85000000.0,
#  235000.0,
#  260000.0,
#  86000000.0,
#  111000000.0,
#  265000.0,
#  76000000.0,
#  95000000.0,
#  280000000.0,
#  14300000.0,
#  81000000.0,
#  720000.0,
#  67000000.0,
#  10200000.0,
#  220000000.0,
#  108000000.0,
#  370000.0,
#  48000000.0,
#  192000000.0,
#  1900000.0,
#  41000000.0,
#  144000000.0,
#  270000000.0,
#  250000000.0,
#  320000.0,
#  38000000.0,
#  64000000.0,
#  620000.0,
#  234000000.0,
#  460000000.0,
#  13500000.0,
#  195000000.0,
#  7300000.0,
#  16500000.0,
#  92000000.0,
#  135000000.0,
#  155000.0,
#  840000000.0,
#  248000000.0,
#  570000.0,
#  260000000.0,
#  175000000.0,
#  810000.0,
#  600000000.0,
#  6750000.0,
#  78000000.0,
#  255000000.0,
#  570000000.0,
#  31000000.0,
#  540000.0,
#  6200000.0]

# %% [markdown]
# Stage column

# %%
combinedData['Stage'].unique()
# Out:
# array(['Seed', 'Series A', 'Angel', 'Series B', 'Pre-Seed',
#        'Private Equity', 'Venture - Series Unknown', 'Grant',
#        'Debt Financing', 'Post-IPO Debt', 'Series H', 'Series C',
#        'Series E', 'Corporate Round', 'Undisclosed',
#        'https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593',
#        'Series D', 'Secondary Market', 'Post-IPO Equity',
#        'Non-equity Assistance', 'Funding Round', 'Pre-series A',
#        'Series G', 'Post series A', 'Series F', 'Pre-seed', 'Pre-series',
#        'Debt', 'Pre-series C', 'Pre-series B', 'Bridge', 'Edge', 'Seed A',
#        'Series', 'Seed Round & Series A', 'Angel Round', 'Pre-Series C',
#        'Mid series', 'Series C, D', 'Unknown', 'Seed+', 'Series F2',
#        'Series A+', 'Series B3', 'PE', 'Series F1', 'Pre-series A1',
#        'Unknown, Unknown', 'Early seed', 'Series D1', 'Seies A',
#        'Series A2', 'Series I'], dtype=object)

# %% [markdown]
# let clean the stage and caterorized in mininal stage as possible

# %%
combinedData[(combinedData['Stage'] == "https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593")]
# Out:
#        Company Name HeadQuarter     Sector  Amount($)  \
# 178  BuyForexOnline   Bangalore  Marketing  2000000.0
#
#                                                  Stage  Year Funded
# 178  https://docs.google.com/spreadsheets/d/1x9ziNe...         2018

# %%
combinedData['Stage'] = combinedData['Stage'].replace('https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593', 'Unknown')
combinedData['Stage'] = combinedData['Stage'].replace('Unknown, Unknown', 'Unknown')

# %%
combinedData['Stage'].unique()
# Out:
# array(['Seed', 'Series A', 'Angel', 'Series B', 'Pre-Seed',
#        'Private Equity', 'Venture - Series Unknown', 'Grant',
#        'Debt Financing', 'Post-IPO Debt', 'Series H', 'Series C',
#        'Series E', 'Corporate Round', 'Undisclosed', 'Unknown',
#        'Series D', 'Secondary Market', 'Post-IPO Equity',
#        'Non-equity Assistance', 'Funding Round', 'Pre-series A',
#        'Series G', 'Post series A', 'Series F', 'Pre-seed', 'Pre-series',
#        'Debt', 'Pre-series C', 'Pre-series B', 'Bridge', 'Edge', 'Seed A',
#        'Series', 'Seed Round & Series A', 'Angel Round', 'Pre-Series C',
#        'Mid series', 'Series C, D', 'Seed+', 'Series F2', 'Series A+',
#        'Series B3', 'PE', 'Series F1', 'Pre-series A1', 'Early seed',
#        'Series D1', 'Seies A', 'Series A2', 'Series I'], dtype=object)

# %% [markdown]
# categorize the stage

# %%
def categorize_funding_stage(stage):
    pre_Seed = ['Pre-Seed','Early seed' ]
    seed_stages = ['Seed','Seed A','Seed Round & Series A','Seed+']
    pre_series = ['Pre-series','Pre-series A','Pre-series C', 'Pre-series B','Pre-series A1']
    series = ['Series A', 'Series A+', 'Seies A', 'Mid series','Series A2', 'Series A1', 'Series Unknown','Venture - Series Unknown','Series B', 'Series B+', 'Series B2', 'Series B3', 'Series C', 'Series C, D', 'Post series A','Series D', 'Series D1', 'Series E', 'Series E2', 'Series F', 'Series F1', 'Series F2', 'Series G', 'Series H', 'Series I']
    later_stages = ['Angel Round', 'Corporate Round', 'Funding Round',  'Bridge', 'Bridge Round',  'Post-IPO Equity', 'Secondary Market', 'Non-equity Assistance', 'Grant', 'Undisclosed', 'Unknown']
    debt = ['Post-IPO Debt', 'Debt Financing', 'Debt']
    others = ['Edge', 'Private Equity', 'PE', 'Angel', 'Angel Round','Unknown']


    if stage in pre_Seed:
        return 'Pre Seed Stage '
    elif stage in seed_stages:
        return 'Seed Stage '
    elif stage in pre_series:
        return 'Pre Series Stage '
    elif stage in series:
        return 'Series Stage '
    elif stage in later_stages:
        return 'Later Stage '
    elif stage in debt:
        return 'Debt Stage '
    else:
        return 'Others Stage '


combinedData['Stage'] = combinedData['Stage'].apply(categorize_funding_stage)

# %%
combinedData['Stage'].unique()
# Out:
# array(['Seed Stage ', 'Series Stage ', 'Others Stage ', 'Pre Seed Stage ',
#        'Later Stage ', 'Debt Stage ', 'Pre Series Stage '], dtype=object)

# %%
combinedData.sample(10)
# Out:
#                      Company Name HeadQuarter              Sector  Amount($)  \
# 708   Mobile Premier League (MPL)   Bangalore       Entertainment   500000.0
# 877                Gourmet Garden   Palmwoods   Consumer Services  3000000.0
# 1899                ASQI Advisors      Mumbai  Financial Services  1000000.0
# 51                  Dainik Jagran      Kanpur          Technology   584795.3
# 2203                         peAR      Mumbai            Deeptech   300000.0
# 1018                       EkAnek   New Delhi          Technology  5040000.0
# 864                         TREAD   Bangalore          Technology  1100000.0
# 1157                      VilCart   Bangalore   Business Services  3000000.0
# 2362               Cancer Clinics    Telugana          HealthCare  1500000.0
# 1886             Probus Insurance      Mumbai           Insurance  6700000.0
#
#                   Stage  Year Funded
# 708       Series Stage          2020
# 877       Series Stage          2020
# 1899  Pre Series Stage          2021
# 51          Seed Stage          2018
# 2203  Pre Series Stage          2021
# 1018      Others Stage          2020
# 864       Others Stage          2020
# 1157       Later Stage          2020
# 2362  Pre Series Stage          2021
# 1886       Later Stage          2021

# %% [markdown]
# Sector column

# %%
combinedData['Sector'].unique()
# Out:
# array(['Marketing', 'Finance', 'E-Commerce', 'Technology', 'Transport',
#        'Education', 'Entertainment', 'Healthcare', 'Business Services',
#        'Human Resources', 'Consumer Services', 'Industrial', 'Justince',
#        'Agriculture', 'AI startup', 'EdTech', 'B2B E-commerce', 'FinTech',
#        'Home services', 'HealthTech', 'Tech Startup', 'E-commerce',
#        'B2B service', 'Helathcare', 'Renewable Energy', 'Electronics',
#        'IT startup', 'Food & Beverages', 'Aeorspace', 'Deep Tech',
#        'Dating', 'Gaming', 'Robotics', 'Retail', 'Food', 'Oil and Energy',
#        'AgriTech', 'Telecommuncation', 'Milk startup', 'AI Chatbot', 'IT',
#        'Logistics', 'Hospitality', 'Fashion', 'Transportation',
#        'LegalTech', 'Food delivery', 'Automotive', 'SaaS startup',
#        'Fantasy sports', 'Video communication', 'Social Media',
#        'Skill development', 'Rental', 'Recruitment', 'HealthCare',
#        'Sports', 'Computer Games', 'Consumer Goods',
#        'Information Technology', 'Apparel & Fashion',
#        'Logistics & Supply Chain', 'Healthtech', 'SportsTech', 'HRTech',
#        'Wine & Spirits', 'Mechanical & Industrial Engineering',
#        'Spiritual', 'Financial Services', 'Industrial Automation',
#        'Health', 'Lifestyle', 'IoT', 'Banking', 'Computer software',
#        'Tech startup', 'Digital mortgage',
#        'Information Technology & Services', 'Furniture',
#        'B2B marketplace', 'Healtcare', 'Location Analytics', 'Media',
#        'Consumer Electronics', 'Tobacco', 'Deeptech', 'Insuretech',
#        'MLOps platform', 'Venture Capital', 'Pet care', 'Drone',
#        'Wholesale', 'Construction', 'E-learning',
#        'Venture Capital & Private Equity', 'Health, Wellness & Fitness',
#        'OTT', 'Education Management', 'Computer Software', 'Insurance',
#        'Software Startup', 'Computer & Network Security',
#        'Capital Markets', 'Social network', 'Hospital & Health Care',
#        'Music', 'Hauz Khas',
#        'Primary Business is Development and Manufacturing of Novel Healthcare Products in Effervescent forms using imported propriety ingredients.',
#        "MoEVing is India's only Electric Mobility focused Technology Platform with a vision to accelerate EV adoption in India.",
#        'Cosmetics', 'Mobility', 'Social media', 'Real Estate',
#        'Digital platform', 'B2B Ecommerce', 'Online Media',
#        'Social commerce', 'Mobile Games', 'Food Production', 'Podcast',
#        'HeathTech', 'Battery', 'Content publishing', 'Water purification',
#        'Content commerce', 'Innovation Management', 'Software company',
#        'Automation', 'Food Industry', 'Celebrity Engagement',
#        'Trading platform', 'Personal Care', 'Cannabis startup',
#        'Blogging', 'Consulting', 'BioTechnology', 'B2B Marketplace',
#        'Health care', 'Social audio', 'Fashion and lifestyle',
#        'Delivery service', 'B2B Manufacturing', 'Home Decor', 'Solar',
#        'TaaS startup', 'EV startup', 'HR Tech', 'Blockchain startup',
#        'Food and Beverages', 'Beverages', 'Manufacturing startup',
#        'Cryptocurrency', 'Vehicle repair startup', 'Advisory firm',
#        'Legaltech', 'Pollution control equiptment', 'Fashion & Lifestyle',
#        'Blockchain', 'Fitness', 'D2C', 'Automobile',
#        'Environmental Services', 'Merchandise', 'Facilities Services',
#        'Marketing & Advertising', 'Eyewear', 'D2C Business',
#        'Biotechnology', 'Farming', 'NFT Marketplace', 'Internet',
#        'SpaceTech', 'Consumer software', 'Social community', 'Fishery',
#        'Renewables & Environment', 'Online storytelling', 'Aviation',
#        'IT company', 'Environmental service', 'Job discovery platform',
#        'D2C Fashion', 'Heathcare', 'CRM', 'Software', 'Nutrition',
#        'D2C startup', 'Innovation management', 'Community platform',
#        'Venture capitalist', 'Networking', 'Commercial Real Estate',
#        'AR startup', 'Consumer service', 'Consumer goods', 'MarTech',
#        'Advertisement', 'Content creation', 'Augmented reality',
#        'Rental space', 'Bike Rental', 'Beauty products', 'Tourism',
#        'FemTech', 'Cultural', 'Co-working', 'InsureTech',
#        'Supply chain platform', 'Social platform', 'CleanTech',
#        'Real estate', 'AI company', 'Sports startup', 'Matrimony',
#        'Crypto', 'Clothing', 'Analytics', 'IoT platform', 'Commerce',
#        'Defense & Space', 'Business Supplies & Equipment', 'NFT',
#        'Oil & Energy', 'EV', 'Company-as-a-Service', 'Textiles',
#        'Professional Training & Coaching', 'Maritime',
#        'Housing Marketplace', 'Furniture Rental', 'Telecommunications',
#        'Equity Management', 'Cloud kitchen', 'Nanotechnology',
#        'Community', 'Higher Education', 'B2B',
#        'Mechanical Or Industrial Engineering', 'D2C jewellery',
#        'Sales and Distribution', 'SaaS', 'Information Services',
#        'Translation & Localization', 'Investment Banking', 'Femtech',
#        'sports', 'Foootwear', 'Legal Services', 'Veterinary',
#        'Arts & Crafts', 'Investment Management', 'Management Consulting',
#        'B2B startup',
#        'Sochcast is an Audio experiences company that give the listener and creators an Immersive Audio experience',
#        'Design', 'B2B Travel', 'Interior Design',
#        'Manchester, Greater Manchester', 'Product studio',
#        'Aviation & Aerospace', 'Staffing & Recruiting'], dtype=object)

# %%
# List of categories
Sector = combinedData['Sector']
def Sectors_redistributionCombinedData(Sector):
    if re.search(r'Marketing|Marketing & Advertising|Advertisement|Content creation|Content publishing|Blogging|Social media|Social network|Social platform|Social audio|Online storytelling|Social commerce|Podcast|Celebrity Engagement|Content commerce|Social community|Consumer software|Digital platform|Online Media|Innovation Management', Sector, re.IGNORECASE):
        return 'Marketing'
    
    elif re.search(r'Transport|Transportation|Logistics|Bike Rental|EV startup|Vehicle repair startup|Mobility|Logistics & Supply Chain|Delivery service|Telecommuncation|Oil and Energy|Renewable Energy|CleanTech|Real estate|Automotive|Automobile|Automotive|Environmental Services',Sector, re.IGNORECASE):
        return 'Transport'
    
    elif re.search(r'Technology|AI startup|HealthTech|Deep Tech| AI Chatbot|IT|Tech Startup|IT startup|Deeptech|Insuretech|IoT|Blockchain|AR startup|IoT platform|Tech startup|Healthtech|MLOps platform|SpaceTech|Drone|Environmental Services|Automation|Analytics|Information Technology|Information Technology & Services|TaaS startup|Computer Software|Software company|Software Startup|SaaS|SaaS startup|Innovation Management|Computer & Network Security|Cloud kitchen|Company-as-a-Service|Digital platform|Mobility|Social media|Video communication|Computer Games|Computer software|AR startup|Machine learning|Data Science', Sector, re.IGNORECASE):
        return 'Technology'
    
    elif re.search(r'Healthcare|HealthCare| Helathcare|Health care|HeathTech|Heathcare|Health|Healthcare|Healthtech|Hospital & Health Care|Health, Wellness & Fitness|Medical devices|Biotechnology|Medical|HealthTech|Healthcare|Biotechnology|Health, Wellness & Fitness|Medical devices|HealthTech|BioTechnology|Personal Care|Veterinary|FemTech|Femtech', Sector, re.IGNORECASE):
        return 'Healthcare' 
    
    elif re.search(r'E-Commerce|B2B E-commerce| Social commerce|Content commerce|B2B marketplace|B2B Ecommerce|Online Media|Social media|Social network|Social platform|Social audio|Online storytelling|Blogging|Social community|Consumer software|D2C|D2C Business|D2C Fashion|NFT Marketplace|D2C jewellery|E-commerce|B2B|B2B service|B2B startup|B2B Marketplace|B2B Manufacturing|B2B Travel|B2B Ecommerce|B2B marketplace|B2B E-commerce', Sector, re.IGNORECASE):
        return 'E-Commerce'
    
    elif re.search(r'Education|EdTech|E-learning|Education Management| Skill development|Higher Education|Primary Business is Development and Manufacturing of Novel Healthcare Products in Effervescent forms using imported propriety ingredients.|Digital platform|Cultural|Facilities Services|Higher Education', Sector, re.IGNORECASE):
        return 'Education'
    
    elif re.search(r'Entertainment Gaming|Video communication|Fantasy sports|Sports|Music|Podcast|Celebrity Engagement|SportsTech|Sports startup|Foootwear|Entertainment|Dating|Social Media|Content creation|Media|OTT|Sports', Sector, re.IGNORECASE):
        return 'Entertainment'
    
    elif re.search(r'Finance|FinTech| Financial Services|Venture Capital|Capital Markets|Investment Banking|Cryptocurrency|Blockchain startup|InsureTech|Digital mortgage|Equity Management|Venture Capital & Private Equity|Investment Management|NFT Marketplace|Venture capitalist|Banking', Sector, re.IGNORECASE):
        return 'Finance' 
    
    elif re.search(r'Consumer Services|Home services|Home Decor|Real estate| Rental|Rental space|Furniture|Furniture Rental|Co-working|Facilities Services|CleanTech|Environmental Services|Environmental service|Pollution control equiptment|Renewable Energy|Renewables & Environment|Solar|Water purification|Consumer Services|Consumer Goods|Consumer service|Consumer goods|Consumer Electronics|Consumer Services|Consumer service|Personal Care|Consumer Goods|Consumer software|Home services|Consumer electronics|Consumer software|Consumer services|Eyewear|Pet care|Pet care|Housing Marketplace|Rental|Merchandise|Beauty products|Apparel & Fashion|Fashion|Fashion & lifestyle|Fashion and lifestyle|Cosmetics|Fashion & Lifestyle|Eyewear|Apparel & Fashion', Sector, re.IGNORECASE):
        return 'Consumer Services'
    
    elif re.search(r'Industrial|Industrial Automation|Mechanical & Industrial Engineering| Mechanical Or Industrial Engineering|Aerospace|Defense & Space|Aviation & Aerospace|Manufacturing startup|Nanotechnology|Aviation|Defense & Space|Industrial|Pollution control equiptment|Nanotechnology|Mechanical & Industrial Engineering|Industrial Automation|Industrial Automation|Mechanical Or Industrial Engineering|Industrial', Sector, re.IGNORECASE):
        return 'Industrial' 
    
    elif re.search(r'Agriculture|AgriTech|Farming|Food Production|Food & Beverages|Food delivery|Food Industry|Food and Beverages|Food|Food & Beverages|Milk startup|Food|Food & Beverages|Fishery|AgriTech|Environmental Services|Renewables & Environment|Solar|Agriculture|Agricultur', Sector, re.IGNORECASE):
        return 'Agriculture'
    
    elif re.search(r'Human Resources|HR Tech|Recruitment|HRTech|Human Resources|Staffing & Recruiting|Recruitment', Sector, re.IGNORECASE):
        return 'Human Resources'
    
    elif re.search(r'Business Services|Business Supplies & Equipment|Professional Training & Coaching|Management Consulting|Consulting|Advisory firm|Information Services|Translation & Localization|HRTech|Recruitment|Staffing & Recruiting|Job discovery platform|CRM|B2B service|B2B startup|Business Services|Capital Markets|Consulting', Sector, re.IGNORECASE):
        return 'Business Services'
    
    elif re.search(r'LegalTech|Legal Services|Justice|Legaltech|Legal Service', Sector, re.IGNORECASE):
        return 'Justice'
    
    elif re.search(r'Spiritual|', Sector, re.IGNORECASE):
        return 'Religious'
    
    else:
        return Sector

# %%
combinedData['Sector'] = combinedData['Sector'].apply(Sectors_redistributionCombinedData)

# %%
combinedData['Sector'].unique()
# Out:
# array(['Marketing', 'Finance', 'E-Commerce', 'Technology', 'Transport',
#        'Education', 'Entertainment', 'Healthcare', 'Business Services',
#        'Human Resources', 'Consumer Services', 'Industrial', 'Religious',
#        'Agriculture', 'Justice'], dtype=object)

# %% [markdown]
# Column HeadQuarter

# %%
uniqueValue = combinedData['HeadQuarter'].unique()
uniqueValue = uniqueValue.tolist()
uniqueValue = sorted(uniqueValue)
uniqueValue
# Out:
# ['Ahmadabad',
#  'Ahmedabad',
#  'Alleppey',
#  'Alwar',
#  'Ambernath',
#  'Anand',
#  'Andheri',
#  'Azadpur',
#  'Bangalore',
#  'Bangalore City',
#  'Banglore',
#  'Beijing',
#  'Belgaum',
#  'Bengaluru',
#  'Bhilwara',
#  'Bhopal',
#  'Bhubaneswar',
#  'Bihar',
#  'Chandigarh',
#  'Chennai',
#  'Cochin',
#  'Coimbatore',
#  'Computer Games',
#  'Dehradun',
#  'Delhi',
#  'Dhingsara',
#  'Ernakulam',
#  'Faridabad',
#  'Faridabad, Haryana',
#  'Food & Beverages',
#  'Frisco',
#  'Gandhinagar',
#  'Ghaziabad',
#  'Goa',
#  'Guindy',
#  'Gujarat',
#  'Guntur',
#  'Gurgaon',
#  'Gurugram',
#  'Gurugram\t#REF!',
#  'Guwahati',
#  'Haryana',
#  'Hubli',
#  'Hyderabad',
#  'Hyderebad',
#  'India',
#  'Indore',
#  'Information Technology & Services',
#  'Irvine',
#  'Jaipur',
#  'Jharkhand',
#  'Jiaxing',
#  'Jodhpur',
#  'Kalkaji',
#  'Kalpakkam',
#  'Kannur',
#  'Kanpur',
#  'Kerala',
#  'Kochi',
#  'Kolkata',
#  'Kormangala',
#  'Kota',
#  'Kottayam',
#  'London',
#  'Lucknow',
#  'Ludhiana',
#  'Mangalore',
#  'Margão',
#  'Milano',
#  'Mohali',
#  'Mountain View, CA',
#  'Mumbai',
#  'Mylapore',
#  'Nagpur',
#  'New Delhi',
#  'New York',
#  'Newcastle Upon Tyne',
#  'Noida',
#  'Odisha',
#  'Online Media\t#REF!',
#  'Orissia',
#  'Outside India',
#  'Palmwoods',
#  'Panaji',
#  'Panchkula',
#  'Paris',
#  'Patna',
#  'Pharmaceuticals\t#REF!',
#  'Plano',
#  'Powai',
#  'Pune',
#  'Rajastan',
#  'Rajasthan',
#  'Rajsamand',
#  'Ranchi',
#  'Riyadh',
#  'Roorkee',
#  'Samastipur',
#  'Samsitpur',
#  'San Francisco Bay Area',
#  'San Ramon',
#  'Santra',
#  'Satara',
#  'Shanghai',
#  'Silvassa',
#  'Small Towns, Andhra Pradesh',
#  'Surat',
#  'Tamil Nadu',
#  'Tangerang',
#  'Telangana',
#  'Telugana',
#  'Thane',
#  'The Nilgiris',
#  'Thiruvananthapuram',
#  'Tirunelveli',
#  'Trivandrum',
#  'Tumkur',
#  'Uttar Pradesh',
#  'Uttar pradesh',
#  'Vadodara',
#  'Warangal',
#  'West Bengal',
#  'Worli']

# %%
combinedData['HeadQuarter'].describe()
# Out:
# count          2845
# unique          123
# top       Bangalore
# freq            969
# Name: HeadQuarter, dtype: object

# %% [markdown]
# column Stage

# %%
unique_values = combinedData['HeadQuarter'].unique()
unique_list = unique_values.tolist()
sorted_list = sorted(unique_list)
for i in sorted_list:
    print(i)
# Out:
# Ahmadabad
# Ahmedabad
# Alleppey
# Alwar
# Ambernath
# Anand
# Andheri
# Azadpur
# Bangalore
# Bangalore City
# Banglore
# Beijing
# Belgaum
# Bengaluru
# Bhilwara
# Bhopal
# Bhubaneswar
# Bihar
# Chandigarh
# Chennai
# Cochin
# Coimbatore
# Computer Games
# Dehradun
# Delhi
# Dhingsara
# Ernakulam
# Faridabad
# Faridabad, Haryana
# Food & Beverages
# Frisco
# Gandhinagar
# Ghaziabad
# Goa
# Guindy
# Gujarat
# Guntur
# Gurgaon
# Gurugram
# Gurugram	#REF!
# Guwahati
# Haryana
# Hubli
# Hyderabad
# Hyderebad
# India
# Indore
# Information Technology & Services
# Irvine
# Jaipur
# Jharkhand
# Jiaxing
# Jodhpur
# Kalkaji
# Kalpakkam
# Kannur
# Kanpur
# Kerala
# Kochi
# Kolkata
# Kormangala
# Kota
# Kottayam
# London
# Lucknow
# Ludhiana
# Mangalore
# Margão
# Milano
# Mohali
# Mountain View, CA
# Mumbai
# Mylapore
# Nagpur
# New Delhi
# New York
# Newcastle Upon Tyne
# Noida
# Odisha
# Online Media	#REF!
# Orissia
# Outside India
# Palmwoods
# Panaji
# Panchkula
# Paris
# Patna
# Pharmaceuticals	#REF!
# Plano
# Powai
# Pune
# Rajastan
# Rajasthan
# Rajsamand
# Ranchi
# Riyadh
# Roorkee
# Samastipur
# Samsitpur
# San Francisco Bay Area
# San Ramon
# Santra
# Satara
# Shanghai
# Silvassa
# Small Towns, Andhra Pradesh
# Surat
# Tamil Nadu
# Tangerang
# Telangana
# Telugana
# Thane
# The Nilgiris
# Thiruvananthapuram
# Tirunelveli
# Trivandrum
# Tumkur
# Uttar Pradesh
# Uttar pradesh
# Vadodara
# Warangal
# West Bengal
# Worli

# %%
combinedData.replace({'HeadQuarter': {"Ahmadabad":"Ahmedabad",
                        "Bangalore City|Banglore" :"Bangalore",
                        "Beijing|Frisco|Irvine|Jiaxing|London|The Nilgiris|Tangerang|San Ramon|Shanghai|San Francisco Bay Area|Milano|Mountain View, CA|New York|Newcastle Upon Tyne|Palmwoods|Paris": "Outside India",
                        "Faridabad, Haryana":"Faridabad",
                        "Gurugram	#REF!":"Gurugram",
                        "Hyderebad":"Hyderebad",
                        "India|Computer Games|Food & Beverages|Information Technology & Services|Online Media	#REF!|Pharmaceuticals	#REF!":"Bangalore", #most frequency
                        "Kalkaji":"Delhi",
                        "Mylapore":"Chennai",
                        "Rajastan":"Rajasthan",
                        "Santra":"Gujarat",
                        "Small Towns, Andhra Pradesh":"Amaravati",
                        "Telugana":"Telangana",
                        "Uttar pradesh":"Uttar Pradesh",
                        "Worli":"Mumbai"
                    }},inplace =True, regex=True)

# %%
combinedData['HeadQuarter'].unique().tolist()
# Out:
# ['Bangalore',
#  'Mumbai',
#  'Gurgaon',
#  'Noida',
#  'Hyderabad',
#  'Bengaluru',
#  'Delhi',
#  'Hubli',
#  'New Delhi',
#  'Chennai',
#  'Mohali',
#  'Kolkata',
#  'Pune',
#  'Jodhpur',
#  'Kanpur',
#  'Ahmedabad',
#  'Azadpur',
#  'Haryana',
#  'Cochin',
#  'Faridabad',
#  'Jaipur',
#  'Kota',
#  'Anand',
#  'Belgaum',
#  'Thane',
#  'Margão',
#  'Indore',
#  'Alwar',
#  'Kannur',
#  'Trivandrum',
#  'Ernakulam',
#  'Kormangala',
#  'Uttar Pradesh',
#  'Andheri',
#  'Ghaziabad',
#  'Kochi',
#  'Powai',
#  'Guntur',
#  'Kalpakkam',
#  'Bhopal',
#  'Coimbatore',
#  'Alleppey',
#  'Chandigarh',
#  'Guindy',
#  'Lucknow',
#  'Telangana',
#  'Gurugram',
#  'Surat',
#  'Rajasthan',
#  'Tirunelveli',
#  'Outside Bangalore',
#  'Gujarat',
#  'Kerala',
#  'Outside India',
#  'Dhingsara',
#  'Patna',
#  'Plano',
#  'Samastipur',
#  'Tumkur',
#  'Ludhiana',
#  'Dehradun',
#  'Riyadh',
#  'Warangal',
#  'Hyderebad',
#  'Odisha',
#  'Bihar',
#  'Goa',
#  'Tamil Nadu',
#  'Amaravati',
#  'Rajsamand',
#  'Ranchi',
#  'Vadodara',
#  'Nagpur',
#  'West Bengal',
#  'Samsitpur',
#  'Silvassa',
#  'Thiruvananthapuram',
#  'Roorkee',
#  'Ambernath',
#  'Panchkula',
#  'Mangalore',
#  'Bhubaneswar',
#  'Kottayam',
#  'Panaji',
#  'Satara',
#  'Orissia',
#  'Jharkhand',
#  'Bhilwara',
#  'Guwahati',
#  'Gandhinagar']

# %% [markdown]
# #### **UNIVARIATE ANALYSIS**

# %% [markdown]
# - Univariate analysis involves the examination of a single variable (or feature) at a time. It is the simplest form of data analysis and is often used to describe the characteristics of individual variables.

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
def plot_top_values(data, column_name, n=10, direction='v' , background_color='lightgrey'):
    column_counts = data[column_name].value_counts()

    top_n_values = column_counts.nlargest(n)
    top_n_values_df = pd.DataFrame(top_n_values).reset_index()
    top_n_values_df.columns = [column_name, 'Count']

    colors = ['#046A38']
    plt.figure(figsize=(20, 10), facecolor=background_color)
    ax = sns.barplot(data=top_n_values_df, x=column_name,orient= direction, y='Count', palette=colors*len(top_n_values_df))
    ax.set_facecolor(background_color)
    ax.set_axisbelow(True)
    
    plt.xlabel(column_name)
    plt.ylabel('Count')
    plt.title(f'Top {n} Most Frequent {column_name}s', fontsize=20, weight='bold')

    for index, row in top_n_values_df.iterrows():
        ax.text(index, row['Count'], row['Count'], weight='bold', ha="center")

    plt.show()

# %% [markdown]
# 1. Top 10 Company that recieved multiple investment from 2018-2021

# %%
plot_top_values(combinedData,'Company Name',10)

# %% [markdown]
# summary
#
# - It is evident from the visualization that a company called **BharatPe** stands out among Indian start-ups by securing **9 investments** from 2018 to 2021

# %% [markdown]
# 2. Top 10 Location with more startups that received Investment from 2018-2021

# %%
plot_top_values(combinedData,'HeadQuarter',10)

# %% [markdown]
# It is evident from the visualization that **Bangalore** is the leading location in India, with **984 start-ups** received investments from 2018 to 2021.

# %% [markdown]
# 3. Top 10 sector with most Start Ups that received Investment in India from 2018-2021

# %%
plot_top_values(combinedData,'Sector',10)

# %% [markdown]
# it is evident from the visualization that the **Technology sector** leads in investments, with \*_767 start-ups_ in this sector receiving funding in India from 2018 to 2021.

# %% [markdown]
# 4. Top 5 Stage where startups received more Investments in India from 2018-2021

# %%
plot_top_values(combinedData,'Stage',5)

# %% [markdown]
# It is evident from the visualization that the Series stage is the most significant stage, with 1201 Investment in India startups receiving investments at this stage from 2018 to 2021.

# %%
def total_investment_amount(data, amount_column='Amount($)'):
    
    data[amount_column] = pd.to_numeric(data[amount_column], errors='coerce')
    total_amount = data[amount_column].sum()
    
    total_amount = f"${total_amount:,.0f}"

    return total_amount

# %% [markdown]
# Total Amount Invested in Indian Start ups from 2018-2021

# %%
total_investment_amount(combinedData)
# Out:
# '$280,688,791,137'

# %% [markdown]
# Total Amount Invested in Indian Start ups from 2018-2021 was Approximately **$280.7 Bilions**

# %% [markdown]
# ### **MULTIVARIATE ANALYSIS**

# %% [markdown]
# Multivariate Analysis: A statistical technique used to examine and interpret data involving multiple variables simultaneously to understand relationships, patterns, and interactions among them. It helps in uncovering complex dependencies and provides comprehensive insights into the data

# %% [markdown]
# Plotting the correlation heatmap for the **Amount**, **Year Funded** and **Founded** columns.

# %%
combinedData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2845 entries, 0 to 2855
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company Name  2845 non-null   object
#  1   HeadQuarter   2845 non-null   object
#  2   Sector        2845 non-null   object
#  3   Amount($)     2845 non-null   float64
#  4   Stage         2845 non-null   object
#  5   Year Funded   2845 non-null   int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 155.6+ KB

# %%
# Compute the correlation matrix
numeric_data = combinedData.select_dtypes(include=[float, int])
corr_matrix = numeric_data.corr()
colors = ['#FF9933', 'white', '#046A38']
cmap = LinearSegmentedColormap.from_list('IndianFlagColors', colors)
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap=cmap, linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# From our correlation heatmap, there seem to be a very weak positive relationship between the year funded and funding amount received.
#
# For founding years of companies and funding obtained, there exits a weak negative relationship.
#
# This implies that, amount funded does not depend on the particular year in which funding was received.

# %% [markdown]
# ## Answering the formulated 5 SMART questions:

# %% [markdown]
#     5 SMART Analytics Questions:
#
# 1.  What is the overall trend in funding received by start-ups in India from 2018 to 2021?

# %%
# Trend of Funding for Startups in India (2018-2021)
total_funding_per_year = combinedData.groupby('Year Funded')['Amount($)'].sum()
years = total_funding_per_year.index
total_funding = total_funding_per_year.values / 1e9  # Divide by 1 billion
plt.figure(figsize=(10, 6))
plt.plot(years, total_funding, marker='o', linestyle='-', color='#046A38')
plt.xlabel('Year Funded')
plt.ylabel('Total Funding Amount (Billions $)')
plt.title('Yearly Trend of Funding for Startups in India (2018-2021)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlim(min(years) - 1, max(years) + 1)  
plt.xticks(years) 
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. 2018-2019: Downtrend
#
# - 2018: The total funding received by Indian startups was $6.84B.
# - 2019: Funding dropped significantly to $3.41B, indicating a downward trend in investment.
#
# 2. 2020-2021: Surge and Exponential Growth
#
# - 2020: Funding witnessed an unprecedented increase, reaching $90.56B, driven by increased investor confidence and the rise of technology-driven startups during the pandemic.
# - 2021: Funding further soared to $179.88B, more than doubling the amount from the previous year, reflecting robust expansion of the startup ecosystem and heightened interest from global investors.

# %% [markdown]
# 2.  Which sectors have received the highest funding during this period?

# %%
# Calculate the top 10 sectors by total funding amount
top_10 = pd.DataFrame(combinedData.groupby('Sector')['Amount($)'].sum().nlargest(10)).reset_index()
top_10.columns = ['Sector', 'Total Amount']
top_10['Total Amount'] = top_10['Total Amount'] / 1e9
plt.figure(figsize=(10, 6))
ax = sns.barplot(data=top_10, x='Total Amount', y='Sector', orient="h", color='#046A38')
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel('Total Amount (Billions $)', fontsize=16)
plt.ylabel('Sector', fontsize=16)
plt.title('Top 10 Funded Sectors (2018-2021)', fontsize=16, weight='bold')
for index, value in enumerate(top_10['Total Amount']):
    plt.text(value, index, f'{value:.2f}B', color='black', ha="left", va="center", fontsize=15)

plt.tight_layout()
plt.show()

# %%
#Total Amount Invested
top_Amount = combinedData['Amount($)'].sum()
top_Amount = top_Amount/ 1e9
print(f'${top_Amount:.2f}B')
# Out:
# $280.69B

# %% [markdown]
# 3.  What is the distribution of startups across the cities in India?

# %%
startups_by_HeadQuarter = combinedData['HeadQuarter'].value_counts().nlargest(10).reset_index()
startups_by_HeadQuarter.columns = ['HeadQuarter', 'Number of Startups']
plt.figure(figsize=(16, 10))
ax = sns.barplot(data=startups_by_HeadQuarter, x='Number of Startups', y='HeadQuarter', orient="h", color='#046A38')
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel('Number of Startups', fontsize=16)
plt.ylabel('HeadQuarter', fontsize=16)
plt.title('Distribution of Startups Across Top Cities in India', fontsize=16, weight='bold')
for index, value in enumerate(startups_by_HeadQuarter['Number of Startups']):
    plt.text(value, index, f'{value}', color='black', ha="left", va="center",weight='bold', fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# 4.  What is the average funding amount received by start-ups in India during this period?

# %%
mean_funding_per_year = combinedData.groupby('Year Funded')['Amount($)'].mean().reset_index()
mean_funding_per_year.columns = ['Year', 'Average Funding']
mean_funding_per_year['Average Funding'] = mean_funding_per_year['Average Funding'] / 1e6
plt.figure(figsize=(12, 8))
sns.barplot(data=mean_funding_per_year, x='Year', y='Average Funding', color='#046A38')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Average Funding Amount (Millions $)', fontsize=15)
plt.title('Average Funding Amount Received by Start-ups in India (2018-2021)', fontsize=18, weight='bold')
for index, value in enumerate(mean_funding_per_year['Average Funding']):
    plt.text(index, value, f'${value:,.2f}M', color='black', ha="center", va="bottom", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# 5.  What is the distribution of the number of startups that received funding in each year from 2018 to 2021?

# %%
# Group the data by year and count the number of startups that received funding each year
startup_counts_per_year = combinedData.groupby('Year Funded')['Company Name'].count().reset_index()
startup_counts_per_year.columns = ['Year', 'Number of Startups']

# Create the bar plot
plt.figure(figsize=(12, 8))
sns.barplot(data=startup_counts_per_year, x='Year', y='Number of Startups', color='#046A38')

# Customize the appearance
plt.xticks(fontsize=18)
plt.yticks(fontsize=15)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Number of Startups', fontsize=15)
plt.title('Number of Startups Receiving Funding Each Year (2018-2021)', fontsize=18, weight='bold')

# Add value labels on the bars
for index, value in enumerate(startup_counts_per_year['Number of Startups']):
    plt.text(index, value, f'{value}', color='black', ha="center", va="bottom", fontsize=12,)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# 6. At What Stages were Most Start-ups Funded?

# %%
df_filtered_stages = combinedData.groupby(['Stage'])['Amount($)'].sum().nlargest(3)
labels = df_filtered_stages.index
sizes = df_filtered_stages.values

# doughnut pie chart
plt.figure(figsize=(8, 6), facecolor='lightgrey')
colors = ['#FF9933', '#046A38', 'white']
wedges, texts, autotexts = plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90,colors=colors, wedgeprops=dict(width=0.3), pctdistance=0.85)
plt.setp(autotexts, size=12, weight='bold')
plt.setp(texts, size=12)
plt.title('Top 3 Funding Stages in Finding ', fontsize=16)
plt.axis('equal')
plt.show()

# %% [markdown]
# 5.  Hypotheses Testing
#
# Hypothesis testing is a statistical method that allows you to test an assumption or claim about a population parameter based on sample data.

# %% [markdown]
# ### ANOVA is used to test the hypothesis at a significance level of 0.05 against the p-value.
#
# #### If the p-value is lessthan the alpha level of significance we will reject the null hypothesis otherwise we dont reject.
#
# #### To choose between the non parametric and parametric ANOVA , the distribution of the amount column is investigated. If it is normal we use the parametric one way ANOVA otherwise we use the the non prametric ANOVA known as Kruskal Wallis
#
# Hypothesis 1
#
# **Null Hypothesis (H₀):** There are no significant disparities in funding received by different sectors of Indian startups.
#
# **Alternate Hypothesis (Ha):** The technology sector receives significantly higher funding compared to other industries.

# %%
# Alpha 
alpha=0.05

# %% [markdown]
# Test method: Since we are comparing funding amounts across multiple sectors, an ANOVA (Analysis of Variance) test is appropriate.

# %%
# Hypothesis 1: Sector-Based Funding Disparities
sector_groups = [combinedData[combinedData['Sector'] == sector]['Amount($)'] for sector in combinedData['Sector'].unique()]
anova_result_sector = stats.f_oneway(*sector_groups)

#print("F-statistic:", anova_result_sector.statistic)
print("p-value:", anova_result_sector.pvalue)
if anova_result_sector.pvalue <= alpha:
    print("Reject the null hypothesis: There are significant disparities in funding received by different sectors.")
else:
    print("Do not reject the null hypothesis: There are no significant disparities in funding received by different sectors.")
# Out:
# p-value: 0.9852718143033432
# Do not reject the null hypothesis: There are no significant disparities in funding received by different sectors.

# %% [markdown]
# Hypothesis 2
#
# **Null Hypothesis (H₀):** The location of a startup in a particular city does not influence the amount of funding it receives.
#
# **Alternate Hypothesis (Ha):** The location of a startup in a particular city significantly affects the amount of funding it receives.

# %%
city_groups = [combinedData[combinedData['HeadQuarter'] == city]['Amount($)'] for city in combinedData['HeadQuarter'].unique()]
anova_result_city = stats.f_oneway(*city_groups)

#print("F-statistic:", anova_result_city.statistic)
print("p-value:", anova_result_city.pvalue)

if anova_result_city.pvalue <= alpha:
    print("Reject the null hypothesis: The location of a startup significantly affects the amount of funding it receives.")
else:
    print("Do not reject the null hypothesis: The location of a startup does not significantly affect the amount of funding it receives.")
# Out:
# p-value: 0.9999999999999999
# Do not reject the null hypothesis: The location of a startup does not significantly affect the amount of funding it receives.

# %%
#Export the cleaned 
combinedData.to_csv('dataset/cleanedData.csv',index=False)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The analysis suggests a dynamic and growing startup, with a diverse range of sectors attracting substantial funding . The concentration of funding in specific cities, such as **Bangalore,Mumbai, and Gurugram**, highlights the importance of geographical factors in the startup landscape. The upward trend in funding over the years, particularly the significant increase in 2021, indicates a robust and expanding startup ecosystem. However, it's essential to consider external factors and market conditions that may influence funding trends. The findings provide valuable insights for investors interested in **Technology,Finace and Education** as the top sector in the startup ecosystem in India Startups where the total Investment was **$280.69B** in total.
